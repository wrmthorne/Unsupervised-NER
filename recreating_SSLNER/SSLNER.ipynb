# %% [markdown]
# # Self-Supervised Named Entity Recognition (SSLNER)
#
# Project based on [this repository](https://github.com/ajitrajasekharan/unsupervised_NER) and [this medium blog post](https://towardsdatascience.com/ssl-could-avoid-supervised-learning-fd049a27cd1b). RoBERTa is used instead of BERT because of the improved robustness of the model from dynamic masking instead of static masking.

# %%
from transformers import RobertaTokenizer, RobertaModel, BertTokenizer, BertModel
import json
import urllib.request
from pprint import pprint
import kmeans_pytorch

# %%
model_name = 'bert-base-cased'

# tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
# model = RobertaModel.from_pretrained('roberta-base', output_hidden_states=True)

tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained("bert-base-cased", output_hidden_states=True)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
response = urllib.request.urlopen("https://s3.amazonaws.com/models.huggingface.co/bert/roberta-base-vocab.json")
thing = response.read()

#pprint(thing)

# %%
response = urllib.request.urlopen("https://s3.amazonaws.com/models.huggingface.co/bert/roberta-base-vocab.json")
response = urllib.request.urlopen(tokenizer.pretrained_vocab_files_map['vocab_file'][model_name])
try:
    vocab = dict(zip((tokens := response.read().decode('utf-8').splitlines()), tokenizer.convert_tokens_to_ids(tokens)))
except Exception as e:
    print(e)

#pprint(vocab)

# %%
entity_types = {'PERSON', 'ORG', 'LOC', 'DATE_TIME', 'WORK_OF_ART', 'MATERIAL', 'EVENT', 'MONEY', 'CARDINAL', 'ORDINAL', 'MISC'}

# %%
with open('ordinal.lst', 'r') as file:
    ordinals = file.read().splitlines()

ordinals = {ord for ord in ordinals if ord in vocab}

# %%
cardinals = {s for s in vocab if s.isdigit()}

with open('numbers.lst', 'r') as file:
    string_cardinals = file.read().splitlines()

cardinals = cardinals | {card for card in string_cardinals if card in vocab}

# %%
with open('person_first.lst', 'r') as file:
    first_names = file.read().splitlines()

names = {name for name in first_names if name in vocab} | {n for name in first_names if (n := name.lower()) in vocab}

# %% [markdown]
# Extracting contextual embeddings by summing over the lasy 4 layers

# %%
import torch
import torch.nn as nn

text = 'After stealing money from the bank vault, the bank robber was seen fishing on the Mississippi river bank.'
enc_text = tokenizer.encode_plus(text, return_tensors='pt')

model.eval()
with torch.no_grad():
    outputs = model(enc_text.input_ids, enc_text.attention_mask)
    hidden_states = outputs[2]

print(enc_text.input_ids.shape)
token_embeddings = torch.stack(hidden_states, dim=0)
token_embeddings = torch.squeeze(token_embeddings, dim=1)
print(token_embeddings.shape)
token_embeddings = token_embeddings.permute(1, 0, 2)
print(token_embeddings.shape)

token_vecs_sum = [torch.sum(token[-4:], dim=0) for token in token_embeddings]
print("bank vault   ", str(token_vecs_sum[5][:5]))
print("bank robber  ", str(token_vecs_sum[10][:5]))
print("river bank   ", str(token_vecs_sum[19][:5]))

cos = nn.CosineSimilarity(dim=0)
print(f'Bank Vault - Bank Robber: {cos(token_vecs_sum[6], token_vecs_sum[10])}')
print(f'Bank Vault - River Bank: {cos(token_vecs_sum[6], token_vecs_sum[19])}')
print(f'Bank Robber - River Bank: {cos(token_vecs_sum[10], token_vecs_sum[19])}')
# Out:
# torch.Size([1, 24])
# torch.Size([13, 24, 768])
# torch.Size([24, 13, 768])
# bank vault    tensor([-1.1211, -1.5639,  0.5538, -0.5256,  0.1242])
# bank robber   tensor([-2.0299, -0.9155, -4.2468,  4.2540,  2.1868])
# river bank    tensor([ 3.1898, -0.4442, -1.9258, -0.4348,  2.5461])
# Bank Vault - Bank Robber: 0.903982400894165
# Bank Vault - River Bank: 0.7330647110939026
# Bank Robber - River Bank: 0.6783679723739624

# %% [markdown]
# Extracting raw word embeddings

# %%
#print([module for module in model.modules()])
test_terms = ['stream', 'Stream']
print([t in vocab for t in test_terms])

similarity_test = tokenizer.convert_tokens_to_ids(test_terms)
print(similarity_test)

raw_word_embeddings = model.embeddings.word_embeddings.weight.detach()

cos = nn.CosineSimilarity(dim=0)
with torch.no_grad():
    tok_embeds = raw_word_embeddings[similarity_test]
    print(tok_embeds)
    print(cos(*tok_embeds))

print(len(raw_word_embeddings))
# Out:
# [True, True]
# [5118, 22627]
# tensor([[-0.0263, -0.0251, -0.0134,  ..., -0.0169, -0.0548, -0.0229],
#         [-0.0144, -0.0418, -0.0290,  ...,  0.0302, -0.0696,  0.0051]])
# tensor(0.5783)
# 28996

# %%
enc_tok = tokenizer.convert_tokens_to_ids('United')

dist = torch.norm(raw_word_embeddings - raw_word_embeddings[enc_tok], dim=1, p=None)
knn = dist.topk(20, largest=False)
print(knn)

print(list(zip([cos(raw_word_embeddings[enc_tok], raw_word_embeddings[k]) for k in knn.indices], tokenizer.convert_ids_to_tokens(knn.indices))))
# Out:
# torch.return_types.topk(
# values=tensor([0.0000, 1.3220, 1.3394, 1.3422, 1.3484, 1.3511, 1.3578, 1.3616, 1.3660,
#         1.3695, 1.3733, 1.3790, 1.3815, 1.3826, 1.3832, 1.3832, 1.3856, 1.3859,
#         1.3880, 1.3886]),
# indices=tensor([1244, 1646, 1392, 1237, 1203, 1570, 1456, 1970, 1993, 2921, 1305, 1109,
#         2579, 1291, 3466, 3604, 2690, 1978, 2685, 1287]))
# [(tensor(1.), 'United'), (tensor(0.2931), 'US'), (tensor(0.2538), 'City'), (tensor(0.2395), 'American'), (tensor(0.2826), 'New'), (tensor(0.2471), 'International'), (tensor(0.2403), 'North'), (tensor(0.2515), 'Central'), (tensor(0.2230), 'UK'), (tensor(0.1580), 'Johnson'), (tensor(0.2120), 'National'), (tensor(0.1072), 'The'), (tensor(0.2352), 'Northern'), (tensor(0.2352), 'World'), (tensor(0.1613), 'Harry'), (tensor(0.2574), 'FC'), (tensor(0.1618), 'Jones'), (tensor(0.1055), 'seven'), (tensor(0.2046), 'Southern'), (tensor(0.1081), 'John')]

# %% [markdown]
# ## Filtering of RoBERTa vocabulary
#
# Remove any punctuation strings, sub-word level tokens and single character tokens

# %%
import string
import re

filtered_vocab = {token: idx for token, idx in vocab.items() if not any(s in string.punctuation for s in token) and len(token) > 1}

print(f'Filtered Vocab: {len(filtered_vocab)}/{len(vocab)}')
# Out:
# Filtered Vocab: 21415/28996

# %% [markdown]
# Computing cosine similarity matrix for all filtered token embeddings

# %%
# Dictionary mapping incrementing indices to the vocab ids
index_idxs = {idx: k for idx, k in enumerate(filtered_vocab.values())}

filtered_vocab_embeds = raw_word_embeddings[list(filtered_vocab.values())]

# Calculate cosine similarity matrix 
with torch.no_grad():
    normalised = filtered_vocab_embeds / filtered_vocab_embeds.norm(dim=1)[:, None]
    similarity_matrix = torch.mm(normalised, normalised.transpose(0, 1))

similarity_matrix.fill_diagonal_(0)
print(similarity_matrix)
# Out:
# tensor([[ 0.0000,  0.4298,  0.4382,  ..., -0.1729, -0.1898, -0.2358],
#         [ 0.4298,  0.0000,  0.4958,  ..., -0.1483, -0.1938, -0.1900],
#         [ 0.4382,  0.4958,  0.0000,  ..., -0.1942, -0.2092, -0.1902],
#         ...,
#         [-0.1729, -0.1483, -0.1942,  ...,  0.0000,  0.2980,  0.2323],
#         [-0.1898, -0.1938, -0.2092,  ...,  0.2980,  0.0000,  0.2660],
#         [-0.2358, -0.1900, -0.1902,  ...,  0.2323,  0.2660,  0.0000]])

# %% [markdown]
# Implement graph based clustering. First split into graphs where similarity is above a threshold

# %%
threshold = 0.4

similarity_matrix[similarity_matrix < threshold] = 0
print(similarity_matrix)
# Out:
# tensor([[0.0000, 0.4298, 0.4382,  ..., 0.0000, 0.0000, 0.0000],
#         [0.4298, 0.0000, 0.4958,  ..., 0.0000, 0.0000, 0.0000],
#         [0.4382, 0.4958, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]])

# %% [markdown]
# [NEED TO FIND ALL FULLY CONNECTED SUBGRAPHS]

# %% [markdown]
# Then find node with highest average connection strength for each graph

# %%
# Calculate mean within graph, i.e. mean of all non-zero values
mean_connections = similarity_matrix.sum(dim=1) / (similarity_matrix != 0).sum(dim=1)
mean_connections = mean_connections.nan_to_num(0)

# Column vector of average weights within fully connected graphs
print(mean_connections)
print(torch.max(mean_connections))
print(torch.argmax(mean_connections))
# Out:
# tensor([0.4788, 0.5025, 0.4936,  ..., 0.5003, 0.4588, 0.4784])
# tensor(0.8169)
# tensor(5251)

# %%
stacked_means = mean_connections.repeat(similarity_matrix.size(0), 1)

pivots = torch.argmax(stacked_means * (similarity_matrix != 0), dim=1)
print(pivots)
# Out:
# tensor([   38,    11,    33,  ...,  4803,  7684, 12445])

# %%
print(len(pivots.unique()))
pivot_tokens = list(set(pivots))
pivot_vectors = raw_word_embeddings[[index_idxs[int(token)] for token in pivot_tokens]]
# Out:
# 8771

# %%
grouped_by_pivot = {int(i): (pivots == i).nonzero().squeeze() for i in pivots.unique()}
pprint(grouped_by_pivot)
# Out:
# {0: tensor([  125,   202,   267,  ..., 21377, 21378, 21381]),
#  1: tensor([ 3,  4,  8, 10, 11, 14, 16, 17]),
#  2: tensor(33),
#  3: tensor(546),
#  4: tensor([26, 50, 59, 80]),
#  7: tensor([ 23,  40, 961]),
#  8: tensor(244),
#  10: tensor([ 95, 111]),
#  11: tensor([1, 9]),
#  12: tensor(30),
#  13: tensor(53),
#  14: tensor(494),
#  15: tensor(36),
#  16: tensor(212),
#  17: tensor(468),
#  20: tensor([ 15,  31,  49, 103, 113]),
#  22: tensor(595),
#  23: tensor([ 5, 28]),
#  25: tensor(2713),
#  27: tensor(48),
#  28: tensor(1130),
#  32: tensor([188, 589]),
#  33: tensor([   2,   29, 1633]),
#  34: tensor(2955),
#  35: tensor([ 19,  39, 281, 291]),
#  37: tensor([ 207, 1883]),
#  38: tensor([ 0, 12, 13, 18, 75]),
#  39: tensor([  65, 1259]),
#  40: tensor([  7,  21,  34, 377]),
#  42: tensor([  45,   88, 2362]),
#  46: tensor([1061, 1364]),
#  49: tensor([ 20,  27, 298]),
#  50: tensor(926),
#  51: tensor([ 94, 122, 269]),
#  52: tensor(4153),
#  53: tensor(895),
#  54: tensor([ 410, 1353]),
#  55: tensor([  37,   93,  123,  196,  772, 1411]),
#  56: tensor([230, 340]),
#  58: tensor(74),
#  60: tensor([ 584,  586, 1746]),
#  61: tensor([484, 969]),
#  62: tensor(1545),
#  63: tensor(82),
#  64: tensor(2967),
#  67: tensor([128, 183]),
#  68: tensor(1165),
#  69: tensor(428),
#  71: tensor([ 407, 1554, 5640]),
#  73: tensor(182),
#  74: tensor(14336),
#  75: tensor([   6,   38,  214,  481, 1291]),
#  76: tensor([ 302,  527, 8539]),
#  77: tensor(12759),
#  78: tensor([1232, 3414]),
#  79: tensor([ 24, 164]),
#  80: tensor([1029, 3281]),
#  82: tensor([  63, 1319]),
#  83: tensor([  70,  867, 1311]),
#  85: tensor([ 411,  638,  813, 1047, 4264]),
#  86: tensor([514, 534, 889]),
#  88: tensor([  42,   64, 3725]),
#  89: tensor(2473),
#  91: tensor([134, 135]),
#  92: tensor(1795),
#  93: tensor([  55,  156, 2059, 2813]),
#  97: tensor([ 146, 1128, 1139]),
#  98: tensor(13957),
#  99: tensor(4158),
#  100: tensor(5108),
#  101: tensor(7721),
#  102: tensor([370, 838]),
#  104: tensor(7184),
#  105: tensor(6825),
#  106: tensor([1551, 5745]),
#  107: tensor(66),
#  108: tensor(1669),
#  109: tensor([ 972, 3106]),
#  112: tensor([  58, 4393]),
#  114: tensor(8936),
#  116: tensor(4549),
#  117: tensor([3261, 3301]),
#  118: tensor([ 347,  389,  740,  913,  951, 2650]),
#  119: tensor([  155, 16100]),
#  121: tensor(21038),
#  123: tensor(158),
#  124: tensor([  270,  2569, 11687]),
#  127: tensor(2399),
#  131: tensor([ 524,  594, 5228]),
#  133: tensor([ 143,  449, 1184]),
#  134: tensor(2800),
#  136: tensor(2179),
#  138: tensor(5342),
#  141: tensor(1863),
#  144: tensor([ 453,  844, 1942, 9985]),
#  145: tensor([1385, 2908]),
#  146: tensor([  97, 1659, 4066]),
#  147: tensor([ 873, 2544]),
#  148: tensor([ 350,  420, 2586, 3777]),
#  149: tensor([1240, 2718]),
#  150: tensor(11157),
#  151: tensor(16085),
#  153: tensor(170),
#  154: tensor([1112, 1193, 1272, 4010]),
#  155: tensor(620),
#  157: tensor(13565),
#  158: tensor(4692),
#  159: tensor([201, 392, 585, 917, 925]),
#  160: tensor(8731),
#  161: tensor(7058),
#  162: tensor(3533),
#  164: tensor(79),
#  165: tensor(1063),
#  166: tensor([ 149,  644, 6234]),
#  167: tensor([ 521,  672,  755,  857, 1899]),
#  169: tensor([2250, 7760]),
#  170: tensor([153, 778]),
#  171: tensor([236, 426]),
#  172: tensor(220),
#  174: tensor([  76,  404, 1003, 1306, 5368, 8399]),
#  175: tensor([1568, 5635]),
#  176: tensor([ 319, 1695]),
#  177: tensor([1243, 1325]),
#  178: tensor([ 635,  700, 2518]),
#  179: tensor(1309),
#  180: tensor(3502),
#  181: tensor([ 866, 1652, 2075]),
#  182: tensor(73),
#  183: tensor([  67, 2107]),
#  184: tensor([1143, 3024, 4768]),
#  185: tensor(425),
#  186: tensor([  791, 16797]),
#  187: tensor([ 365,  661, 1711, 9416]),
#  188: tensor([  32,  380, 3583]),
#  189: tensor([ 663, 5684, 6164]),
#  191: tensor([ 3063,  4772, 18195]),
#  192: tensor([ 272, 2012, 3053]),
#  193: tensor([ 372, 2843]),
#  194: tensor(4806),
#  195: tensor([  880,  1114,  2141, 18622]),
#  196: tensor([  84,  248,  513, 1164, 1312]),
#  199: tensor([ 142,  518,  612, 1044, 3553, 7208]),
#  200: tensor([2405, 3621]),
#  201: tensor([ 120,  918, 4157]),
#  203: tensor(1492),
#  204: tensor(4379),
#  205: tensor([ 312,  326, 2020, 3753, 6679]),
#  206: tensor([   98,   454,  1470,  6118,  9230, 13907]),
#  208: tensor([ 264,  280,  355, 1264, 1738]),
#  210: tensor([ 257, 1764]),
#  211: tensor([1786, 4733]),
#  213: tensor(2708),
#  215: tensor([  231,   303, 18549]),
#  216: tensor([2194, 8066]),
#  218: tensor([ 861, 1178, 4564, 7393]),
#  219: tensor([ 483,  631, 2150]),
#  220: tensor([ 172, 3009]),
#  221: tensor([ 533,  648, 1067, 1191]),
#  222: tensor(6943),
#  223: tensor([ 107,  385,  984, 3540]),
#  226: tensor(8362),
#  227: tensor(238),
#  228: tensor([ 294, 1006]),
#  229: tensor([1349, 1667, 1993, 2885]),
#  233: tensor(6930),
#  234: tensor([5666, 7433]),
#  236: tensor([ 171, 4632, 8910]),
#  237: tensor(1475),
#  238: tensor([197, 217, 222, 224, 227, 232, 233, 235, 252, 255, 296]),
#  240: tensor(8780),
#  242: tensor(10124),
#  243: tensor([1402, 1485, 1691]),
#  246: tensor([798, 907]),
#  247: tensor(4717),
#  249: tensor(780),
#  250: tensor(1469),
#  251: tensor(1237),
#  256: tensor([2195, 2377, 7512]),
#  257: tensor([ 210,  225,  242,  243,  245,  254,  259,  260,  279,  314,  342,  367,
#          378,  400,  435,  463,  476,  568,  606,  643,  646,  682,  699,  717,
#          739,  761,  793,  805,  858,  908,  947,  958,  988,  996, 1025, 1048,
#         1062, 1097, 1117, 1145, 1158, 1162, 1180, 1183, 1201, 1211, 1229, 1230,
#         1258, 1288, 1315, 1546, 1697, 1704]),
#  258: tensor([ 992, 1228]),
#  260: tensor(8118),
#  261: tensor(2276),
#  262: tensor([ 765,  845, 1429]),
#  263: tensor([4652, 9686]),
#  266: tensor([2656, 2844, 5314]),
#  268: tensor(4305),
#  269: tensor(51),
#  270: tensor([ 124,  839, 2038, 3239, 5569]),
#  271: tensor([ 3075, 12648]),
#  272: tensor([ 437, 1454]),
#  273: tensor([2126, 8109]),
#  280: tensor([ 208, 1502, 2870]),
#  281: tensor([  35,   43,   81,  240, 2115]),
#  282: tensor([1194, 1522]),
#  283: tensor([ 445, 4602, 6785]),
#  284: tensor([ 832, 8021]),
#  285: tensor([ 2733,  4940,  8532, 19386]),
#  286: tensor(11993),
#  288: tensor([ 703, 1303, 1717]),
#  289: tensor([  348,  2470,  3929,  5847, 11134]),
#  291: tensor([1113, 1153]),
#  292: tensor([2520, 6440]),
#  293: tensor([2686, 3450, 5072]),
#  294: tensor([190, 228]),
#  296: tensor(10814),
#  300: tensor([ 2565,  2975,  3479,  4347, 14187]),
#  301: tensor([1142, 2125, 4981, 8836]),
#  302: tensor(8255),
#  303: tensor([ 215,  726, 1253, 2096]),
#  304: tensor([ 464,  628, 3032, 3504, 8492, 8744]),
#  305: tensor([1521, 2555]),
#  306: tensor([ 1617,  3987,  7699,  8128, 18003]),
#  307: tensor([ 500, 3830]),
#  308: tensor([ 226,  542, 1463, 3324, 3877, 4136, 6602]),
#  309: tensor(2064),
#  310: tensor([ 1239,  2229, 11996]),
#  311: tensor(3431),
#  312: tensor([ 9904, 11257]),
#  313: tensor([  119,   432,   816,   824,   932,  1486,  2543,  2599,  3156,  3849,
#          6290,  7469,  8044,  9762, 18444]),
#  315: tensor([3008, 4078]),
#  317: tensor([1106, 1195, 2533]),
#  318: tensor([ 104,  110, 2173, 2296, 3184]),
#  319: tensor([ 176, 2688]),
#  320: tensor([  339, 11189, 14771]),
#  322: tensor(706),
#  323: tensor(6523),
#  325: tensor(994),
#  326: tensor([  205, 16180]),
#  327: tensor([ 860, 1045, 1157, 2920]),
#  328: tensor([1549, 2183]),
#  329: tensor(2401),
#  330: tensor(441),
#  332: tensor([ 477, 8230]),
#  333: tensor([1590, 1637]),
#  334: tensor([ 246, 2821, 2972]),
#  335: tensor([5171, 8609]),
#  336: tensor([1442, 5077]),
#  337: tensor(16370),
#  339: tensor(3279),
#  340: tensor([  56,  691,  942, 6696]),
#  344: tensor([ 901, 1940, 2101, 3001]),
#  345: tensor(6385),
#  348: tensor([ 289, 4951]),
#  350: tensor(15967),
#  351: tensor(4691),
#  352: tensor(5192),
#  354: tensor([2234, 4397]),
#  355: tensor([2094, 2637, 3221, 3628, 7775, 9841]),
#  357: tensor([  169,   576,   997,  7663,  9830, 10876]),
#  358: tensor([ 465, 2845]),
#  359: tensor(2783),
#  360: tensor([ 539,  737, 1340]),
#  361: tensor(914),
#  362: tensor([ 1930,  1974, 12367]),
#  363: tensor([  439,  4742,  7174, 19888]),
#  364: tensor(2024),
#  365: tensor([10043, 12348, 12563]),
#  366: tensor(44),
#  368: tensor([ 186,  607, 1155, 4453]),
#  371: tensor([ 783, 3087, 6272, 9403]),
#  372: tensor([2422, 2867]),
#  373: tensor([   41,   434,   912,  2008,  2554,  3642,  3878,  4290,  5689,  8556,
#         10135, 15994]),
#  374: tensor([  140,   390,   875,  3204, 10805]),
#  376: tensor(2893),
#  377: tensor(4241),
#  378: tensor([1412, 1413, 1552, 1628, 1822, 1869, 6577]),
#  379: tensor([1575, 1756]),
#  380: tensor(7834),
#  381: tensor([1177, 3571, 9024]),
#  382: tensor([ 933, 1051, 1857]),
#  383: tensor(569),
#  384: tensor(503),
#  385: tensor([ 223, 3073, 4723]),
#  386: tensor([ 4369, 19347]),
#  387: tensor([  157,  2620,  2696, 10064, 12665, 14278]),
#  388: tensor([ 145,  806, 2167]),
#  389: tensor(572),
#  393: tensor([1493, 2219]),
#  394: tensor([  364,   634,  1050,  5353,  9467, 11022, 18391]),
#  395: tensor([  939,  1024,  3396,  4823, 10036]),
#  396: tensor([ 115,  309,  346, 1205, 1373, 6621]),
#  397: tensor([ 4975, 10477, 11078]),
#  398: tensor(898),
#  401: tensor([1076, 2394, 2427]),
#  402: tensor([ 3590,  9517, 13483]),
#  404: tensor([ 174, 2416, 9902]),
#  405: tensor([2486, 6683]),
#  406: tensor([ 1524,  1580,  2425, 10813]),
#  407: tensor([   52,    62,    71,    92,   213,   299,   399, 15221]),
#  408: tensor(8209),
#  409: tensor(168),
#  410: tensor(1439),
#  411: tensor([  85,  165,  723, 4953, 5112]),
#  412: tensor([ 653, 2812]),
#  413: tensor(6902),
#  414: tensor([ 652, 1266]),
#  416: tensor([  655,  1056,  1556,  1569,  5120, 10933, 18205]),
#  418: tensor(5499),
#  419: tensor([  25,   47, 1231]),
#  422: tensor([  249,   324,   398,   440,   529,   581,   582,  1110,  1118,  1375,
#          3240,  3331,  3537,  3582, 13652, 14695, 14949, 19505]),
#  423: tensor([3805, 6456]),
#  424: tensor([ 965, 1792, 3353, 6024]),
#  425: tensor(185),
#  428: tensor(69),
#  429: tensor([  475,  2801, 14840]),
#  430: tensor([ 161, 4612]),
#  431: tensor([ 692,  734, 1091, 5032]),
#  432: tensor(14322),
#  433: tensor([ 9142, 13533]),
#  436: tensor(2522),
#  437: tensor(13374),
#  438: tensor(636),
#  439: tensor([  363,  1976,  2015,  3186, 10177]),
#  442: tensor([ 179,  651, 3627, 4094]),
#  443: tensor([ 928, 3818, 4941]),
#  444: tensor([  990,  5779,  6039,  6800,  7006, 13479]),
#  445: tensor([ 283, 2741]),
#  446: tensor([1760, 8041]),
#  447: tensor([ 1468,  3857,  6957, 11312, 14927, 15800, 16530, 17231, 20068]),
#  448: tensor([ 6672, 16259]),
#  450: tensor([ 167,  460,  508,  645,  649,  710,  794, 1335]),
#  451: tensor(8772),
#  452: tensor(909),
#  453: tensor([ 144, 2699, 4724, 5861]),
#  455: tensor([ 1604, 15106]),
#  457: tensor([2556, 2796, 7255]),
#  458: tensor([1775, 2326, 2625, 6289]),
#  459: tensor([ 995, 4872]),
#  460: tensor([2999, 3231, 4002]),
#  461: tensor(489),
#  462: tensor([ 544, 2803]),
#  465: tensor([1455, 2956, 3551, 4616, 6740]),
#  467: tensor(4129),
#  469: tensor(949),
#  470: tensor([2283, 4890]),
#  474: tensor([  605,   650,   696,  3111,  5317, 11628]),
#  475: tensor([178, 429]),
#  476: tensor([1719, 1958, 1959]),
#  477: tensor([  332,  1064,  3603, 10357, 11470]),
#  478: tensor(843),
#  479: tensor([1702, 7486]),
#  480: tensor([ 2939, 10790, 16963]),
#  481: tensor(619),
#  483: tensor(11042),
#  484: tensor([  61, 6526]),
#  486: tensor([ 152, 2364]),
#  487: tensor([1523, 3631, 6252, 6298]),
#  488: tensor([1341, 2516, 4069]),
#  490: tensor([ 118,  287,  801, 1763]),
#  491: tensor([ 632,  937, 1458, 1703, 6119]),
#  492: tensor(13559),
#  493: tensor(306),
#  496: tensor([ 361,  565, 1448]),
#  498: tensor([2627, 4699, 5660, 7649]),
#  500: tensor([ 307,  626, 5549]),
#  501: tensor([2639, 3078]),
#  503: tensor([  384,   408,  1126,  1807,  5439, 17727]),
#  504: tensor(2343),
#  505: tensor([ 1565,  1692,  4179,  6157,  7267, 16314]),
#  506: tensor(6063),
#  508: tensor(450),
#  509: tensor([  96, 6111]),
#  510: tensor([ 4801, 13074]),
#  511: tensor([1245, 7920]),
#  512: tensor([2171, 3529]),
#  513: tensor(338),
#  514: tensor([  86,  108,  658, 5434]),
#  515: tensor(10817),
#  517: tensor(6162),
#  519: tensor(11348),
#  520: tensor([ 2514, 10256]),
#  523: tensor(2454),
#  524: tensor([ 131, 7508]),
#  525: tensor(1434),
#  526: tensor([ 877, 2042]),
#  527: tensor([ 4795,  6671, 12495]),
#  528: tensor([ 1582,  3138,  7541, 11878]),
#  530: tensor(6069),
#  531: tensor(1220),
#  532: tensor([1466, 7036]),
#  533: tensor([ 221, 6369]),
#  537: tensor([ 6874, 15195]),
#  538: tensor([ 938, 1316, 1487, 2109, 2381, 4304]),
#  540: tensor(2284),
#  541: tensor([1757, 2421]),
#  542: tensor([ 9349, 15140]),
#  543: tensor(6697),
#  544: tensor(462),
#  545: tensor([2203, 2339]),
#  547: tensor([4748, 4764]),
#  548: tensor([1058, 2233]),
#  549: tensor([ 616, 2165]),
#  550: tensor([2001, 6469]),
#  551: tensor([  829,   993,  2347,  3275,  5820,  6081, 17245]),
#  552: tensor([2223, 6787, 7901]),
#  553: tensor([2888, 9058]),
#  554: tensor([1877, 6728]),
#  555: tensor([11178, 15601]),
#  557: tensor(7067),
#  560: tensor([ 5161, 18861]),
#  561: tensor([ 4192,  5755, 10859]),
#  562: tensor([ 3487, 16131]),
#  563: tensor([ 2241,  6539, 14830]),
#  564: tensor([173, 815]),
#  567: tensor([  639,  1894,  4944,  9397, 12614, 14951]),
#  569: tensor([ 383,  826, 3071, 8186]),
#  570: tensor([ 204, 1500]),
#  572: tensor(20209),
#  573: tensor([3312, 7972]),
#  574: tensor([ 3173,  4488,  8236, 19915]),
#  576: tensor([ 357,  790, 7921]),
#  577: tensor([ 599, 1074, 1257, 2626, 7073]),
#  578: tensor([1460, 2651]),
#  583: tensor(6257),
#  584: tensor([5216, 6815]),
#  585: tensor([ 159, 3674, 6860]),
#  586: tensor([   60,  6399, 10744]),
#  587: tensor([1202, 1945, 2534, 7280]),
#  591: tensor(825),
#  594: tensor(4269),
#  595: tensor(22),
#  596: tensor([10529, 21039]),
#  597: tensor([3196, 9687]),
#  598: tensor(9000),
#  601: tensor([ 3080, 17723, 18354]),
#  602: tensor([2135, 2496]),
#  603: tensor([2260, 2833, 9193]),
#  604: tensor([ 1167,  2606,  3865, 10938]),
#  605: tensor([ 474, 8065]),
#  606: tensor([1601, 1679, 1721]),
#  607: tensor([  368,  2679, 12423]),
#  608: tensor(3264),
#  609: tensor([ 1713,  5035, 11497]),
#  610: tensor([  887,  3625, 12753, 15696, 20952]),
#  611: tensor([ 331,  777, 1426, 2129, 9844]),
#  612: tensor(199),
#  613: tensor(13009),
#  614: tensor([2855, 6258, 7765]),
#  615: tensor([ 1173,  4191, 16819]),
#  617: tensor(2865),
#  618: tensor([  746,  3199, 14650]),
#  621: tensor([2477, 2835]),
#  622: tensor(1204),
#  623: tensor(15000),
#  624: tensor([ 609,  870, 3119]),
#  626: tensor(7477),
#  627: tensor([  271,   352,   395,   516,   697,   833,   900,  3887,  5490,  5706,
#          9950, 10387, 12740]),
#  628: tensor([  304,  5442,  6592, 19406]),
#  629: tensor([  130,   139,   209,  1049, 16921]),
#  631: tensor([ 219, 1430, 9062]),
#  632: tensor(10326),
#  635: tensor([1626, 2615, 2770]),
#  636: tensor(438),
#  637: tensor([  871, 10171]),
#  638: tensor(13884),
#  639: tensor(9309),
#  640: tensor([  731,  1190,  1224,  2690,  3288, 16272]),
#  641: tensor([ 675, 1249]),
#  642: tensor([ 1007, 12499, 17237]),
#  643: tensor([1712, 1761, 2080]),
#  644: tensor([  166,   919,  1675,  8865, 13487]),
#  645: tensor([1175, 1514]),
#  647: tensor([5507, 7708]),
#  649: tensor(2600),
#  651: tensor(15576),
#  652: tensor([ 414, 2912]),
#  653: tensor([ 412, 2026, 7799]),
#  654: tensor([  796,  1543,  5253, 11072]),
#  656: tensor([ 930, 4622, 4993, 5447, 7583]),
#  657: tensor([ 4670, 16119]),
#  658: tensor(21158),
#  659: tensor([1085, 1694, 1920, 9504]),
#  661: tensor([  187,  4921,  6312, 13808]),
#  662: tensor([ 8480, 17773]),
#  663: tensor([  189,   277,   936,  1295,  1970,  2127,  2446,  3483, 12400]),
#  664: tensor([2439, 2824, 3202, 3681]),
#  665: tensor([ 151, 2169, 2317, 5500]),
#  666: tensor([ 1079, 17111]),
#  667: tensor([2902, 3712, 8167]),
#  668: tensor([ 3109,  3296,  7773, 11364]),
#  669: tensor(8926),
#  670: tensor([ 865, 1838, 3339]),
#  671: tensor(5116),
#  673: tensor(9869),
#  674: tensor([ 820, 1346, 3325, 3696, 7065]),
#  675: tensor(9649),
#  677: tensor(2936),
#  679: tensor([  329,  1147,  4893,  7881, 10438]),
#  680: tensor([ 3435,  5168, 12230]),
#  681: tensor([  770, 12885, 13804]),
#  683: tensor(1286),
#  684: tensor([3622, 3843, 8516]),
#  685: tensor([ 590, 1041, 1888, 5221, 6429, 9728]),
#  686: tensor([ 1042,  5043,  7229, 16900]),
#  687: tensor([  456,  2258,  3652,  8752, 12133]),
#  689: tensor(18055),
#  690: tensor([ 7824, 10292]),
#  693: tensor([ 1008,  1744,  2810, 18635]),
#  694: tensor(4709),
#  695: tensor([1420, 2302, 2334, 7319, 7456]),
#  702: tensor(1409),
#  703: tensor([  288, 10400]),
#  704: tensor(1855),
#  705: tensor(1968),
#  706: tensor([  322,  1901,  2235,  9584, 10166]),
#  707: tensor([1810, 2538, 4745, 6006]),
#  708: tensor(5152),
#  709: tensor([2772, 4661, 4909]),
#  710: tensor([1283, 2357]),
#  712: tensor(4100),
#  713: tensor(1119),
#  714: tensor([  452,   497,   941,   998,  1200,  1755,  2092,  3525,  3798,  4030,
#          4332,  5457, 14835, 18144]),
#  715: tensor([  720,  3679, 11190]),
#  716: tensor(752),
#  718: tensor([ 6285, 15296]),
#  719: tensor([  883,  1203,  1273,  4778,  7804, 10406]),
#  721: tensor([ 817, 3336, 4037, 9715]),
#  722: tensor(9023),
#  723: tensor(1267),
#  725: tensor([ 7731, 20430]),
#  726: tensor([ 160, 8692]),
#  727: tensor(13265),
#  728: tensor([2063, 2735, 7130]),
#  729: tensor([  876,  1950,  5751, 12705]),
#  730: tensor(2415),
#  731: tensor([ 3792, 18358]),
#  733: tensor(461),
#  734: tensor([ 431, 1865, 9535]),
#  735: tensor([ 6446,  6477,  9964, 13406]),
#  736: tensor([ 834, 1559, 3002, 3018]),
#  738: tensor([ 3972, 18353]),
#  739: tensor([1233, 1505]),
#  740: tensor(18342),
#  741: tensor([ 4034,  7914, 16961]),
#  742: tensor(19343),
#  743: tensor(9402),
#  744: tensor([1358, 1390, 3114, 3215, 7917]),
#  745: tensor([ 5651,  9781, 12371, 13953]),
#  746: tensor([ 618, 1885, 2654]),
#  747: tensor([ 2211, 12183]),
#  748: tensor([  480, 14641]),
#  750: tensor([ 571, 5464, 8388]),
#  752: tensor([ 716, 2379]),
#  753: tensor(9565),
#  755: tensor(625),
#  756: tensor(1597),
#  757: tensor(17456),
#  758: tensor([1380, 2130]),
#  759: tensor([ 5040, 10306]),
#  760: tensor(6947),
#  763: tensor([1571, 3021]),
#  764: tensor([2540, 5341, 8979]),
#  765: tensor([ 262, 4467, 6704]),
#  766: tensor([ 515, 7413]),
#  768: tensor([  881,  1406,  1723, 19307]),
#  769: tensor(1831),
#  771: tensor([ 1386, 18312]),
#  773: tensor([ 3208, 12714]),
#  775: tensor(3831),
#  776: tensor([ 4110, 14855]),
#  777: tensor([ 133,  278, 5786, 7982]),
#  781: tensor([  766, 12917]),
#  782: tensor([ 819, 1279]),
#  786: tensor([ 1246,  1431,  1935,  2261,  9747, 13584, 20512]),
#  787: tensor([12187, 17540]),
#  789: tensor(1854),
#  790: tensor(18943),
#  798: tensor(14796),
#  799: tensor([ 337,  754, 2376, 7545]),
#  800: tensor(1307),
#  801: tensor([ 496, 1573]),
#  804: tensor([ 4032,  4708,  5948,  6418, 15230]),
#  808: tensor([3094, 5239]),
#  809: tensor(1247),
#  810: tensor([ 1614,  8159, 13245, 20582]),
#  811: tensor([ 1144,  2657,  3692,  3754,  4490,  4726,  6482,  8963,  9742, 12603,
#         12945, 15126, 16684, 17092, 17436, 19560]),
#  812: tensor([2087, 6223]),
#  814: tensor([  872, 18477]),
#  815: tensor([564, 570]),
#  817: tensor(18922),
#  818: tensor([1804, 1902, 3319, 9203]),
#  819: tensor([ 782, 2588, 3969]),
#  821: tensor(1530),
#  822: tensor([3731, 4536]),
#  825: tensor([  591, 12882, 21146]),
#  826: tensor(13037),
#  827: tensor([1962, 2535, 8984]),
#  829: tensor([3015, 3835]),
#  831: tensor([ 669, 1134, 1276, 3572, 6727]),
#  832: tensor([16117, 17633]),
#  833: tensor(4752),
#  834: tensor([  604,   736,   786,  4438,  4732,  7238, 12915, 14507]),
#  835: tensor([1116, 7021]),
#  836: tensor([2426, 3358]),
#  837: tensor(957),
#  838: tensor([102, 369]),
#  839: tensor(6383),
#  840: tensor([ 418, 1095, 1509, 1813, 1839, 4222, 5481]),
#  841: tensor([3439, 6839]),
#  842: tensor([ 1270,  5643,  6795, 10520]),
#  843: tensor(478),
#  844: tensor(4501),
#  845: tensor(2630),
#  846: tensor(11298),
#  848: tensor([4063, 8059]),
#  850: tensor([ 3695,  4239,  5254, 14556]),
#  852: tensor(1028),
#  853: tensor([ 713, 1098]),
#  854: tensor([   91,   781,  2216,  2218,  6237, 15845]),
#  855: tensor(5296),
#  856: tensor([1021, 2156, 3516]),
#  859: tensor(6706),
#  861: tensor([ 218, 1227, 4721, 4936, 7258, 9845]),
#  862: tensor([1023, 5229, 7288]),
#  863: tensor(1405),
#  864: tensor([ 2152,  4358, 10178, 14505]),
#  865: tensor([ 1099,  1733,  4420, 11087, 20325]),
#  866: tensor(9707),
#  867: tensor(1531),
#  868: tensor([1318, 1680, 4185]),
#  869: tensor([ 1529,  6832, 13984]),
#  870: tensor([  624,  1399, 20146]),
#  871: tensor([ 637, 9654]),
#  872: tensor([  814, 13200]),
#  874: tensor([ 321, 6907]),
#  875: tensor([ 5098, 11507, 19357, 20000]),
#  876: tensor([ 729, 1994, 5183]),
#  877: tensor(530),
#  878: tensor([1870, 7002]),
#  879: tensor([ 5303,  5606, 13372]),
#  880: tensor(8534),
#  881: tensor([  768, 20845]),
#  883: tensor([ 3556,  3685, 11959]),
#  885: tensor([1083, 1488]),
#  886: tensor(3329),
#  887: tensor(3306),
#  890: tensor([ 954, 5372, 5837]),
#  891: tensor([5010, 9301]),
#  892: tensor([1635, 4613]),
#  894: tensor([ 3081,  3838, 12283, 13481]),
#  896: tensor(5029),
#  897: tensor(17238),
#  900: tensor(7448),
#  901: tensor(15453),
#  902: tensor(137),
#  903: tensor([1619, 6465]),
#  905: tensor([2431, 6434]),
#  906: tensor(20971),
#  909: tensor(863),
#  910: tensor(101),
#  911: tensor([ 4460,  6311, 20206]),
#  915: tensor(1621),
#  916: tensor([ 2396,  3482,  4070,  4277, 14736, 17052, 17673, 17912]),
#  918: tensor([ 830, 6752]),
#  921: tensor([  396,   442,  1323, 10596, 21015]),
#  925: tensor([ 5818, 11554, 13781]),
#  927: tensor([ 1512, 17137, 19691]),
#  928: tensor(5836),
#  930: tensor(3648),
#  933: tensor(6093),
#  934: tensor([1642, 1896, 4080, 7598, 8895]),
#  935: tensor([1359, 4557]),
#  936: tensor(15214),
#  940: tensor([1356, 4857, 8882]),
#  943: tensor(1424),
#  944: tensor(13355),
#  945: tensor(7976),
#  946: tensor(7591),
#  947: tensor(1790),
#  948: tensor([  265,  1689,  2788,  8767, 18735]),
#  949: tensor(18440),
#  950: tensor([1928, 2358, 4928]),
#  952: tensor(711),
#  953: tensor([1971, 2004, 2948, 3040, 4106, 4343]),
#  956: tensor(5747),
#  957: tensor([  837,  3804, 13191]),
#  959: tensor([3372, 4487, 8056]),
#  960: tensor([ 5541,  9428, 20303]),
#  965: tensor(18734),
#  966: tensor([1105, 3606, 4678]),
#  967: tensor([ 3701, 17038]),
#  968: tensor([3942, 5872, 7727]),
#  970: tensor([1107, 4062, 8262]),
#  971: tensor(7361),
#  972: tensor([  109, 13198]),
#  973: tensor([ 927, 3497, 7290]),
#  974: tensor([ 4319,  5693, 12256, 13527]),
#  976: tensor([ 1446,  2333,  5599, 13613]),
#  978: tensor([ 2512,  3284, 13538]),
#  981: tensor(4784),
#  982: tensor([ 5548, 20245]),
#  983: tensor([1859, 6393]),
#  984: tensor(12704),
#  989: tensor(5185),
#  990: tensor([ 349,  444, 1089, 3494]),
#  991: tensor(4664),
#  992: tensor([  258,  1929,  2414,  6221,  7672,  9056, 10201, 20503]),
#  993: tensor([ 732, 1811, 2176, 7827, 9917]),
#  994: tensor([  325,  5365, 14431]),
#  995: tensor([  459, 13077]),
#  998: tensor([  714,  1494, 15131]),
#  999: tensor([  608,   623,  1396,  3197,  5020, 10828]),
#  1001: tensor(3841),
#  1002: tensor([  470,  1206,  4178,  5110,  5941,  7348, 11439]),
#  1003: tensor([ 4900,  6775, 19145]),
#  1005: tensor([2631, 4620]),
#  1007: tensor([  295,   642,  3755, 10363]),
#  1008: tensor([ 693, 5407, 7129]),
#  1009: tensor([ 3323,  6735,  8732, 11666, 12584]),
#  1010: tensor([ 2232,  5048, 10386, 18657]),
#  1011: tensor(3154),
#  1012: tensor([2474, 3407, 4552, 4783]),
#  1014: tensor(5013),
#  1015: tensor([ 3822, 16194, 17207, 20728]),
#  1016: tensor([ 2497,  3750,  5793, 12784]),
#  1017: tensor(1784),
#  1018: tensor([ 1036, 19974]),
#  1019: tensor([3217, 3542]),
#  1020: tensor([ 1395,  2341,  3820, 11859]),
#  1021: tensor([  856, 16667]),
#  1022: tensor(11030),
#  1023: tensor([7296, 8408]),
#  1024: tensor([ 4845, 16368, 18073]),
#  1025: tensor(2348),
#  1026: tensor(16943),
#  1027: tensor([  132,   471,  3918, 12602]),
#  1028: tensor([  852,  4859, 12675]),
#  1029: tensor(12483),
#  1030: tensor([3979, 5804]),
#  1032: tensor([ 3911, 14422]),
#  1036: tensor(2942),
#  1037: tensor(3866),
#  1038: tensor([ 1033,  2306,  3137, 13554]),
#  1040: tensor(12510),
#  1043: tensor([4797, 5832]),
#  1044: tensor(20519),
#  1046: tensor(5976),
#  1047: tensor(18298),
#  1050: tensor([  394,  3620, 14400]),
#  1051: tensor(13415),
#  1052: tensor([ 2693,  9811, 20228]),
#  1053: tensor([ 1077, 12752]),
#  1054: tensor([1593, 2142, 2973, 3871, 5559, 9453]),
#  1055: tensor(7685),
#  1059: tensor([3647, 5337]),
#  1060: tensor([ 4270,  5980,  8164, 11468, 11469, 11924, 16568]),
#  1061: tensor([ 46, 924]),
#  1064: tensor([3230, 6745]),
#  1066: tensor([ 3155, 15076]),
#  1069: tensor([2291, 5535]),
#  1070: tensor([2181, 2413, 8306]),
#  1071: tensor([2110, 5059]),
#  1072: tensor([ 1925,  2700,  8990, 17332]),
#  1073: tensor([ 7364, 20350]),
#  1074: tensor([1525, 1550]),
#  1075: tensor(588),
#  1076: tensor([ 4832, 17178]),
#  1077: tensor([ 718, 1053, 4079, 4261, 9885]),
#  1078: tensor(904),
#  1079: tensor([ 666, 2166, 2292, 3989, 6624, 8992]),
#  1080: tensor([1216, 6294]),
#  1081: tensor(3066),
#  1082: tensor([5947, 7112]),
#  1083: tensor([ 742,  885, 1706]),
#  1084: tensor([ 4232,  5200, 18780, 21358]),
#  1085: tensor([ 3886,  6883, 14231]),
#  1086: tensor([ 1387, 10923]),
#  1087: tensor([ 5986,  6116, 13634, 16214]),
#  1088: tensor([ 3283, 21401]),
#  1089: tensor([   57, 12979]),
#  1090: tensor([ 4518, 13235]),
#  1092: tensor([ 6588, 13666, 14282]),
#  1093: tensor([1014, 8700]),
#  1094: tensor(12290),
#  1095: tensor([ 485, 1752]),
#  1096: tensor([1393, 1907, 9897]),
#  1098: tensor([  853,  2578,  2662,  6504, 11807, 15364]),
#  1099: tensor([  543, 10071]),
#  1102: tensor(11170),
#  1103: tensor([ 596, 1547, 2537]),
#  1105: tensor([ 1718,  4371, 13519]),
#  1106: tensor([ 317, 4729, 4813]),
#  1108: tensor([1868, 1972, 5558]),
#  1109: tensor([ 986, 4072, 6520]),
#  1110: tensor(920),
#  1114: tensor([  195, 11432, 12381]),
#  1115: tensor(724),
#  1116: tensor([  835, 11027]),
#  1120: tensor([ 2528,  5468, 13833]),
#  1121: tensor(4506),
#  1123: tensor([ 4659, 18771]),
#  1124: tensor(11431),
#  1125: tensor([  323,  2712,  2969, 10943, 14360, 21408]),
#  1126: tensor([ 2206, 12769]),
#  1127: tensor([3844, 4865, 6556]),
#  1128: tensor([ 4601, 11602]),
#  1129: tensor(1820),
#  1130: tensor(6685),
#  1131: tensor([ 2113,  7474, 12049]),
#  1132: tensor([3951, 5449, 6738]),
#  1133: tensor([2974, 5128, 9750]),
#  1134: tensor([  831,  6653,  8472, 14003, 16052]),
#  1135: tensor([ 495, 1900, 4846, 5829, 9155]),
#  1136: tensor(17622),
#  1137: tensor([ 4604,  6343, 19410]),
#  1138: tensor([5578, 5723]),
#  1141: tensor([ 1727,  4514, 21306]),
#  1142: tensor([  301, 20925]),
#  1143: tensor([  184,  5052, 17649]),
#  1144: tensor([ 3299,  4138,  7324, 12721, 13041]),
#  1145: tensor(1946),
#  1150: tensor(2576),
#  1151: tensor([ 3107,  6571, 10650, 11620, 18207]),
#  1154: tensor([2727, 5410]),
#  1155: tensor(14454),
#  1156: tensor(3182),
#  1157: tensor([  327,  2989, 19566]),
#  1163: tensor(10801),
#  1164: tensor(882),
#  1165: tensor([  68, 3934, 4569]),
#  1166: tensor(4355),
#  1167: tensor([ 4111, 10531]),
#  1169: tensor([ 2023,  4739,  5646,  8179, 10609]),
#  1171: tensor(6755),
#  1172: tensor([ 8359, 10899, 16551]),
#  1173: tensor(13035),
#  1174: tensor(13574),
#  1175: tensor(5922),
#  1176: tensor([ 8267,  8530, 18967]),
#  1179: tensor([ 1499, 18054]),
#  1182: tensor([1587, 4679]),
#  1187: tensor([ 1751,  2926,  3416,  5232, 19972]),
#  1188: tensor([3038, 4383, 4647, 5019]),
#  1189: tensor(2739),
#  1190: tensor([ 1992, 15016]),
#  1192: tensor(1472),
#  1193: tensor(14979),
#  1194: tensor([ 282, 9523]),
#  1195: tensor(2612),
#  1196: tensor(17920),
#  1197: tensor(17212),
#  1198: tensor([2212, 7392]),
#  1199: tensor([ 5936, 13528]),
#  1200: tensor(1310),
#  1202: tensor([  587,  3108, 20257]),
#  1204: tensor([ 622, 8053]),
#  1206: tensor(7289),
#  1208: tensor([ 2006,  3085,  4915,  5742,  6363, 10784, 11115, 13832]),
#  1209: tensor([3462, 6942, 8368]),
#  1210: tensor(8112),
#  1213: tensor([ 2720, 13378]),
#  1214: tensor([ 9817, 17721]),
#  1217: tensor([1816, 5041, 5319, 6479]),
#  1221: tensor([5602, 9265]),
#  1222: tensor(19663),
#  1224: tensor([ 554,  640, 2910, 9835]),
#  1225: tensor([ 7745, 17220]),
#  1226: tensor([ 531, 3809, 4970]),
#  1228: tensor(87),
#  1231: tensor([ 100,  126,  419, 1988]),
#  1232: tensor([   78, 10450]),
#  1234: tensor([ 2373,  4486, 12694]),
#  1235: tensor(8351),
#  1236: tensor([ 690, 1057, 2121, 2670, 8847]),
#  1238: tensor([ 1215,  1244, 12440, 16639]),
#  1239: tensor([ 2387,  4866, 16857, 19161]),
#  1241: tensor([10533, 19173]),
#  1242: tensor([  630,   733,  1027,  4456,  6638,  8291, 11380]),
#  1243: tensor(11446),
#  1245: tensor([ 511, 6491]),
#  1246: tensor([ 2016,  3006,  3095,  3147,  3706,  6560,  8974,  9722,  9861, 10336,
#         10518, 13348, 17771, 21142]),
#  1247: tensor([ 809, 4254]),
#  1248: tensor([  955,  1862, 10877]),
#  1249: tensor([  641,  2572,  2945,  5366, 12436]),
#  1251: tensor(5504),
#  1252: tensor([4948, 5653]),
#  1253: tensor([ 9718, 14658]),
#  1254: tensor(3274),
#  1256: tensor(741),
#  1257: tensor([ 577, 3262, 3981, 7388]),
#  1261: tensor([ 1553,  9690, 12302]),
#  1263: tensor([ 6542,  7911,  8950, 15983]),
#  1269: tensor([  520,  2280,  4367, 15998, 20596]),
#  1270: tensor(14196),
#  1271: tensor([1192, 8657, 9873]),
#  1272: tensor([  154,  6370, 15223]),
#  1273: tensor([ 4855,  7033, 12123, 15348]),
#  1274: tensor(7297),
#  1275: tensor([3140, 9147]),
#  1276: tensor([2456, 8686]),
#  1278: tensor([3046, 4776]),
#  1279: tensor([ 6368,  9005, 11352, 12016]),
#  1281: tensor([2838, 2900, 3635, 4672, 4720, 5963]),
#  1282: tensor([1438, 9764]),
#  1284: tensor([ 5354, 13713]),
#  1286: tensor(683),
#  1289: tensor([ 3099,  4190, 11101, 12590]),
#  1290: tensor(4834),
#  1294: tensor([3225, 4352]),
#  1295: tensor([6484, 6952]),
#  1296: tensor([ 3659,  5843, 11043]),
#  1297: tensor([ 1517,  1783,  3014,  5799, 12586, 15767]),
#  1300: tensor([ 138, 2442, 7273]),
#  1301: tensor([ 5073,  8993, 13153]),
#  1302: tensor(11045),
#  1303: tensor(11792),
#  1304: tensor(17375),
#  1305: tensor([2243, 8879]),
#  1306: tensor([ 1772,  2346, 16656, 19624, 20020]),
#  1307: tensor(800),
#  1309: tensor([ 2351, 14140]),
#  1311: tensor([  83, 4227]),
#  1312: tensor([2756, 5435, 7256]),
#  1313: tensor([ 6969, 12799, 13498]),
#  1314: tensor([  180,   290,   423,   788,   803,   828,  2580,  2642,  3633,  3913,
#          4000,  4231,  5890,  6216,  8542, 13869]),
#  1316: tensor([  538,  3263,  4156, 19358]),
#  1317: tensor([ 1794,  2501,  2726,  4750, 10481, 11068]),
#  1318: tensor([ 2722,  2724,  8416,  8458, 10409]),
#  1320: tensor([ 2505, 20621]),
#  1322: tensor([ 2914,  8028, 18772]),
#  1323: tensor([  921,  1732,  2161,  7595,  8553, 12588]),
#  1324: tensor([ 2196,  7538, 19951]),
#  1325: tensor(177),
#  1326: tensor([ 2081,  2846,  6933, 12974, 13550]),
#  1327: tensor([ 1562,  2014,  7715, 11300]),
#  1329: tensor([ 1102,  4497, 16975]),
#  1331: tensor(7546),
#  1332: tensor([ 8598, 20046]),
#  1333: tensor([ 899, 2392, 5426, 5720]),
#  1334: tensor([1332, 2564, 3619]),
#  1335: tensor([2114, 3949, 7161]),
#  1336: tensor(8211),
#  1337: tensor([ 523, 5343]),
#  1338: tensor([ 4240,  4533,  4868, 15202]),
#  1339: tensor([ 1196,  5360,  5691,  8036, 13730]),
#  1341: tensor([ 488, 9538]),
#  1343: tensor([ 4044, 18940]),
#  1344: tensor(5515),
#  1345: tensor(9338),
#  1347: tensor([ 2591, 10878]),
#  1349: tensor([4391, 5105]),
#  1351: tensor([ 1172,  2604,  3229, 15818]),
#  1352: tensor([ 1770,  2553, 13176, 13318, 18869]),
#  1353: tensor(54),
#  1354: tensor([ 2566,  3241,  8662, 19693]),
#  1356: tensor([  719,  1372,  5418,  8707, 12720]),
#  1357: tensor(17181),
#  1358: tensor([ 7668, 13444]),
#  1359: tensor([  935,  3295,  5694,  6462,  6845,  7327,  8651,  9976, 12148, 21373]),
#  1360: tensor([2052, 6409]),
#  1361: tensor([2983, 3162, 6963, 8709]),
#  1366: tensor([ 1845,  5248, 20709]),
#  1367: tensor([3939, 9241]),
#  1368: tensor([3432, 7600]),
#  1369: tensor(14463),
#  1370: tensor([1939, 2728]),
#  1371: tensor([ 446, 3093]),
#  1372: tensor([2589, 9063]),
#  1373: tensor([2674, 3343]),
#  1374: tensor([3832, 7858, 9091]),
#  1376: tensor([1394, 2715, 4728]),
#  1377: tensor([2403, 7682]),
#  1378: tensor([ 7511, 16812, 21030]),
#  1379: tensor([  757,   859,  1664,  4769,  7277, 14028]),
#  1380: tensor([  758,  4346,  5711, 12424]),
#  1381: tensor([ 1241,  3047,  9639, 17042, 20271]),
#  1382: tensor([ 5495,  7667, 10705, 12802, 16993, 18728]),
#  1383: tensor([ 849, 1519, 2774, 5370, 7880]),
#  1384: tensor(2761),
#  1386: tensor([ 7989, 15914, 19009]),
#  1387: tensor([1086, 5807]),
#  1388: tensor(10550),
#  1389: tensor(8098),
#  1390: tensor([  744,  1146,  1911,  2214,  3688, 12808]),
#  1391: tensor([ 6981, 11123]),
#  1392: tensor(7529),
#  1395: tensor(10413),
#  1396: tensor([ 999, 1793, 1948, 2491, 2634]),
#  1397: tensor(2256),
#  1398: tensor([3557, 4159, 7385, 9021]),
#  1399: tensor(5433),
#  1400: tensor([ 7999,  8241, 10540]),
#  1401: tensor([3673, 5641]),
#  1403: tensor([2541, 7657]),
#  1404: tensor([ 4445, 13232]),
#  1406: tensor(11555),
#  1407: tensor([2420, 4201, 7707]),
#  1408: tensor([2162, 3786]),
#  1409: tensor([  702,  1826,  1984,  3811,  7869, 13911, 15579]),
#  1410: tensor(7418),
#  1411: tensor(316),
#  1414: tensor([2210, 4054, 6606]),
#  1415: tensor([ 1018,  1998,  3201,  7032,  8370, 11574]),
#  1416: tensor(16153),
#  1417: tensor([ 2455,  3859,  4476,  6021,  6525, 10689, 16540]),
#  1420: tensor([ 7425, 11062, 12715]),
#  1422: tensor(1583),
#  1423: tensor([ 3055,  4545,  7307,  8982,  9581, 11728, 16179]),
#  1424: tensor([ 943, 1612]),
#  1425: tensor(16622),
#  1426: tensor([1443, 6513]),
#  1427: tensor([  980,  2198,  4706, 11144]),
#  1429: tensor([ 4431, 18581]),
#  1432: tensor([2090, 2938]),
#  1433: tensor(13499),
#  1436: tensor([6372, 7807]),
#  1437: tensor([ 2025,  9684, 10562]),
#  1438: tensor([ 1282, 13165]),
#  1441: tensor(3936),
#  1442: tensor([ 336, 5463]),
#  1444: tensor([5537, 6249, 6475, 6604, 9472]),
#  1446: tensor(976),
#  1447: tensor([ 4033,  5375,  7061, 18270]),
#  1449: tensor(15660),
#  1450: tensor([ 7788, 10494]),
#  1452: tensor([13143, 15357]),
#  1456: tensor([ 2084, 21293]),
#  1457: tensor([ 5094,  5687, 11738, 13876, 13936, 14725, 14770, 15895, 20526]),
#  1458: tensor([ 491, 4382, 6102, 8003]),
#  1459: tensor(5280),
#  1460: tensor([4135, 8132, 8483]),
#  1463: tensor([ 1740, 10579, 12105]),
#  1464: tensor([2286, 6502]),
#  1466: tensor(532),
#  1467: tensor([ 3003, 12368]),
#  1469: tensor(250),
#  1470: tensor([ 206, 6120]),
#  1471: tensor(2645),
#  1474: tensor([ 6124,  7468,  7810,  7904,  8708, 21107]),
#  1475: tensor([  237, 19861]),
#  1477: tensor([ 3005,  4390,  5664, 12540]),
#  1478: tensor(5892),
#  1479: tensor([1754, 4465, 6744]),
#  1480: tensor([ 4101, 11514]),
#  1481: tensor(6723),
#  1484: tensor([ 3995,  8632, 11863]),
#  1486: tensor([  313, 13893]),
#  1489: tensor([ 2298, 11440, 13759]),
#  1490: tensor(3721),
#  1492: tensor(203),
#  1493: tensor([ 3568, 11984]),
#  1495: tensor([1847, 3423]),
#  1496: tensor(6421),
#  1497: tensor([ 3678,  4362,  5519, 16621]),
#  1498: tensor([2242, 5009, 5761, 9941]),
#  1499: tensor(5102),
#  1501: tensor(4599),
#  1503: tensor([ 1579,  6703, 16378]),
#  1504: tensor(17301),
#  1505: tensor(10629),
#  1506: tensor(7831),
#  1507: tensor(17195),
#  1508: tensor([1444, 7003, 9474]),
#  1509: tensor(1965),
#  1510: tensor([  318,  8927, 10445]),
#  1511: tensor([ 884, 2380, 3059, 7127]),
#  1513: tensor([2148, 4496]),
#  1515: tensor([ 4631, 11098]),
#  1516: tensor([ 1065,  2484,  5645, 14548]),
#  1517: tensor(9210),
#  1519: tensor([ 1383,  2395,  3039,  3454,  5159,  7252, 20040]),
#  1520: tensor([ 5918,  9548, 12708]),
#  1521: tensor([  305,   975,  1342,  1919,  2614,  4714,  5961, 19314]),
#  1523: tensor([  487,  7279,  8900, 16883]),
#  1527: tensor(3644),
#  1529: tensor(15565),
#  1530: tensor([  821,  7251, 20887]),
#  1532: tensor([4377, 5975]),
#  1534: tensor([  251,   562,  1908, 15176]),
#  1535: tensor(3378),
#  1536: tensor(20812),
#  1537: tensor([1339, 1886, 6085]),
#  1538: tensor([ 3656,  6416,  7220, 16923]),
#  1539: tensor(5765),
#  1540: tensor([3958, 4013, 5308]),
#  1541: tensor([ 7201, 18100]),
#  1543: tensor([6483, 8557]),
#  1544: tensor([1290, 1613, 6611, 9996]),
#  1548: tensor([ 2859,  5175, 10446, 10803]),
#  1549: tensor(5230),
#  1550: tensor(17373),
#  1551: tensor(1956),
#  1553: tensor(3491),
#  1556: tensor(5775),
#  1557: tensor(9306),
#  1558: tensor([ 8844, 14494]),
#  1559: tensor([ 3475,  4988,  6072,  7295, 12311, 13800]),
#  1561: tensor([ 3376,  4330,  7187,  8586,  8735,  8916, 10094]),
#  1566: tensor([ 1277,  3914,  4213,  6698,  7034, 10102, 14653, 18990]),
#  1567: tensor(6420),
#  1568: tensor([  175, 15484]),
#  1569: tensor([ 8643, 16087]),
#  1570: tensor([1285, 1647]),
#  1571: tensor([ 763, 6000]),
#  1572: tensor(4547),
#  1574: tensor([ 4210, 14929]),
#  1577: tensor([ 3065,  8789, 18687]),
#  1578: tensor([4268, 4553]),
#  1580: tensor([  406, 18607]),
#  1581: tensor([ 548, 6543, 9191]),
#  1582: tensor(528),
#  1583: tensor([ 330, 1422, 2072]),
#  1584: tensor(9606),
#  1585: tensor(9287),
#  1586: tensor([  685,  1169,  1461,  2061,  2905,  2909,  3077,  3498,  4161,  4204,
#          5930,  8305, 10489, 15160, 15847, 16170, 16827]),
#  1587: tensor([  745,   902,  1168,  1182,  1271,  2078,  2147,  2994,  3579,  4524,
#          5363,  6941,  7253,  9086,  9556, 13573, 17190]),
#  1588: tensor(15656),
#  1589: tensor([ 2331, 14372, 15899, 20913]),
#  1590: tensor(12345),
#  1592: tensor([ 2123, 20130]),
#  1594: tensor([ 2793, 13259]),
#  1596: tensor([6277, 7134]),
#  1597: tensor([  756,  4584,  8622, 14464]),
#  1599: tensor([ 2866, 17611]),
#  1602: tensor([ 5810, 13625]),
#  1603: tensor([ 4747, 13341]),
#  1604: tensor([ 3390,  6305, 16714]),
#  1606: tensor(6366),
#  1607: tensor([1328, 6541]),
#  1608: tensor([2740, 7117]),
#  1609: tensor([ 748, 1109, 1440, 2275]),
#  1611: tensor([ 1482,  4617,  6403,  8201,  8343, 11024]),
#  1613: tensor([ 8450, 16907]),
#  1614: tensor([  810,  1363, 12689]),
#  1615: tensor(6133),
#  1616: tensor([ 973, 1115, 1951, 3277]),
#  1619: tensor(14787),
#  1620: tensor([1643, 2175, 3165, 3530, 6919]),
#  1622: tensor([ 2790, 16929]),
#  1623: tensor([ 7430, 11948, 15568]),
#  1625: tensor([2682, 3785]),
#  1626: tensor([ 335, 3269]),
#  1627: tensor(3101),
#  1629: tensor(2526),
#  1631: tensor(18887),
#  1632: tensor([ 2278,  3484,  6282,  6616,  9550, 15561]),
#  1634: tensor([4858, 4979]),
#  1635: tensor([15740, 17366]),
#  1636: tensor(3488),
#  1637: tensor([  333, 16332, 19081]),
#  1639: tensor([ 2205, 13128]),
#  1640: tensor([4325, 5921]),
#  1641: tensor([2077, 4499, 4663]),
#  1642: tensor([ 2729,  8538, 15819, 16911]),
#  1643: tensor([  842,  1620, 11167, 19310]),
#  1646: tensor([ 320, 4133, 4169, 6426]),
#  1647: tensor([1570, 3463, 4570]),
#  1648: tensor(19958),
#  1649: tensor([4462, 6306]),
#  1650: tensor(14544),
#  1651: tensor([ 4022,  5582, 12050]),
#  1652: tensor(12047),
#  1653: tensor([ 5649,  6104,  8653, 20221]),
#  1654: tensor([ 7078, 14009, 18382]),
#  1656: tensor([  701,  3776,  4473, 16470]),
#  1657: tensor([6152, 8334]),
#  1658: tensor(5367),
#  1661: tensor([13950, 14773]),
#  1662: tensor([ 4839, 12833]),
#  1663: tensor([ 4298, 13410]),
#  1664: tensor(1379),
#  1665: tensor([ 4071, 11530]),
#  1666: tensor([ 3593,  4403,  9109,  9669, 14199, 19201]),
#  1668: tensor([ 3160,  3433, 10908, 18984]),
#  1669: tensor(4807),
#  1671: tensor([ 6677,  9820, 10444, 11776, 12434, 14805, 16499]),
#  1672: tensor([ 3879,  4417,  9240,  9508, 11886]),
#  1673: tensor(4255),
#  1674: tensor([ 6061,  9451, 10051]),
#  1675: tensor([ 5621, 17008, 17079]),
#  1676: tensor(1075),
#  1678: tensor([2503, 4051]),
#  1681: tensor(9856),
#  1682: tensor(3945),
#  1683: tensor(15288),
#  1684: tensor([1989, 3351]),
#  1685: tensor(21167),
#  1687: tensor([ 1778,  9190, 11471]),
#  1688: tensor([1837, 4999]),
#  1689: tensor([ 948, 3161]),
#  1690: tensor([ 2215,  4097,  7729, 12647]),
#  1692: tensor([  505,  5174, 15390, 16489]),
#  1693: tensor([ 2310,  3294,  4933,  5427,  7748,  8413, 14583]),
#  1696: tensor(6466),
#  1698: tensor(13011),
#  1699: tensor(2419),
#  1700: tensor(11536),
#  1701: tensor([ 1627,  1910,  4252,  4674,  9444, 14079, 14523, 19071]),
#  1702: tensor(11730),
#  1705: tensor([ 4903, 20795]),
#  1706: tensor([11052, 13740]),
#  1708: tensor(3505),
#  1709: tensor([1254, 2575]),
#  1710: tensor([ 455, 2093, 6591, 6956]),
#  1711: tensor(12812),
#  1713: tensor([ 6770,  8216, 15090, 17803, 20891]),
#  1714: tensor([1696, 3285, 9131]),
#  1715: tensor(13400),
#  1716: tensor([ 2707, 17859]),
#  1717: tensor(7647),
#  1718: tensor(18829),
#  1720: tensor([4411, 7146]),
#  1722: tensor(3684),
#  1725: tensor([3042, 4643, 5686, 8689, 9093]),
#  1726: tensor([4418, 4707]),
#  1727: tensor(8136),
#  1729: tensor(8397),
#  1730: tensor(4886),
#  1731: tensor(9628),
#  1732: tensor([4682, 5869]),
#  1737: tensor([ 1140,  1510,  2273,  3027,  4603,  5615,  6690, 12169, 13736, 14973,
#         17267]),
#  1738: tensor(9783),
#  1739: tensor([8771, 8848]),
#  1741: tensor([2619, 5763, 6448, 6581, 8030, 8628]),
#  1743: tensor([2390, 5219, 5533]),
#  1745: tensor([1111, 2970, 4983, 9893]),
#  1747: tensor(20392),
#  1749: tensor([ 3766,  4087, 17783]),
#  1750: tensor([ 2817,  6531, 12983]),
#  1751: tensor([ 1275,  2730, 16597]),
#  1752: tensor([ 1515,  2247,  8349, 11997, 17839]),
#  1756: tensor([  379, 19126]),
#  1757: tensor(541),
#  1759: tensor([ 688, 7158, 7750]),
#  1763: tensor([490, 575]),
#  1765: tensor(11759),
#  1766: tensor([ 4314,  4956,  9741, 10804]),
#  1767: tensor(3418),
#  1768: tensor([ 4322,  4850, 14712]),
#  1769: tensor(9224),
#  1770: tensor([1352, 6055]),
#  1771: tensor(17010),
#  1772: tensor([ 7346, 12397, 14124]),
#  1775: tensor(13207),
#  1777: tensor([ 2765,  3168,  5701,  5915, 11688, 12271, 14945, 15510]),
#  1778: tensor([ 1687, 12765]),
#  1780: tensor([1655, 3941, 7281]),
#  1781: tensor([ 2435,  4835, 12139]),
#  1782: tensor([ 4996, 14559]),
#  1783: tensor([10045, 12118, 19714]),
#  1784: tensor(1017),
#  1786: tensor(211),
#  1787: tensor([3287, 3973]),
#  1789: tensor([2683, 4758]),
#  1792: tensor([ 7169, 10220]),
#  1794: tensor([ 2502,  9794, 11703, 16235]),
#  1797: tensor(4542),
#  1798: tensor(1851),
#  1801: tensor([ 8720, 16442]),
#  1802: tensor(6765),
#  1803: tensor([ 3377,  3880,  4837, 13557, 13863, 15667]),
#  1805: tensor([1101, 5798, 6844]),
#  1806: tensor([ 2949,  8793, 11323, 16060]),
#  1811: tensor([1345, 1462, 6973]),
#  1812: tensor(14975),
#  1813: tensor([ 840, 8485]),
#  1815: tensor([3305, 9612]),
#  1816: tensor(16130),
#  1817: tensor([17609, 20878]),
#  1818: tensor([ 3169,  7228, 11473, 13257, 19549]),
#  1820: tensor(1129),
#  1821: tensor(3910),
#  1825: tensor([ 547, 7855]),
#  1829: tensor([  417,  6291, 16965]),
#  1831: tensor([  769, 19844]),
#  1833: tensor(20732),
#  1835: tensor([2515, 4230, 5712]),
#  1836: tensor(4840),
#  1837: tensor(1688),
#  1838: tensor([ 670, 2992, 9907]),
#  1839: tensor([ 9188, 14555]),
#  1840: tensor(2009),
#  1841: tensor([11889, 17813]),
#  1844: tensor([ 2002,  4209,  4284, 12775, 13310, 16450, 18129]),
#  1845: tensor([ 1366,  2408, 11086, 12550, 17937]),
#  1848: tensor(7320),
#  1849: tensor([ 4755, 16228]),
#  1851: tensor(1798),
#  1852: tensor(4226),
#  1854: tensor(17601),
#  1855: tensor([  704,  1425,  1788, 13862, 19810]),
#  1856: tensor([ 3909,  5079,  5420,  7712,  8955, 12074, 13983]),
#  1857: tensor([ 382, 3561]),
#  1858: tensor([6459, 6540]),
#  1859: tensor([ 3532,  4029, 19706]),
#  1860: tensor(18559),
#  1861: tensor(5218),
#  1862: tensor([1248, 2701, 3845, 9966]),
#  1863: tensor(141),
#  1864: tensor([18648, 21169]),
#  1865: tensor(10436),
#  1868: tensor([11011, 14144]),
#  1872: tensor([ 3655,  8685, 15396, 17344, 17726, 19274]),
#  1873: tensor([ 7955,  9647, 12593, 16449, 18577]),
#  1874: tensor([ 2397,  3473,  5974, 10149, 15539, 15820, 15970]),
#  1875: tensor(17206),
#  1876: tensor([12946, 13108]),
#  1877: tensor([ 7630, 11968, 17694]),
#  1878: tensor(9464),
#  1879: tensor([ 963, 2482]),
#  1880: tensor([3833, 6173]),
#  1881: tensor(5868),
#  1882: tensor(1447),
#  1883: tensor(16506),
#  1887: tensor([  162, 21400]),
#  1890: tensor([7431, 7544, 8808]),
#  1891: tensor(15677),
#  1892: tensor([12009, 12199, 15513]),
#  1893: tensor([ 7680,  8765, 18300]),
#  1895: tensor(15900),
#  1897: tensor([ 1681,  3125,  5545,  5992,  8746, 14261, 17711]),
#  1898: tensor(10578),
#  1899: tensor(3297),
#  1900: tensor(13825),
#  1904: tensor([3872, 5639, 9379, 9422]),
#  1905: tensor([5607, 6077, 8361]),
#  1907: tensor([ 1096,  4167, 12678, 15736]),
#  1908: tensor(1534),
#  1909: tensor([3959, 6022]),
#  1913: tensor([ 2393,  3216,  3506, 19369]),
#  1914: tensor([ 8229, 18883]),
#  1915: tensor([ 1997, 12886, 14764, 15902, 17688]),
#  1916: tensor([ 3307, 14509, 18475, 20980]),
#  1917: tensor([ 4594, 21016]),
#  1920: tensor([ 4229, 11861]),
#  1921: tensor([ 3132,  5780,  6769, 10626, 13512, 20349]),
#  1922: tensor([5544, 5885]),
#  1923: tensor(5642),
#  1925: tensor(19321),
#  1926: tensor([3437, 5521]),
#  1927: tensor([ 9786, 13636]),
#  1928: tensor([ 950, 1357]),
#  1929: tensor([ 525, 4463, 5199]),
#  1930: tensor([  362, 15721]),
#  1931: tensor([ 2852,  6991,  7219, 13097, 21273]),
#  1932: tensor([8920, 9561, 9769]),
#  1933: tensor([ 9854,  9858, 12439]),
#  1934: tensor(15110),
#  1936: tensor(6918),
#  1937: tensor([ 5243, 10541]),
#  1939: tensor([ 1255,  1370,  2932,  6175, 11198, 14364, 14759, 18942, 20214]),
#  1943: tensor([10779, 16818]),
#  1944: tensor([6038, 9619]),
#  1946: tensor([ 2667,  3481,  4427,  5425, 10232, 11162, 12388, 13357, 13492, 13809,
#         13864, 15004, 16488, 16953]),
#  1950: tensor(9533),
#  1951: tensor(8924),
#  1954: tensor([ 2780, 11119]),
#  1955: tensor([ 3495,  5911,  9959, 11465]),
#  1960: tensor([ 2231,  2428,  3176,  7669, 16299, 17848]),
#  1961: tensor([1938, 9129]),
#  1962: tensor([  827, 13897, 17539]),
#  1963: tensor(12875),
#  1965: tensor(15910),
#  1967: tensor(5302),
#  1968: tensor(705),
#  1972: tensor([2570, 3354, 5998, 9133, 9205]),
#  1973: tensor([ 3392, 11963]),
#  1975: tensor(4188),
#  1977: tensor([3751, 3775]),
#  1978: tensor(4294),
#  1979: tensor([ 2695,  4203,  4630,  9311, 11118, 16695, 18884]),
#  1980: tensor([  774,   983,  1600,  2463,  2993,  9657, 10098]),
#  1981: tensor([ 9546, 11149]),
#  1982: tensor(239),
#  1983: tensor([ 5668, 14553]),
#  1984: tensor(17911),
#  1985: tensor(3425),
#  1986: tensor([ 1480,  6855, 11526]),
#  1987: tensor([5474, 8969]),
#  1989: tensor([ 1684, 13339, 17391]),
#  1990: tensor([5284, 6871]),
#  1991: tensor([ 9048, 14183]),
#  1992: tensor(3905),
#  1993: tensor([  229,  3143,  3222,  3501,  4441,  4775,  5014,  6031, 11548, 11869,
#         12084, 20703]),
#  1997: tensor([ 1915, 10553, 12402, 13495, 17312]),
#  1998: tensor([ 1136,  1415,  4137, 11843]),
#  1999: tensor([ 1156,  7634,  7841, 10073]),
#  2000: tensor(3683),
#  2001: tensor([  550,  1964,  2451,  3699,  4326,  7247,  8253, 11845]),
#  2002: tensor([ 1844, 12972]),
#  2003: tensor([  556,  2222,  6137,  7786,  8781, 11272, 11482, 16217]),
#  2005: tensor([ 286, 2532, 9641]),
#  2006: tensor([ 493, 9751]),
#  2008: tensor([13790, 18337, 21322]),
#  2009: tensor(20439),
#  2010: tensor([ 4829, 15072, 16445, 17584, 19534]),
#  2011: tensor([ 2039,  7681,  9803, 10089, 14453, 21300]),
#  2012: tensor(192),
#  2013: tensor([ 2827,  6612, 16623]),
#  2014: tensor([ 1327,  2959, 19256, 21290]),
#  2016: tensor([ 3460, 10075, 11994, 15609]),
#  2017: tensor([ 6686,  8748, 12555, 15338, 20796, 20990]),
#  2018: tensor([ 4193,  8031, 10835, 11671, 13506]),
#  2019: tensor(15543),
#  2025: tensor([ 2499,  6900, 14680, 17927, 20781]),
#  2028: tensor(4407),
#  2029: tensor(14103),
#  2031: tensor([2423, 5503, 6145]),
#  2032: tensor(4961),
#  2034: tensor([ 9186, 12129, 12470, 12674]),
#  2035: tensor([ 6753, 10272]),
#  2036: tensor([ 1716,  3366,  6288,  9157, 16475]),
#  2037: tensor([ 2010,  6626, 11188, 12554, 14130, 15762]),
#  2039: tensor([ 2011, 11955]),
#  2040: tensor([17124, 17394]),
#  2041: tensor([ 3233, 11421, 15008, 17731]),
#  2042: tensor(526),
#  2044: tensor([ 1539,  4266,  5448,  5942,  5944,  6048,  7985, 14382, 14810]),
#  2046: tensor([2335, 4887, 8101]),
#  2048: tensor([  536,  1174,  1256,  1966,  6113,  7415,  8664, 11201]),
#  2049: tensor([  510, 11844]),
#  2050: tensor([ 2898,  5741, 20986]),
#  2051: tensor(2944),
#  2052: tensor([ 1251,  1360,  1527,  3276,  3548,  4854, 16456]),
#  2053: tensor([ 1875,  8138, 17430]),
#  2054: tensor([ 5456, 16127]),
#  2055: tensor([3524, 4871]),
#  2056: tensor([ 7389, 10844]),
#  2057: tensor([ 8856, 12006, 13596]),
#  2058: tensor([4885, 5954, 8957]),
#  2060: tensor([ 6182,  7889, 13386]),
#  2062: tensor([8867, 9571]),
#  2063: tensor([  728,  5016,  6609, 15765, 21405]),
#  2064: tensor(1039),
#  2065: tensor([10096, 11220, 11998, 16723, 17528, 20148]),
#  2066: tensor([ 4574,  6360,  6739,  9868,  9999, 14843]),
#  2067: tensor(12497),
#  2069: tensor(2828),
#  2072: tensor(19790),
#  2075: tensor(181),
#  2076: tensor([ 2963,  3122, 11385, 11823, 14965]),
#  2078: tensor([3249, 7049]),
#  2079: tensor([ 7645, 15980, 16699]),
#  2081: tensor(1326),
#  2082: tensor([ 6574, 14659, 19492]),
#  2083: tensor(2360),
#  2084: tensor([ 1456,  7148, 18095]),
#  2088: tensor([ 8008, 13619]),
#  2092: tensor([ 6373, 12089, 14204]),
#  2093: tensor([1710, 2340, 5086]),
#  2094: tensor([ 5326,  5736, 15056]),
#  2098: tensor([ 4730,  4896,  5912,  8252, 15187, 21083]),
#  2099: tensor([ 6816, 21068]),
#  2101: tensor([  344,  5404,  9247, 14291]),
#  2102: tensor([5122, 5652, 7928]),
# ...
#  19692: tensor(19599),
#  19695: tensor([ 5512, 17383]),
#  19697: tensor([10039, 19914]),
#  19722: tensor(10944),
#  19723: tensor(19459),
#  19726: tensor(18935),
#  19727: tensor(18718),
#  19730: tensor(16150),
#  19733: tensor(12637),
#  19736: tensor(12135),
#  19737: tensor(14483),
#  19738: tensor([12631, 20824]),
#  19740: tensor(14355),
#  19742: tensor(12597),
#  19745: tensor([ 6709, 20634]),
#  19747: tensor(20278),
#  19749: tensor(20376),
#  19751: tensor(10739),
#  19756: tensor(8369),
#  19757: tensor(7195),
#  19762: tensor(17899),
#  19763: tensor(14960),
#  19764: tensor(18842),
#  19765: tensor([16110, 19747]),
#  19779: tensor(16649),
#  19784: tensor([ 8447, 16099]),
#  19786: tensor([11401, 19008, 20880]),
#  19787: tensor([ 7071, 14097]),
#  19789: tensor(20533),
#  19792: tensor([13810, 14476]),
#  19793: tensor([12518, 18276, 21352]),
#  19796: tensor([17716, 18215]),
#  19797: tensor(5001),
#  19798: tensor([15026, 15180]),
#  19804: tensor([10874, 12981, 18831]),
#  19805: tensor(20876),
#  19806: tensor(16559),
#  19808: tensor(15463),
#  19811: tensor(6532),
#  19813: tensor(12710),
#  19817: tensor([14732, 17444, 21351]),
#  19822: tensor(17643),
#  19824: tensor(2344),
#  19829: tensor([17808, 18583]),
#  19834: tensor(13493),
#  19835: tensor([19760, 20467]),
#  19841: tensor([ 9670,  9685, 11466, 17558, 17619]),
#  19856: tensor(19072),
#  19864: tensor(16462),
#  19870: tensor([16397, 20939]),
#  19875: tensor([10683, 12111, 17947]),
#  19879: tensor(14853),
#  19881: tensor(10014),
#  19889: tensor(20359),
#  19897: tensor([ 9520, 21390]),
#  19899: tensor([ 7706, 10340]),
#  19900: tensor([17930, 20999]),
#  19905: tensor(20122),
#  19909: tensor(10620),
#  19916: tensor(19122),
#  19922: tensor(7328),
#  19923: tensor(16455),
#  19925: tensor(7974),
#  19926: tensor(12159),
#  19929: tensor(5849),
#  19930: tensor([17835, 18791]),
#  19933: tensor(14806),
#  19935: tensor(7045),
#  19942: tensor(7702),
#  19944: tensor(15670),
#  19947: tensor(13743),
#  19949: tensor(10270),
#  19950: tensor(20436),
#  19955: tensor([ 5970, 17096]),
#  19962: tensor([18139, 19983, 20087]),
#  19963: tensor([ 8119, 15178, 16973, 17473]),
#  19964: tensor([ 7866, 21019]),
#  19967: tensor(10458),
#  19976: tensor([15233, 20528]),
#  19980: tensor(9242),
#  19985: tensor([13887, 17678]),
#  19987: tensor(2747),
#  19991: tensor(17216),
#  19992: tensor(17274),
#  19993: tensor([20017, 21093]),
#  19995: tensor(12344),
#  19999: tensor(19960),
#  20005: tensor(9875),
#  20010: tensor([15657, 19531]),
#  20015: tensor([17796, 21268]),
#  20016: tensor(12103),
#  20019: tensor([ 5278, 19597]),
#  20022: tensor(20094),
#  20024: tensor(8741),
#  20027: tensor(11297),
#  20038: tensor(11771),
#  20042: tensor(15053),
#  20043: tensor([17664, 20888, 21032]),
#  20047: tensor(6514),
#  20048: tensor(18120),
#  20051: tensor([15416, 19265]),
#  20058: tensor(10395),
#  20064: tensor([ 9258, 11196, 20833]),
#  20069: tensor(16609),
#  20071: tensor(14947),
#  20072: tensor(16113),
#  20074: tensor(11875),
#  20079: tensor(6618),
#  20080: tensor(17000),
#  20084: tensor(11518),
#  20086: tensor(11200),
#  20091: tensor(17222),
#  20094: tensor(20022),
#  20104: tensor(9834),
#  20116: tensor(8806),
#  20118: tensor([10305, 17176]),
#  20141: tensor(13148),
#  20142: tensor(17921),
#  20154: tensor(19156),
#  20159: tensor(19940),
#  20165: tensor(6062),
#  20166: tensor(19754),
#  20168: tensor([10993, 15354, 16223, 16651, 19004, 19519, 21399]),
#  20170: tensor(9729),
#  20172: tensor(13313),
#  20181: tensor(16564),
#  20184: tensor(6763),
#  20187: tensor(14467),
#  20193: tensor(12523),
#  20196: tensor(13211),
#  20200: tensor(10086),
#  20201: tensor(5441),
#  20203: tensor([ 8042, 19473, 20669]),
#  20205: tensor(11206),
#  20217: tensor([16705, 19210, 20937, 21077]),
#  20222: tensor(18931),
#  20224: tensor(17918),
#  20233: tensor(11368),
#  20234: tensor(14499),
#  20236: tensor([10183, 13282, 15014, 16062, 18133, 18620]),
#  20237: tensor(9709),
#  20241: tensor(17561),
#  20250: tensor(18602),
#  20279: tensor(16491),
#  20283: tensor([ 5882, 10504, 14150, 15606, 20909]),
#  20291: tensor(19241),
#  20292: tensor(7720),
#  20293: tensor(14472),
#  20295: tensor(21188),
#  20305: tensor(17860),
#  20319: tensor([ 1906, 20755]),
#  20327: tensor([ 8641, 16102, 17288]),
#  20329: tensor(12930),
#  20335: tensor(9140),
#  20337: tensor(10655),
#  20339: tensor(16577),
#  20342: tensor(20817),
#  20350: tensor(1073),
#  20354: tensor(17897),
#  20355: tensor(19493),
#  20356: tensor(13757),
#  20357: tensor([8376, 8568]),
#  20360: tensor([ 2131,  9488, 14115]),
#  20361: tensor(13370),
#  20364: tensor(19779),
#  20373: tensor(10464),
#  20375: tensor([ 5536, 12813, 18407, 21145]),
#  20376: tensor(19749),
#  20382: tensor(8379),
#  20385: tensor(14316),
#  20389: tensor(19467),
#  20391: tensor(12092),
#  20406: tensor(20348),
#  20408: tensor(19380),
#  20410: tensor(9752),
#  20412: tensor(16890),
#  20414: tensor(11256),
#  20415: tensor(20468),
#  20422: tensor(15829),
#  20425: tensor(12198),
#  20433: tensor(15495),
#  20434: tensor(10115),
#  20444: tensor(20370),
#  20448: tensor(14821),
#  20454: tensor(9542),
#  20458: tensor(10308),
#  20461: tensor([13991, 18065]),
#  20468: tensor(20415),
#  20470: tensor(9471),
#  20477: tensor(9319),
#  20479: tensor([15519, 17355, 17626, 17749, 18459, 19350, 21036]),
#  20481: tensor(16919),
#  20484: tensor(14298),
#  20494: tensor(18726),
#  20498: tensor(17397),
#  20499: tensor([ 6895, 15464]),
#  20508: tensor(5190),
#  20520: tensor(12852),
#  20521: tensor(11867),
#  20522: tensor(18269),
#  20525: tensor(19967),
#  20531: tensor(19446),
#  20547: tensor(16869),
#  20564: tensor([10965, 17191]),
#  20568: tensor(11930),
#  20584: tensor(4132),
#  20585: tensor([13905, 20484, 20868]),
#  20587: tensor([18725, 20639]),
#  20593: tensor(20586),
#  20604: tensor(10046),
#  20605: tensor(15944),
#  20609: tensor(11163),
#  20612: tensor(15669),
#  20619: tensor(5908),
#  20620: tensor(18117),
#  20621: tensor([ 1320, 15430]),
#  20628: tensor(14999),
#  20630: tensor(4543),
#  20634: tensor(18978),
#  20635: tensor(3278),
#  20644: tensor(12657),
#  20647: tensor([16454, 17048]),
#  20650: tensor(21404),
#  20653: tensor(7688),
#  20655: tensor(7514),
#  20659: tensor(3036),
#  20661: tensor(18666),
#  20663: tensor(7898),
#  20665: tensor(14191),
#  20667: tensor(11481),
#  20668: tensor(20387),
#  20674: tensor([5332, 8872]),
#  20676: tensor([16408, 21064]),
#  20678: tensor([18739, 20688]),
#  20686: tensor(13968),
#  20692: tensor([20067, 21402]),
#  20706: tensor([14074, 14153, 18238, 20972]),
#  20713: tensor([14107, 18387, 19389]),
#  20714: tensor(10229),
#  20715: tensor(9355),
#  20723: tensor(17129),
#  20725: tensor([ 8511, 18689]),
#  20730: tensor(11714),
#  20731: tensor(14433),
#  20732: tensor(10350),
#  20744: tensor(12024),
#  20745: tensor(3344),
#  20747: tensor(19725),
#  20750: tensor([11887, 14345]),
#  20763: tensor(4447),
#  20776: tensor(13192),
#  20783: tensor([18799, 19209]),
#  20787: tensor(2704),
#  20789: tensor(4112),
#  20792: tensor(15575),
#  20797: tensor([13489, 19816]),
#  20798: tensor(13210),
#  20799: tensor(13144),
#  20802: tensor(14789),
#  20803: tensor(19907),
#  20807: tensor([14214, 20263]),
#  20814: tensor([  375,   427,   473,   502,   535,   579,   580,   600,   678,   767,
#           779,  1031,  1122,  1280,  1287,  1330,  1362,  1453,  1618,  1774,
#          1776,  1796,  1819,  1832,  1853,  1918,  1996,  2047,  2074,  2095,
#          2112,  2213,  2236,  2262,  2263,  2368,  2382,  2487,  2506,  2511,
#          2548,  2571,  2607,  2616,  2663,  2671,  2725,  2805,  2921,  2954,
#          2958,  2968,  3104,  3134,  3148,  3200,  3203,  3218,  3303,  3315,
#          3321,  3333,  3341,  3352,  3379,  3387,  3441,  3485,  3499,  3510,
#          3536,  3545,  3559,  3562,  3564,  3570,  3594,  3605,  3616,  3672,
#          3779,  3784,  3817,  3826,  3850,  3853,  3858,  3895,  3927,  3944,
#          3950,  3963,  3975,  3993,  4008,  4028,  4043,  4047,  4058,  4082,
#          4088,  4118,  4128,  4130,  4131,  4143,  4163,  4164,  4196,  4214,
#          4243,  4256,  4259,  4302,  4309,  4311,  4345,  4354,  4368,  4399,
#          4426,  4495,  4507,  4526,  4590,  4618,  4644,  4653,  4690,  4696,
#          4743,  4757,  4873,  5025,  5028,  5046,  5075,  5082,  5180,  5196,
#          5208,  5261,  5299,  5300,  5322,  5344,  5346,  5374,  5401,  5453,
#          5575,  5610,  5699,  5722,  5870,  5884,  5933,  6099,  6148,  6196,
#          6220,  6287,  6394,  6400,  6435,  6445,  6493,  6501,  6597,  6619,
#          6726,  6857,  6914,  7056,  7141,  7164,  7177,  7313,  7345,  7368,
#          7384,  7459,  7466,  7497,  7585,  7656,  7662,  7719,  7722,  7761,
#          7790,  7847,  7977,  7996,  8174,  8177,  8185,  8295,  8309,  8320,
#          8514,  8565,  8603,  8655,  8713,  8819,  8970,  9068,  9088,  9090,
#          9092,  9184,  9272,  9335,  9363,  9373,  9440,  9448,  9470,  9633,
#          9645,  9702,  9828,  9833,  9877,  9912,  9932, 10025, 10026, 10040,
#         10060, 10123, 10159, 10332, 10334, 10347, 10507, 10515, 10526, 10586,
#         10592, 10613, 10623, 10627, 10692, 10701, 10764, 10884, 10886, 10900,
#         10909, 10970, 10978, 11012, 11204, 11230, 11236, 11245, 11249, 11349,
#         11396, 11433, 11486, 11632, 11675, 11719, 11780, 11787, 11862, 11883,
#         12020, 12228, 12332, 12377, 12457, 12460, 12493, 12501, 12526, 12646,
#         12797, 12855, 12948, 13091, 13157, 13218, 13383, 13473, 13497, 13505,
#         13580, 13631, 13639, 13734, 13735, 13742, 13756, 13817, 13834, 13845,
#         13868, 13910, 13974, 13999, 14036, 14067, 14084, 14138, 14141, 14151,
#         14181, 14241, 14272, 14346, 14488, 14518, 14554, 14558, 14568, 14597,
#         14613, 14622, 14656, 14689, 14692, 14703, 14714, 14721, 14776, 14824,
#         14866, 14867, 14885, 14887, 14952, 14955, 14969, 15062, 15098, 15108,
#         15141, 15204, 15216, 15287, 15345, 15389, 15395, 15451, 15467, 15647,
#         15718, 15746, 15760, 15780, 15793, 15811, 15889, 15938, 16098, 16209,
#         16303, 16323, 16325, 16349, 16414, 16423, 16468, 16505, 16570, 16604,
#         16644, 16663, 16679, 16716, 16725, 16731, 16745, 16761, 16789, 16809,
#         16811, 16852, 16886, 16905, 16916, 16931, 16942, 16966, 16979, 16999,
#         17030, 17045, 17049, 17059, 17083, 17095, 17114, 17167, 17174, 17264,
#         17292, 17315, 17320, 17329, 17334, 17337, 17351, 17416, 17508, 17565,
#         17640, 17641, 17662, 17677, 17680, 17713, 17719, 17738, 17792, 17795,
#         17819, 17960, 17976, 17999, 18000, 18032, 18168, 18188, 18204, 18294,
#         18297, 18335, 18344, 18394, 18419, 18420, 18439, 18470, 18532, 18578,
#         18586, 18659, 18671, 18695, 18757, 18828, 18877, 18885, 18915, 18916,
#         18946, 18959, 18964, 19056, 19100, 19167, 19199, 19206, 19254, 19336,
#         19392, 19398, 19411, 19423, 19450, 19476, 19555, 19591, 19632, 19654,
#         19662, 19674, 19723, 19762, 19835, 19962, 19976, 19987, 19999, 20063,
#         20159, 20161, 20220, 20227, 20232, 20236, 20283, 20302, 20305, 20319,
#         20364, 20389, 20449, 20459, 20463, 20471, 20479, 20492, 20507, 20520,
#         20545, 20597, 20633, 20640, 20678, 20692, 20713, 20734, 20758, 20769,
#         20808, 20840, 20841, 20869, 20968, 20970, 20993, 21001, 21012, 21013,
#         21024, 21025, 21031, 21094, 21104, 21144, 21164, 21165, 21173, 21186,
#         21215, 21229, 21238, 21256, 21280, 21308, 21336, 21393, 21409]),
#  20816: tensor([11640, 15121]),
#  20826: tensor(19096),
#  20827: tensor(11765),
#  20831: tensor(13958),
#  20832: tensor(7422),
#  20838: tensor(18855),
#  20840: tensor([17089, 18519, 20048, 20365, 21057]),
#  20841: tensor(20936),
#  20844: tensor(7377),
#  20846: tensor(17974),
#  20849: tensor(21212),
#  20850: tensor([ 9502, 13767]),
#  20852: tensor(11751),
#  20863: tensor([ 7416,  9814, 14440, 14895, 15707]),
#  20869: tensor(13100),
#  20876: tensor(19805),
#  20888: tensor(18426),
#  20898: tensor(8828),
#  20917: tensor([14471, 16669]),
#  20919: tensor(11025),
#  20921: tensor(17780),
#  20926: tensor(11942),
#  20927: tensor([11864, 14055]),
#  20929: tensor(2819),
#  20930: tensor(17501),
#  20934: tensor(11516),
#  20935: tensor([18271, 18864]),
#  20942: tensor(11357),
#  20949: tensor(9574),
#  20953: tensor(8068),
#  20956: tensor(16525),
#  20964: tensor(19621),
#  20966: tensor(7235),
#  20968: tensor([ 2737, 14011, 16697, 17100, 19165, 20075, 20583, 20747]),
#  20971: tensor(906),
#  20974: tensor(18867),
#  20984: tensor(12253),
#  20990: tensor(19564),
#  20993: tensor([ 1827,  7189, 12314, 14898, 18206, 19700, 20473, 20882]),
#  20996: tensor([6079, 9881]),
#  20997: tensor([13399, 18132]),
#  20998: tensor(6622),
#  20999: tensor(19900),
#  21002: tensor(16793),
#  21005: tensor([10034, 15449]),
#  21006: tensor(9016),
#  21008: tensor(8503),
#  21013: tensor([ 1758,  2146, 18476, 19605, 20757, 21084, 21302]),
#  21017: tensor(11242),
#  21020: tensor(18525),
#  21024: tensor([13006, 15963, 17024, 17261, 17449, 17812, 18381, 20145, 20524]),
#  21025: tensor([ 2460,  2539,  7499, 19236, 19660, 20137, 21139, 21160, 21275]),
#  21030: tensor(1378),
#  21031: tensor([13204, 15580, 16588, 17891, 19498, 19717, 19885]),
#  21035: tensor(21398),
#  21041: tensor(12188),
#  21049: tensor(16287),
#  21056: tensor([12051, 14202, 16887, 20328]),
#  21068: tensor(2099),
#  21081: tensor(9443),
#  21094: tensor([12419, 18520, 19181, 20803]),
#  21098: tensor([12990, 13119, 16478, 18250]),
#  21099: tensor(7735),
#  21100: tensor(9962),
#  21104: tensor([12680, 14768, 15933, 18299, 20394, 20483]),
#  21110: tensor(16140),
#  21111: tensor([ 2830, 20223]),
#  21114: tensor(17588),
#  21115: tensor(15815),
#  21117: tensor(14696),
#  21124: tensor(16748),
#  21125: tensor(19437),
#  21126: tensor(16605),
#  21132: tensor(11255),
#  21133: tensor(10065),
#  21134: tensor(17777),
#  21136: tensor([16877, 17864, 18792, 19104, 20777, 20983]),
#  21141: tensor(16387),
#  21142: tensor(7282),
#  21144: tensor([14117, 15646, 17932, 18077, 19798, 20672, 21362]),
#  21145: tensor(14161),
#  21151: tensor(19134),
#  21154: tensor(10653),
#  21157: tensor(16574),
#  21158: tensor(18804),
#  21159: tensor([17552, 18024]),
#  21166: tensor(12537),
#  21173: tensor([14232, 15005, 16853, 17651, 20288, 20852]),
#  21174: tensor([13351, 16041, 17256, 17259, 19594, 20147, 20354, 21122]),
#  21177: tensor([13093, 13930]),
#  21186: tensor([16309, 17685, 18056]),
#  21187: tensor([ 7610, 15224, 17282]),
#  21188: tensor(21389),
#  21190: tensor(2217),
#  21191: tensor(3447),
#  21194: tensor(10028),
#  21196: tensor([15174, 17593]),
#  21197: tensor(17627),
#  21200: tensor([ 9212, 15375]),
#  21201: tensor(17732),
#  21204: tensor([19643, 19922]),
#  21206: tensor([5502, 9353]),
#  21209: tensor(4656),
#  21210: tensor(14782),
#  21211: tensor(10561),
#  21212: tensor([16050, 20849]),
#  21215: tensor([21067, 21148]),
#  21216: tensor([ 5328, 13836]),
#  21218: tensor(7131),
#  21229: tensor(19622),
#  21232: tensor([13769, 20797, 21382]),
#  21233: tensor(12630),
#  21235: tensor(11668),
#  21237: tensor(13811),
#  21238: tensor([12358, 15198, 16284, 16898, 17443, 18278, 18285, 19647, 20190, 20518,
#         20612, 21046, 21221, 21295, 21394]),
#  21241: tensor([ 5997, 11141, 11643, 16741, 17953, 18803, 19132, 19657, 20770, 20839]),
#  21256: tensor([13703, 13901, 14031, 15961, 18654, 18775, 19469, 19797, 19867, 19876,
#         20567, 20574, 20629, 20643, 20890]),
#  21258: tensor([18166, 18582]),
#  21266: tensor([18740, 20458]),
#  21267: tensor(6627),
#  21268: tensor(13815),
#  21269: tensor([10388, 17319]),
#  21281: tensor(14797),
#  21291: tensor(11564),
#  21294: tensor(7587),
#  21306: tensor(1141),
#  21308: tensor(12905),
#  21310: tensor(17642),
#  21317: tensor(10145),
#  21318: tensor(16956),
#  21319: tensor(11250),
#  21326: tensor(14502),
#  21330: tensor(6028),
#  21331: tensor(5877),
#  21339: tensor(8266),
#  21340: tensor([16460, 20727, 20794]),
#  21345: tensor(3636),
#  21347: tensor([ 1445,  6034, 11010, 13963]),
#  21348: tensor(14707),
#  21351: tensor([ 8037, 19817]),
#  21352: tensor([10988, 20641]),
#  21361: tensor(13655),
#  21366: tensor(16002),
#  21372: tensor(19266),
#  21382: tensor([18513, 18679, 21232]),
#  21388: tensor(10033),
#  21390: tensor([ 8432, 19897]),
#  21392: tensor([13068, 13321]),
#  21393: tensor([ 4474, 16073, 16504, 16954, 17159, 17998, 18621]),
#  21398: tensor(21035),
#  21404: tensor(20650),
#  21406: tensor([11654, 14179]),
#  21409: tensor([15336, 20104, 20992]),
#  21410: tensor([ 7126, 18580]),
#  21411: tensor(12293),
#  21412: tensor(4803),
#  21413: tensor(17316),
#  21414: tensor([ 8933, 12445])}

# %%
original_ids_pivots = {index_idxs[int(k)]: [index_idxs[int(v_i)] for v_i in v.flatten().tolist()] for k, v in grouped_by_pivot.items()}

decoded_pivots = {tokenizer.convert_ids_to_tokens(k): tokenizer.convert_ids_to_tokens(v) for k, v in original_ids_pivots.items()}
pprint(decoded_pivots)
# Out:
# {'10th': ['1st',
#           'fourth',
#           '2nd',
#           '19th',
#           '3rd',
#           'fifth',
#           '20th',
#           '4th',
#           'sixth',
#           '5th',
#           '18th',
#           '6th',
#           '7th',
#           '17th',
#           'seventh',
#           '16th',
#           '8th',
#           '12th',
#           '13th',
#           '11th',
#           '9th',
#           '15th',
#           '14th',
#           'eighth',
#           '21st',
#           'ninth',
#           'Fourth',
#           'tenth',
#           'nineteenth',
#           'Fifth',
#           'twentieth',
#           '25th',
#           'Sixth',
#           'Seventh',
#           '50th',
#           '30th',
#           'twelfth',
#           '24th',
#           'eleventh',
#           '22nd',
#           '23rd',
#           'eighteenth',
#           '26th',
#           '27th',
#           '28th',
#           'sixteenth',
#           '29th',
#           'Eighth',
#           '40th',
#           'thirteenth',
#           '100th',
#           'seventeenth',
#           '31st',
#           'Ninth',
#           'fifteenth',
#           'fourteenth',
#           '35th',
#           '34th',
#           '32nd',
#           '33rd',
#           '60th',
#           '42nd',
#           '36th',
#           '38th',
#           '39th',
#           '37th',
#           '41st',
#           '45th'],
#  '11th': ['11', '111', '116'],
#  '12th': ['115', '112', '114', '117', '118', '119'],
#  '13th': ['124', '126', '132', '131', '136', '142'],
#  '1620': ['Rotterdam'],
#  '1640': ['Johanna', 'Westphalia'],
#  '1642': ['Cromwell', 'Guitars', 'ignited'],
#  '1648': ['Bremen', 'Gdańsk', 'Malmö'],
#  '1661': ['mosques', 'Apostles'],
#  '1680': ['Bohemia',
#           'archbishop',
#           'Protestants',
#           'Percussion',
#           'sermons',
#           'inexpensive'],
#  '1689': ['Reformation', 'Cebu'],
#  '1715': ['implicated', 'Aleppo'],
#  '1720': ['Baroque', 'Genoa', 'Violin', 'nobleman', 'lucrative', 'Fulham'],
#  '1730': ['Mughal', 'Glamorgan'],
#  '1740': ['Habsburg', 'Brewery', 'modernization', 'concerto'],
#  '1745': ['Otago'],
#  '1746': ['nobles', 'Ljubljana', 'pained', 'Johnstone'],
#  '1747': ['Derbyshire', 'satirical', 'Guangzhou', 'Fife', 'jerking', 'Elgin'],
#  '1748': ['prolonged',
#           'Versailles',
#           'mandolin',
#           'functioned',
#           'statesman',
#           'Inverness',
#           'comedies'],
#  '1749': ['fortifications',
#           'castles',
#           'Priory',
#           'facilitated',
#           'chronicles',
#           'Guangdong',
#           'establishes',
#           'hampered',
#           'frigates',
#           'narratives',
#           'fortification',
#           'Nagoya',
#           'intrinsic',
#           'plausible',
#           'Annapolis'],
#  '1750': ['Keyboards', 'baroque'],
#  '1751': ['implementing',
#           'Biological',
#           'communists',
#           'Putnam',
#           'augmented',
#           'ineffective',
#           'murdering',
#           'befriended',
#           'Softball'],
#  '1752': ['Bihar',
#           'Württemberg',
#           'forts',
#           'prosperous',
#           'Watford',
#           'Silesia',
#           'gothic',
#           'feasible',
#           'weaponry',
#           'Wexford',
#           'symmetrical',
#           'embroidered',
#           'sturdy',
#           'jurist',
#           'Ghent'],
#  '1753': ['illegitimate',
#           'Jesuits',
#           'Scandinavia',
#           'morphology',
#           'Fishing',
#           'harvesting',
#           'Veterinary'],
#  '1754': ['Mauritius',
#           'Wentworth',
#           'Kabul',
#           'outfielder',
#           'Guadalupe',
#           'Masovian'],
#  '1755': ['disastrous',
#           'Christoph',
#           'Preliminary',
#           'horrific',
#           'constructions'],
#  '1756': ['intricate',
#           'ensures',
#           'Eton',
#           'Iroquois',
#           'Lacrosse',
#           'hideous',
#           'Ramírez'],
#  '1757': ['Lahore',
#           'methodology',
#           'Hussain',
#           'Weimar',
#           'Accordingly',
#           'Properties',
#           'Wolff',
#           'Severn'],
#  '1759': ['Giuseppe',
#           'Alexandre',
#           'Félix',
#           'Societies',
#           'Gettysburg',
#           'rabbits',
#           'quantitative',
#           'Sergey',
#           'toxicity',
#           'Siena'],
#  '176': ['Wiltshire'],
#  '1760': ['aristocratic', 'Mysore', 'industrialist'],
#  '1761': ['Dartmouth',
#           'Salzburg',
#           'pivotal',
#           'matrices',
#           'Philosophical',
#           'Salford',
#           'meadows',
#           'revered',
#           'recited'],
#  '1762': ['Stamford', 'Matters', 'Magdalena'],
#  '1764': ['besieged',
#           'Centennial',
#           'Silesian',
#           'insurgents',
#           'heightened',
#           'ecosystems',
#           'Maharaja',
#           'Conquest',
#           'ballads',
#           'physiology',
#           'cartridges',
#           'inventions',
#           'alleviate',
#           'Ballad',
#           'Sahib'],
#  '1765': ['Tudor',
#           'hereditary',
#           'banjo',
#           'fashionable',
#           'forcibly',
#           'vaudeville',
#           'repression'],
#  '1766': ['abbey', 'fearful', 'prosecuted', 'leaping'],
#  '1767': ['constructing',
#           'cannons',
#           'disgusted',
#           'popularized',
#           'alarmed',
#           'pharmacy',
#           'comprehend',
#           'revoked',
#           'centralized'],
#  '1768': ['monasteries',
#           'deposed',
#           'ornate',
#           'Subsequent',
#           'asserts',
#           'forcefully',
#           'alleging',
#           'Decree'],
#  '1769': ['remarkably', 'Monterey'],
#  '1770': ['Enlightenment'],
#  '1771': ['Rajasthan',
#           'strengthening',
#           'tuberculosis',
#           'Pembroke',
#           'Linnaeus',
#           'moaning',
#           'fastened',
#           'Grimsby'],
#  '1772': ['Prussia'],
#  '1773': ['reconstructed', 'Wilkins', 'migrate'],
#  '1774': ['Hoffmann'],
#  '1779': ['Nicaragua', 'Buccaneers', 'Cinematography'],
#  '178': ['12'],
#  '1781': ['Dortmund'],
#  '1785': ['Orioles', 'Rhineland', 'warship', 'Syriac', 'Armagh', 'Léon'],
#  '1786': ['baptized', 'seminal', 'episcopal', 'Sailing', 'Lviv'],
#  '1787': ['interpretations', 'Principles', 'sentiments'],
#  '1788': ['Cairns', 'turbulent'],
#  '1790': ['Beaufort'],
#  '1791': ['banished'],
#  '1794': ['suppression'],
#  '1795': ['Guillaume', 'Vilnius', 'Brest'],
#  '1797': ['denounced', 'Vincenzo', 'repulsed'],
#  '1798': ['Limerick'],
#  '1799': ['Tuscany'],
#  '1802': ['Bonaparte', 'Ascension'],
#  '1803': ['Napoleon'],
#  '1805': ['Gloucester', 'Essays', 'Newmarket', 'Tavern'],
#  '1806': ['Ipswich'],
#  '1807': ['battleships'],
#  '1808': ['Monmouth'],
#  '1809': ['Aleksandr'],
#  '1811': ['Andrés', 'Caracas'],
#  '1813': ['Collingwood'],
#  '1818': ['unpublished', 'Ives'],
#  '1819': ['yellowish'],
#  '1821': ['Archibald'],
#  '1822': ['Guyana', 'cottages', 'aristocracy'],
#  '1823': ['frigate'],
#  '1825': ['regulating', 'silvery', 'Montevideo'],
#  '1826': ['Huddersfield', 'exquisite'],
#  '1827': ['Napoleonic',
#           'landowners',
#           'caressed',
#           'Odisha',
#           'clergyman',
#           'octagonal',
#           'Giacomo',
#           'periodicals',
#           'schooner',
#           'Étienne',
#           'Institutions',
#           'Eugène',
#           'Josiah'],
#  '183': ['Milano'],
#  '1830s': ['Ottomans', 'Cretaceous', 'twenties'],
#  '1831': ['landowner'],
#  '1833': ['Shrewsbury', 'Bernardino', 'Whig', 'explorers', 'repeal'],
#  '1834': ['antiquity',
#           'Elected',
#           'Theodor',
#           'Mecklenburg',
#           'petitioned',
#           'Ignacio'],
#  '1836': ['surveyor'],
#  '1839': ['Tajikistan'],
#  '184': ['Palermo'],
#  '1840s': ['Helens'],
#  '1841': ['authorised'],
#  '1853': ['Forestry'],
#  '1855': ['Crimean'],
#  '186': ['1947', 'Middlesbrough', 'informally'],
#  '188': ['ambiguous'],
#  '189': ['15', '30', '13'],
#  '191': ['Retired', 'reassigned', 'Operational', 'acknowledging'],
#  '193': ['1948', 'Odessa'],
#  '194': ['Utrecht'],
#  '1944': ['wartime'],
#  '1950s': ['postwar'],
#  '1960s': ['1950s',
#            '1930s',
#            '1920s',
#            '1940s',
#            '1880s',
#            '1890s',
#            '1870s',
#            '1860s',
#            '80s',
#            '1900s',
#            '1850s',
#            '70s',
#            '1840s',
#            '1800s'],
#  '197': ['1953'],
#  '1972': ['1960s'],
#  '1980': ['1914'],
#  '1987': ['1970s'],
#  '1992': ['1945', '1944'],
#  '1997': ['1980s', '1946', '1936'],
#  '1998': ['1942', '1943', '1940'],
#  '2001': ['1941', '1951', '1990s'],
#  '2004': ['1966', '1965', '1962', '1961', '1952', '1954', '2000s'],
#  '2007': ['2010',
#           '2011',
#           '2012',
#           '2008',
#           '2009',
#           '2013',
#           '2006',
#           '2014',
#           '2015',
#           '2016',
#           '2005',
#           '2017',
#           '2004',
#           '2000',
#           '2003',
#           '2002',
#           '2001',
#           '1999',
#           '1998',
#           '1997',
#           '1996',
#           '2018',
#           '1995',
#           '1994',
#           '1992',
#           '1993',
#           '1991',
#           '1990',
#           '1989',
#           '1988',
#           '1987',
#           '1986',
#           '1985',
#           '1984',
#           '1980',
#           '1983',
#           '1982',
#           '1979',
#           '1981',
#           '1972',
#           '1976',
#           '1978',
#           '1974',
#           '1975',
#           '1977',
#           '1970',
#           '1968',
#           '1973',
#           '1971',
#           '1969',
#           '1967',
#           '1963',
#           '1958',
#           '1959'],
#  '2008': ['1964', '1960', '1956'],
#  '2010': ['2007', '1950'],
#  '2012': ['2020'],
#  '2014': ['2019'],
#  '216': ['16',
#          '14',
#          '17',
#          '1933',
#          'inconsistent',
#          'articulated',
#          'vigorous',
#          'Cambridgeshire'],
#  '217': ['1917'],
#  '218': ['Pietro', 'Boise'],
#  '224': ['21',
#          '50',
#          '1957',
#          '1955',
#          '1929',
#          '1928',
#          '1922',
#          '1926',
#          '1921',
#          '1913',
#          '1900',
#          '1911',
#          '1890',
#          '1888',
#          'sixteen',
#          'seventy',
#          'ninety',
#          '911',
#          'curving',
#          'spacious',
#          '244'],
#  '226': ['Haryana'],
#  '229': ['20',
#          '18',
#          '1918',
#          '1920',
#          '1919',
#          '1934',
#          '1912',
#          '1910',
#          'additionally',
#          'Haynes',
#          'satisfactory',
#          'saturated',
#          'splendid',
#          'Jang'],
#  '236': ['thirteen', 'Stuttgart', 'Heidelberg', 'Düsseldorf', 'Hahn'],
#  '237': ['doubtful'],
#  '239': ['File'],
#  '241': ['Logistics'],
#  '243': ['100', '1938', 'Oxfordshire', 'Southwestern', 'comparatively'],
#  '244': ['25',
#          '24',
#          '19',
#          '22',
#          '23',
#          '28',
#          '26',
#          '27',
#          '29',
#          '31',
#          '40',
#          '500',
#          '200',
#          '45',
#          '60',
#          '35',
#          '65',
#          '32',
#          '80',
#          '90',
#          '33',
#          '70',
#          '300',
#          '44',
#          '36',
#          '34',
#          '64',
#          '38',
#          '37',
#          '400',
#          '75',
#          '42',
#          '1935',
#          '39',
#          '48',
#          '55',
#          '41',
#          '47',
#          '52',
#          '43',
#          '49',
#          '1927',
#          '46',
#          '1924',
#          '1925',
#          '51',
#          '1923',
#          '150',
#          '54',
#          '600',
#          '56',
#          '53',
#          '1908',
#          '95',
#          '59',
#          '800',
#          '58',
#          '57',
#          '1905',
#          '08',
#          '1906',
#          '1907',
#          '250',
#          '1909',
#          '99',
#          '85',
#          '09',
#          '1904',
#          '05',
#          '07',
#          '06',
#          '66',
#          '1902',
#          '1901',
#          '1903',
#          '62',
#          '98',
#          '72',
#          '04',
#          '01',
#          '96',
#          '97',
#          '03',
#          '120',
#          '1898',
#          '88',
#          '61',
#          '93',
#          '76',
#          '67',
#          '1899',
#          '02',
#          '63',
#          '91',
#          '92',
#          '77',
#          '68',
#          '78',
#          '81',
#          '1895',
#          '1896',
#          '1897',
#          '700',
#          '69',
#          '74',
#          '94',
#          '71',
#          '84',
#          '73',
#          '82',
#          '1889',
#          '89',
#          '1893',
#          '1892',
#          '79',
#          '1894',
#          '86',
#          '1885',
#          '87',
#          '1891',
#          '83',
#          '1864',
#          '1865',
#          '1880',
#          '1887',
#          '1861',
#          '1862',
#          '1863',
#          '1886',
#          '1870',
#          '1884',
#          '1881',
#          '1882',
#          '1883',
#          '1878',
#          '110',
#          '1860',
#          '1876',
#          '1871',
#          '1879',
#          '1875',
#          '1867',
#          '1877',
#          '130',
#          '1872',
#          '1868',
#          '1874',
#          '1873',
#          '1866',
#          '900',
#          '1869',
#          '101',
#          '1850',
#          '1848',
#          '160',
#          '1859',
#          '1857',
#          '180',
#          '1854',
#          '1855',
#          '1858',
#          '140',
#          '350',
#          '1856',
#          '125',
#          '105',
#          '1852',
#          '1851',
#          '1840',
#          '1853',
#          '1849',
#          '1847',
#          '1846',
#          '102',
#          '360',
#          '1830',
#          '1845',
#          '104',
#          '750',
#          '1837',
#          '1844',
#          '103',
#          '1800',
#          '1841',
#          '1838',
#          '1842',
#          '1839',
#          '1843',
#          '1836',
#          '106',
#          '1835',
#          '1832',
#          '450',
#          '1500',
#          '220',
#          '107',
#          'seventeen',
#          '1815',
#          '1834',
#          '108',
#          '170',
#          '1831',
#          '1814',
#          '1833',
#          '1820',
#          '240',
#          '1825',
#          '135',
#          '1828',
#          '109',
#          '1829',
#          '1824',
#          '1821',
#          '1810',
#          '230',
#          '190',
#          '128',
#          '3000',
#          '1826',
#          '1818',
#          '113',
#          '1813',
#          '1822',
#          '1827',
#          '1816',
#          '1793',
#          '1801',
#          '1806',
#          '1823',
#          '1817',
#          '1819',
#          '121',
#          '1803',
#          '1809',
#          '175',
#          '210',
#          '127',
#          '1798',
#          '1808',
#          '1811',
#          '122',
#          '1805',
#          '123',
#          '1804',
#          '1794',
#          '1807',
#          '550',
#          '1790',
#          '1795',
#          '1792',
#          '280',
#          '5000',
#          '1802',
#          '260',
#          '320',
#          '1789',
#          '145',
#          '270',
#          '650',
#          '1799',
#          '1796',
#          '165',
#          '1776',
#          '1797',
#          '155',
#          '330',
#          '1775',
#          'nineteen',
#          '1791',
#          '129',
#          '133',
#          '144',
#          '1200',
#          '1600',
#          '137',
#          '225',
#          '152',
#          '138',
#          '1780',
#          '134',
#          '1783',
#          '185',
#          '141',
#          '1788',
#          '850',
#          'Numerous',
#          'Northampton',
#          '340',
#          '1787',
#          '143',
#          '1777',
#          '501',
#          'Northumberland',
#          '205',
#          '1778',
#          '146',
#          '201',
#          '370',
#          '148',
#          '147',
#          '1784',
#          '151',
#          '1700',
#          '139',
#          '154',
#          '153',
#          '156',
#          '167',
#          '1781',
#          '202',
#          '1758',
#          '1782',
#          '168',
#          '380',
#          '310',
#          '290',
#          '1785',
#          '460',
#          '256',
#          '480',
#          '195',
#          '149',
#          '161',
#          '157',
#          '215',
#          '440',
#          '1786',
#          '420',
#          '1772',
#          '275',
#          '1774',
#          'Peterborough',
#          '192',
#          '1779',
#          '182',
#          '158',
#          '1770',
#          'utilizing',
#          '235',
#          '162',
#          '163',
#          '164',
#          '1660',
#          '375',
#          '177',
#          '212',
#          '1750',
#          '171',
#          '172',
#          '1763',
#          '208',
#          '203',
#          '176',
#          '169',
#          '181',
#          '166',
#          '183',
#          '206',
#          '159',
#          '222',
#          '1760',
#          '188',
#          '301',
#          '410',
#          'Fifteen',
#          '211',
#          '178',
#          '365',
#          '173',
#          '187',
#          '174',
#          '1300',
#          '430',
#          '221',
#          '186',
#          '520',
#          '204',
#          '325',
#          '184',
#          '224',
#          '640',
#          'TX',
#          '1768',
#          '610',
#          '207',
#          '191',
#          '213',
#          '1773',
#          '214',
#          '194',
#          '197',
#          '193',
#          '303',
#          '198',
#          '390',
#          '196',
#          'routinely',
#          'Nottinghamshire',
#          '4000',
#          'noteworthy',
#          '540',
#          '216',
#          '231',
#          '179',
#          '950',
#          'Sixteen',
#          '217',
#          '305',
#          '189',
#          '265',
#          '219',
#          '255',
#          '1400',
#          '1769',
#          '232',
#          '1771',
#          '199',
#          '218',
#          '1765',
#          '223',
#          '1762',
#          '660',
#          '245',
#          '226',
#          '312',
#          '470',
#          '333',
#          'Northeastern',
#          '560',
#          '1761',
#          'Northamptonshire',
#          '1766',
#          '1755',
#          'Franks',
#          '1764',
#          '227',
#          '1767',
#          '1640',
#          '264',
#          '1759',
#          '295',
#          '1740',
#          '285',
#          '1745',
#          '1650',
#          '262',
#          '234',
#          '238',
#          '302',
#          '737',
#          '1100',
#          'Frederic',
#          '233',
#          '228',
#          '490',
#          '241',
#          '1756',
#          '246',
#          '242',
#          '1648',
#          '251',
#          '1754',
#          '1715',
#          '1757',
#          '401',
#          '1689',
#          '229',
#          '625',
#          '720',
#          '243',
#          '252',
#          '315',
#          '281',
#          '313',
#          '287',
#          '253',
#          '1730',
#          '425',
#          '237',
#          '247',
#          '510',
#          '1644',
#          '530',
#          'Vanguard',
#          '311',
#          '1720',
#          '236',
#          '630',
#          '620',
#          '249',
#          '239',
#          '580',
#          '322',
#          'Göttingen',
#          '345',
#          '1A',
#          '1753',
#          'documenting',
#          '1710',
#          '304',
#          '802',
#          '680',
#          '316',
#          '405',
#          '321',
#          '1661',
#          '1642',
#          '1688',
#          '435',
#          'Faust',
#          'doctrines',
#          '272',
#          '308',
#          '1620',
#          '257',
#          'Augsburg',
#          '258',
#          '512',
#          '335',
#          '385',
#          '1751',
#          '261',
#          '1748',
#          '1746',
#          '1747',
#          '248',
#          'credible',
#          'Fourteen',
#          '1680',
#          '760',
#          '395',
#          '415',
#          '1749',
#          '1752',
#          '1690',
#          'nominally',
#          '404',
#          '570',
#          '286'],
#  '248': ['principally',
#          'Warwickshire',
#          'overlapping',
#          'highlighting',
#          'Burnley',
#          'greenish',
#          'ostensibly'],
#  '249': ['1949', 'Museums'],
#  '253': ['physiological', 'systematically', 'unlawful'],
#  '254': ['selecting', 'competence'],
#  '257': ['1915',
#          'Lincolnshire',
#          'confirming',
#          'Leicestershire',
#          'Pharmacy',
#          'confirms',
#          'recaptured',
#          'hurled'],
#  '258': ['00',
#          'sixty',
#          'Forty',
#          'Hasan',
#          'analyzing',
#          'rejecting',
#          'unreliable',
#          'Testing'],
#  '261': ['1932',
#          '1931',
#          '1812',
#          'northernmost',
#          'Freiburg',
#          'astonished',
#          'picturesque',
#          'evaluating',
#          'Torino'],
#  '264': ['commissioning', 'Ghosts'],
#  '272': ['Knoxville', 'Sardinia', 'Chattanooga', 'Lucknow', 'intriguing'],
#  '278': ['fourteen',
#          'Middlesex',
#          'eighty',
#          'Ulrich',
#          'Greenville',
#          'utilizes',
#          'weakening',
#          'Bournemouth',
#          'Orléans',
#          'catastrophic'],
#  '281': ['overseen'],
#  '285': ['oversized', 'usable'],
#  '286': ['Strasbourg', 'Chichester', 'installing'],
#  '287': ['Bratislava', 'Integration'],
#  '288': ['Parma', 'protruding', 'versatile'],
#  '295': ['problematic',
#          'cylindrical',
#          'gigantic',
#          'narrower',
#          'altering',
#          'A2',
#          'Boyer',
#          'Herrera',
#          'exiting',
#          'Pereira',
#          'legislators'],
#  '2D': ['3D'],
#  '304': ['Dorset'],
#  '305': ['1930', 'elongated'],
#  '306': ['Gloucestershire',
#          'refurbished',
#          'affirmed',
#          'Worcestershire',
#          'Chesterfield',
#          'archaic',
#          'Resurrection',
#          'observes'],
#  '307': ['Gómez',
#          'Equipment',
#          'Tripoli',
#          'Lausanne',
#          'blending',
#          'characterization'],
#  '308': ['topography'],
#  '313': ['destroys'],
#  '315': ['Thirteen', 'unconventional'],
#  '321': ['Croydon', 'integrating'],
#  '36th': ['posthumous'],
#  '375': ['Berkshire', 'Staffordshire'],
#  '385': ['1939',
#          '1937',
#          'Nanjing',
#          'Marlborough',
#          'encompassed',
#          'storing',
#          'highlands'],
#  '390': ['1830s'],
#  '395': ['invasions', 'Harrisburg'],
#  '39th': ['Corbett'],
#  '3D': ['2D'],
#  '3rd': ['Second'],
#  '415': ['Gothenburg'],
#  '425': ['1916'],
#  '430': ['Bernhard'],
#  '510': ['Saratoga'],
#  '570': ['1000',
#          'Hertfordshire',
#          'Shropshire',
#          'Mainz',
#          'Colchester',
#          'distributing',
#          'Buckinghamshire'],
#  '580': ['configurations'],
#  '620': ['60s'],
#  '660': ['Carleton'],
#  '737': ['Airbus'],
#  '760': ['Seville', 'Córdoba', 'Liège'],
#  '8th': ['Third', '10th'],
#  '950': ['90s', 'España'],
#  '978': ['ISBN'],
#  '9th': ['third', '209', '254', '2d', '307', '306', '278', '288'],
#  'A1': ['F1', 'M1'],
#  'A2': ['A1'],
#  'AA': ['AAA'],
#  'AAA': ['AA'],
#  'ABC': ['CBS', 'SBS'],
#  'ACC': ['ICC', 'MAC', 'MCC'],
#  'ACT': ['SAT'],
#  'AFC': ['UEFA', 'ACC', 'CONCACAF'],
#  'AFL': ['AFC', 'ABA', 'RAAF'],
#  'AHL': ['GAA', 'preseason'],
#  'AL': ['NL'],
#  'AM': ['PM'],
#  'AND': ['OR'],
#  'ATP': ['WTA'],
#  'Abbot': ['Abbott'],
#  'Abby': ['Olivia', 'Maggie', 'Leah', 'Abigail'],
#  'Abigail': ['Abby', 'Jess'],
#  'Aboriginal': ['Native', 'indigenous', 'Indigenous', 'Māori'],
#  'Academy': ['Institute', 'academy'],
#  'Académie': ['Stade'],
#  'Access': ['access', 'accessed'],
#  'According': ['according'],
#  'Accordingly': ['whereby'],
#  'Ace': ['ace'],
#  'Acheron': ['Talon'],
#  'Achievement': ['Excellence'],
#  'Achilles': ['Trojan'],
#  'Acting': ['Actors'],
#  'Active': ['active', 'passive'],
#  'Actor': ['actor',
#            'actress',
#            'actors',
#            'Artist',
#            'Actress',
#            'Author',
#            'actresses'],
#  'Ad': ['ad'],
#  'Admiral': ['Commodore', 'Admiralty', 'admiral'],
#  'Adobe': ['Microsoft'],
#  'Adolf': ['Maximilian', 'Casimir'],
#  'Adult': ['adult'],
#  'Afghan': ['Mongol'],
#  'African': ['Indian'],
#  'Africans': ['Afro'],
#  'Against': ['against'],
#  'Agatha': ['Gertrude'],
#  'Age': ['age', 'Ages'],
#  'Agency': ['Administration', 'Authority'],
#  'Agent': ['agent', 'Attorney'],
#  'Ah': ['Oh', 'ah'],
#  'Ahead': ['ahead'],
#  'Ahmad': ['Amir', 'Bahadur'],
#  'Ahmed': ['Islam',
#            'Muhammad',
#            'Abdul',
#            'Ahmad',
#            'Mohammad',
#            'Mohammed',
#            'Hassan',
#            'Ibrahim',
#            'Abdullah',
#            'Mohamed',
#            'Allah',
#            'Syed',
#            'Mustafa',
#            'Ismail',
#            'Aziz',
#            'Khalid',
#            'Kamal',
#            'Rashid',
#            'Yusuf',
#            'sultan',
#            'Jamal'],
#  'Aidan': ['Conor'],
#  'Air': ['air'],
#  'Airborne': ['airborne', 'Aerospace', 'Parachute'],
#  'Aires': ['Janeiro'],
#  'Airlines': ['Telecom'],
#  'Airport': ['Stadium',
#              'Airlines',
#              'Airways',
#              'airports',
#              'Airfield',
#              'Racecourse'],
#  'Alabama': ['Carolina', 'Georgia', 'Birmingham', 'LSU'],
#  'Alain': ['Roland', 'Olivier'],
#  'Albert': ['Ernest'],
#  'Alberta': ['Quebec', 'Calgary', 'Edmonton', 'Winnipeg'],
#  'Album': ['album'],
#  'Aleksandr': ['Ivan', 'Boris'],
#  'Alexei': ['Vladimir',
#             'Mikhail',
#             'Nikolai',
#             'Sergei',
#             'Andrei',
#             'Pavel',
#             'Dmitry',
#             'Konstantin'],
#  'Alexis': ['Kelsey'],
#  'Alfonso': ['Ferdinand'],
#  'Alfred': ['Edgar'],
#  'Alfredo': ['Elsa', 'Helmut'],
#  'Algiers': ['Suez'],
#  'Alien': ['alien', 'UFO'],
#  'Alison': ['Fiona'],
#  'Alistair': ['Nigel'],
#  'Alive': ['alive'],
#  'All': ['all'],
#  'AllMusic': ['Billboard',
#               'iTunes',
#               'Metacritic',
#               'Allmusic',
#               'Tomatoes',
#               'IGN',
#               'ARIA',
#               'IUCN',
#               'Oricon',
#               'RIAA',
#               'NME',
#               'Pitchfork'],
#  'Allied': ['allied', 'Allies', 'Axis'],
#  'Alma': ['alma'],
#  'Almost': ['About', 'Absolutely'],
#  'Alone': ['alone'],
#  'Along': ['along'],
#  'Alpha': ['Delta', 'Omega'],
#  'Alpine': ['Nordic', 'Alps', 'Adriatic'],
#  'Alternative': ['alternative', 'Alternate'],
#  'Although': ['But', 'If', 'Unfortunately', 'Actually'],
#  'Alzheimer': ['pneumonia', 'Parkinson'],
#  'Am': ['am'],
#  'Amanda': ['Tabitha'],
#  'Amateur': ['amateur', 'Professional'],
#  'Ambassador': ['embassy', 'Consul'],
#  'Amendment': ['Constitutional', 'amendment', 'amendments'],
#  'American': ['English',
#               'German',
#               'Australian',
#               'Canadian',
#               'Italian',
#               'Americans'],
#  'Americans': ['Indians'],
#  'Among': ['Across'],
#  'An': ['an'],
#  'Ancient': ['ancient', 'Medieval'],
#  'Andhra': ['Sri'],
#  'Andre': ['André'],
#  'Andrei': ['Anton', 'Lucian'],
#  'Andrew': ['Matthew'],
#  'Andrews': ['McGuire'],
#  'Android': ['Linux', 'iOS', 'iPhone'],
#  'André': ['Andre'],
#  'Andrés': ['Marta'],
#  'Angel': ['Angels', 'angel'],
#  'Angelica': ['Angelina'],
#  'Angelina': ['Angelica'],
#  'Angie': ['Bubba'],
#  'Anglican': ['LDS'],
#  'Animal': ['animals', 'animal', 'Animals'],
#  'Ann': ['Anne'],
#  'Annabelle': ['Jenna', 'Genevieve'],
#  'Anne': ['Ann'],
#  'Anniversary': ['Jubilee'],
#  'Antarctic': ['Arctic', 'Antarctica'],
#  'Antarctica': ['Antarctic'],
#  'Anthony': ['Antony'],
#  'Anti': ['anti'],
#  'Antoine': ['Claude'],
#  'Antony': ['Anthony'],
#  'Antrim': ['Bangor', 'Galloway'],
#  'Anya': ['Sasha'],
#  'Apache': ['Cherokee'],
#  'Apart': ['apart', 'Away', 'Aside'],
#  'Approximately': ['circa', 'approx'],
#  'April': ['May',
#            'June',
#            'March',
#            'September',
#            'July',
#            'January',
#            'October',
#            'August',
#            'November',
#            'December',
#            'February'],
#  'Arab': ['African', 'Egyptian', 'Palestinian', 'Arabian'],
#  'Arc': ['arc'],
#  'Arcade': ['arcade'],
#  'Arch': ['arch'],
#  'Archbishop': ['Bishop',
#                 'Cardinal',
#                 'Archdiocese',
#                 'Patriarch',
#                 'theologian',
#                 'abbot'],
#  'Archibald': ['Archie'],
#  'Architectural': ['aesthetic'],
#  'Archive': ['Database'],
#  'Archived': ['Retrieved'],
#  'Are': ['Were'],
#  'Area': ['Areas'],
#  'Argentina': ['Rosario'],
#  'Argentine': ['Israeli', 'Buenos'],
#  'Aristotle': ['Plato', 'Ptolemy'],
#  'Arizona': ['Hawaii', 'Nevada', 'Montana', 'Wyoming', 'Tucson'],
#  'Arkansas': ['Memphis', 'Shreveport'],
#  'Arlington': ['Fairfax'],
#  'Armand': ['Marius'],
#  'Armenia': ['Antioch'],
#  'Army': ['military', 'army', 'Navy', 'Military', 'armies'],
#  'Art': ['art', 'Arts'],
#  'Article': ['article'],
#  'Artist': ['Musicians'],
#  'Arts': ['Art', 'arts', 'Sciences', 'Artists', 'Humanities', 'Artistic'],
#  'Ash': ['ash'],
#  'Ashe': ['Winkler'],
#  'Ashland': ['Gotham'],
#  'Asia': ['Oceania'],
#  'Asian': ['Asiatic'],
#  'Asiatic': ['Oriental'],
#  'Aside': ['aside'],
#  'Assembly': ['assembly'],
#  'Assessment': ['Framework'],
#  'Assistant': ['Additional', 'Advisor', 'Coordinator'],
#  'Associate': ['Associated', 'Associates'],
#  'Association': ['association', 'Federation'],
#  'Astros': ['Twins', 'Suns', 'Spurs'],
#  'Athena': ['Zeus', 'Artemis'],
#  'Atlanta': ['Savannah'],
#  'Atlantic': ['Pacific', 'Mediterranean'],
#  'Atomic': ['Electrical'],
#  'Attorney': ['Counsel'],
#  'Au': ['au'],
#  'Auckland': ['Napier'],
#  'Audience': ['audiences', 'Jury'],
#  'Audio': ['audio'],
#  'Audrey': ['Daphne', 'Gretchen'],
#  'Aunt': ['Mistress', 'Granny'],
#  'Auschwitz': ['Titanic'],
#  'Australian': ['Tasmanian'],
#  'Austria': ['Luxembourg'],
#  'Auto': ['auto', 'Automobile'],
#  'Automatic': ['automatic'],
#  'Auxiliary': ['auxiliary'],
#  'Avalon': ['Jericho', 'Kiran'],
#  'Avengers': ['Marvel', 'Hulk'],
#  'Avenue': ['Plaza', 'Ave', 'avenue'],
#  'Aviation': ['Aero'],
#  'Aviv': ['Maccabi'],
#  'Award': ['awarded', 'award', 'Awards', 'Prize', 'awards', 'Trophy'],
#  'Away': ['away', 'Apart'],
#  'BA': ['MA', 'BS'],
#  'BBC': ['RTÉ'],
#  'BC': ['AD', 'BCE'],
#  'BCE': ['BC', 'CE'],
#  'BMW': ['McLaren', 'Audi'],
#  'BP': ['BT'],
#  'BS': ['MS'],
#  'BT': ['BP'],
#  'Bachelor': ['bachelor', 'Doctorate'],
#  'Background': ['background'],
#  'Bad': ['bad'],
#  'Baghdad': ['Babylon'],
#  'Bahamas': ['Bronx'],
#  'Bai': ['Hai'],
#  'Ban': ['ban'],
#  'Band': ['band'],
#  'Bang': ['bang'],
#  'Bangalore': ['Osaka', 'Baghdad', 'Christchurch'],
#  'Banner': ['banner'],
#  'Bar': ['bar'],
#  'Barack': ['Obama'],
#  'Barbara': ['Clara'],
#  'Baron': ['Earl', 'Viscount', 'baron'],
#  'Baroness': ['Widow'],
#  'Baroque': ['Gothic'],
#  'Bartlett': ['Wheeler', 'Conway'],
#  'Basic': ['basic', 'Essential'],
#  'Basin': ['basin'],
#  'Bass': ['bass'],
#  'Batman': ['Superman', 'Transformers'],
#  'Battalion': ['Infantry', 'Detachment'],
#  'Battery': ['battery'],
#  'Battle': ['battle', 'battles'],
#  'Bavaria': ['Baden', 'Hesse', 'Brandenburg', 'Holstein', 'Palatinate'],
#  'Bay': ['bay'],
#  'Baylor': ['Simmons'],
#  'Beach': ['beach', 'beaches'],
#  'Beauty': ['beauty'],
#  'Bee': ['bee'],
#  'Beethoven': ['Bach', 'Mozart', 'Goethe', 'Schubert'],
#  'Behind': ['behind'],
#  'Belgarath': ['Harald', 'Cuthbert'],
#  'Belgium': ['Flanders', 'Monaco'],
#  'Beneath': ['Into', 'underside'],
#  'Benedict': ['Gregory'],
#  'Bengali': ['Bengal', 'Burmese'],
#  'Bengals': ['Tigers', 'Ravens'],
#  'Benny': ['Frankie'],
#  'Bergman': ['Hitchcock'],
#  'Bernardo': ['Anita'],
#  'Bernhard': ['Neumann'],
#  'Bernstein': ['Hoffman', 'Adler', 'Goldberg'],
#  'Besides': ['besides'],
#  'Best': ['best', 'Outstanding', 'Better', 'Worst'],
#  'Beta': ['Gamma'],
#  'Bethel': ['Luton'],
#  'Betty': ['Sally'],
#  'Between': ['between'],
#  'Bey': ['Pasha'],
#  'Beyoncé': ['Knowles', 'Gaga'],
#  'Beyond': ['beyond'],
#  'Big': ['big'],
#  'Billboard': ['Grammy'],
#  'Billy': ['Tommy'],
#  'Bin': ['bin'],
#  'Bird': ['birds', 'bird', 'Birds'],
#  'Birth': ['birth'],
#  'Birthday': ['anniversary'],
#  'Bishop': ['bishop',
#             'Archbishop',
#             'Diocese',
#             'diocese',
#             'bishops',
#             'Bishops',
#             'Abbot'],
#  'Bismarck': ['Gladstone'],
#  'Bit': ['bit'],
#  'Black': ['White'],
#  'Blacks': ['Reds'],
#  'Blessed': ['Immaculate'],
#  'Blind': ['blind'],
#  'Block': ['block'],
#  'Blood': ['blood'],
#  'Blues': ['blues'],
#  'Bluff': ['bluff'],
#  'Boat': ['Yacht'],
#  'Bob': ['Jim'],
#  'Bobby': ['Johnny'],
#  'Body': ['bodily'],
#  'Boise': ['Sundance'],
#  'Bold': ['bold'],
#  'Bolivia': ['Andes'],
#  'Bollywood': ['Hollywood'],
#  'Bombay': ['Algiers'],
#  'Bone': ['bone'],
#  'Bonnie': ['Elena'],
#  'Bonus': ['bonus'],
#  'Book': ['book', 'Books'],
#  'Boom': ['boom'],
#  'Boone': ['Delilah'],
#  'Border': ['Borders'],
#  'Born': ['born'],
#  'Borneo': ['Timor'],
#  'Borough': ['borough', 'boroughs'],
#  'Box': ['box'],
#  'Boy': ['boy', 'Girl', 'Boys'],
#  'Brady': ['Hayden'],
#  'Brass': ['brass'],
#  'Braves': ['Hawks'],
#  'Brazilian': ['Hawaiian', 'João', 'Brasil', 'Parisian'],
#  'Brewers': ['Brewer'],
#  'Bride': ['bride'],
#  'Bridge': ['bridge', 'Bridges'],
#  'Brigade': ['Squadron'],
#  'Brigham': ['Ogden'],
#  'Brisbane': ['Sydney',
#               'Melbourne',
#               'Queensland',
#               'Adelaide',
#               'Auckland',
#               'Perth',
#               'Canberra',
#               'Hobart',
#               'Mackay',
#               'Fremantle',
#               'Parramatta',
#               'Fitzroy'],
#  'Brittany': ['Alexis', 'Corbin'],
#  'Bronze': ['Silver'],
#  'Brothers': ['Bros'],
#  'Bubba': ['Angie'],
#  'Bucharest': ['Marseille', 'Ankara'],
#  'Buckinghamshire': ['Bedford'],
#  'Buddhism': ['Dharma'],
#  'Budget': ['budget'],
#  'Buffalo': ['Albany'],
#  'Bulgaria': ['Sofia'],
#  'Bull': ['bull', 'Bulls'],
#  'Bureau': ['bureau'],
#  'Burmese': ['Burma'],
#  'Burnley': ['Middleton', 'Buckley'],
#  'Bus': ['bus', 'buses'],
#  'Business': ['business'],
#  'But': ['And', 'Then', 'Even'],
#  'Butcher': ['butcher'],
#  'Butterfly': ['butterfly'],
#  'Byzantine': ['Roman'],
#  'CA': ['CO'],
#  'CBC': ['CBN'],
#  'CBE': ['CB'],
#  'CBS': ['BBC', 'ABC', 'NBC', 'ITV', 'CBC', 'PBS', 'HBO', 'NPR'],
#  'CD': ['LP', 'cassette'],
#  'CF': ['RF'],
#  'CFL': ['SEC', 'LED'],
#  'CIA': ['FBI', 'NASA', 'FAA', 'USAF', 'EPA', 'Pentagon', 'NSA'],
#  'CNN': ['Bloomberg'],
#  'CO': ['CA'],
#  'CPU': ['processors'],
#  'CR': ['BR'],
#  'Cabinet': ['cabinet'],
#  'Cable': ['cable'],
#  'Cadet': ['Commandant', 'cadet'],
#  'Cafe': ['cafe', 'café', 'Pizza', 'Lounge'],
#  'Cage': ['cage'],
#  'Calendar': ['calendar'],
#  'Camille': ['Jules'],
#  'Campaign': ['campaign'],
#  'Campeonato': ['Liga', 'Deportivo', 'Coupe', 'Clube'],
#  'Campo': ['Monte', 'Toro'],
#  'Campus': ['campus', 'Colleges'],
#  'Canal': ['canal'],
#  'Candy': ['candy'],
#  'Canon': ['canon'],
#  'Canton': ['canton'],
#  'Cantonese': ['Cheung'],
#  'Canyon': ['Navajo'],
#  'Cap': ['cap'],
#  'Capital': ['capital'],
#  'Capt': ['Sgt'],
#  'Captain': ['captain', 'Admiral'],
#  'Carbon': ['carbon', 'CO₂', 'Silicon'],
#  'Cardinal': ['Cardinals', 'cardinal'],
#  'Career': ['career'],
#  'Carl': ['Karl'],
#  'Carlson': ['Hanson'],
#  'Carly': ['Maddy'],
#  'Carole': ['Marilyn'],
#  'Carolyn': ['Carole'],
#  'Carrier': ['carrier'],
#  'Carthage': ['Hannibal'],
#  'Cartoon': ['Nickelodeon'],
#  'Cash': ['cash'],
#  'Cassandra': ['Cassie', 'Phoebe'],
#  'Cassie': ['Melissa'],
#  'Castle': ['castle', 'Palace'],
#  'Cat': ['Kat'],
#  'Catalogue': ['Classification'],
#  'Category': ['category'],
#  'Catherine': ['Elizabeth'],
#  'Cathy': ['Kathy', 'Vicky'],
#  'Caucus': ['caucus'],
#  'Cavalry': ['cavalry', 'Tactical'],
#  'Cave': ['cave'],
#  'Cebu': ['GMA'],
#  'Cecilia': ['Monica'],
#  'Celebrity': ['celebrity'],
#  'Celia': ['Lila', 'Norma'],
#  'Cell': ['cell'],
#  'Celtic': ['Germanic'],
#  'Celtics': ['waived', 'Bucks'],
#  'Census': ['census'],
#  'Center': ['Centers'],
#  'Centre': ['centre'],
#  'Centro': ['Paso', 'Campo'],
#  'Century': ['Millennium'],
#  'Cerambycidae': ['Breuning'],
#  'Certificate': ['certificate', 'Diploma'],
#  'Certified': ['Designed', 'Chartered'],
#  'Ch': ['ch'],
#  'Cha': ['Cho'],
#  'Chair': ['chairman', 'Chairman', 'chairs', 'chaired'],
#  'Champagne': ['Savoy', 'Bordeaux'],
#  'Champion': ['Winner'],
#  'Championship': ['Cup', 'Premiership'],
#  'Chancellor': ['Provost'],
#  'Change': ['Changes'],
#  'Channel': ['channel'],
#  'Chapel': ['Church', 'chapel'],
#  'Chapter': ['chapter', 'CHAPTER'],
#  'Character': ['character'],
#  'Chargers': ['Fresno'],
#  'Charles': ['Louis', 'Francis'],
#  'Charlotte': ['Sophie'],
#  'Charter': ['charter'],
#  'Charts': ['Lyrics'],
#  'Chattanooga': ['Sanford'],
#  'Chef': ['chef', 'Restaurant'],
#  'Chelsea': ['Kensington'],
#  'Chen': ['Shen'],
#  'Chennai': ['Shankar'],
#  'Cherokee': ['Apache', 'Seneca', 'Mohawk'],
#  'Cheryl': ['Sheila'],
#  'Chesapeake': ['Calvert'],
#  'Cheung': ['Hong', 'Wong', 'Chung'],
#  'Chevrolet': ['Dodge'],
#  'Chicago': ['Atlanta', 'Denver'],
#  'Chichester': ['Hastings'],
#  'Chief': ['chief', 'Chiefs'],
#  'Child': ['Children'],
#  'Chile': ['Mexico',
#            'Spain',
#            'Brazil',
#            'Argentina',
#            'Portugal',
#            'Colombia',
#            'Cuba',
#            'Peru',
#            'Bulgaria',
#            'Venezuela',
#            'Argentine',
#            'Ecuador',
#            'Bolivia',
#            'Uruguay',
#            'Guatemala',
#            'Chilean',
#            'Haiti',
#            'Colombian',
#            'Paraguay',
#            'Honduras',
#            'Peruvian',
#            'México',
#            'Uruguayan'],
#  'Chilean': ['Basque', 'Iberian'],
#  'Ching': ['Jing'],
#  'Chloe': ['Michelle'],
#  'Cho': ['Cha'],
#  'Chocolate': ['chocolate'],
#  'Choir': ['chorus', 'Chorus', 'choral'],
#  'Chris': ['Christopher'],
#  'Christ': ['Jesus'],
#  'Christchurch': ['Canterbury'],
#  'Christensen': ['Werner', 'Snyder'],
#  'Christina': ['Cecilia'],
#  'Christine': ['Annette'],
#  'Christmas': ['Easter', 'Halloween', 'Thanksgiving'],
#  'Christoph': ['Stephan'],
#  'Christopher': ['Chris'],
#  'Chrysler': ['Packard'],
#  'Chung': ['Choi', 'Chun'],
#  'Church': ['Cathedral', 'Chapel', 'Churches'],
#  'Cicero': ['Nero'],
#  'Cincinnati': ['Charleston', 'Toledo', 'Dayton'],
#  'Cindy': ['Cynthia', 'Connie'],
#  'Circle': ['circle'],
#  'Circuit': ['circuit'],
#  'Circus': ['circus'],
#  'Citation': ['citation'],
#  'Citizen': ['citizen', 'Citizens'],
#  'Citizens': ['Farmers', 'Residents'],
#  'Civic': ['civic'],
#  'Civil': ['civil'],
#  'Clan': ['clan'],
#  'Clark': ['Clarke'],
#  'Clarke': ['Clark'],
#  'Clary': ['Magnus', 'Jace', 'Tessa', 'Isabelle', 'Jocelyn', 'Maia'],
#  'Class': ['class'],
#  'Classical': ['classical', 'Classics'],
#  'Claudia': ['Sandra', 'Emilia', 'Ingrid'],
#  'Clean': ['clean', 'Dry'],
#  'Cleopatra': ['Caesar'],
#  'Clerk': ['clerk'],
#  'Clock': ['clock'],
#  'Close': ['close'],
#  'Co': ['co'],
#  'Coach': ['coach', 'coaching', 'coaches', 'coached', 'Coaches'],
#  'Coal': ['coal', 'Copper'],
#  'Coast': ['coast', 'Coastal'],
#  'Coca': ['Cola'],
#  'Code': ['code', 'codes'],
#  'Cody': ['Tanner'],
#  'Coke': ['soda'],
#  'Collection': ['collection', 'Archives', 'Anthology', 'Collections'],
#  'Collective': ['collective', 'Consortium'],
#  'Collegiate': ['Polytechnic'],
#  'Collingwood': ['Richmond'],
#  'Cologne': ['Rhine', 'Markus'],
#  'Colombia': ['Indonesia',
#               'Thailand',
#               'Panama',
#               'Morocco',
#               'Algeria',
#               'Catalonia'],
#  'Colombian': ['Chile', 'Philippine', 'Iraqi', 'Syrian', 'Lebanese', 'Belize'],
#  'Colonel': ['Corporal'],
#  'Colonial': ['colonial'],
#  'Colony': ['colony'],
#  'Colour': ['colours', 'Color'],
#  'Colton': ['Reece'],
#  'Comet': ['comet'],
#  'Commanding': ['presiding'],
#  'Commerce': ['commerce'],
#  'Commercial': ['commercial', 'commercially'],
#  'Commissioner': ['commissioner',
#                   'Superintendent',
#                   'superintendent',
#                   'inspector',
#                   'Commissioners'],
#  'Committee': ['Council', 'Commission', 'committee'],
#  'Common': ['common'],
#  'Communication': ['Journalism'],
#  'Communications': ['Electronics', 'Enterprises', 'Wireless'],
#  'Communion': ['communion'],
#  'Communist': ['Soviet', 'Nazi', 'socialist'],
#  'Community': ['community', 'communities', 'Communities'],
#  'Company': ['company', 'Companies'],
#  'Complex': ['complex', 'complexes'],
#  'Composer': ['Conservatory'],
#  'Comprehensive': ['comprehensive'],
#  'Con': ['con'],
#  'Concert': ['concert'],
#  'Concerto': ['Requiem'],
#  'Confederacy': ['Confederate'],
#  'Confederate': ['Confederacy'],
#  'Conference': ['Symposium'],
#  'Congregational': ['Masonic'],
#  'Connecticut': ['NY', 'Hartford'],
#  'Conor': ['Brendan'],
#  'Conservative': ['conservative', 'Progressive'],
#  'Consort': ['Empress', 'consort'],
#  'Constituency': ['constituency'],
#  'Constitution': ['constitution'],
#  'Consumer': ['consumers'],
#  'Contact': ['contact'],
#  'Contemporary': ['Traditional'],
#  'Content': ['content'],
#  'Contest': ['contest', 'Competition', 'Eurovision'],
#  'Continental': ['continental'],
#  'Controller': ['controller', 'treasurer'],
#  'Convent': ['convent'],
#  'Conversely': ['alternatively'],
#  'Conway': ['Bartlett'],
#  'Cooperative': ['cooperative', 'Cooperation', 'Sustainable'],
#  'Core': ['core'],
#  'Cork': ['Dublin',
#           'Belfast',
#           'Kerry',
#           'Galway',
#           'Kilkenny',
#           'Tipperary',
#           'Derry',
#           'Waterford',
#           'Antrim',
#           'Kildare'],
#  'Coronation': ['coronation'],
#  'Corps': ['corps'],
#  'Corpus': ['corpus'],
#  'Costello': ['Presley'],
#  'Cottage': ['cottage', 'Pavilion', 'farmhouse'],
#  'Cotton': ['cotton'],
#  'Could': ['Should', 'Must', 'Shall'],
#  'Council': ['councils', 'Councils'],
#  'Councillor': ['magistrate'],
#  'Counsel': ['counselor'],
#  'Counter': ['counter'],
#  'Country': ['country'],
#  'County': ['counties', 'Counties'],
#  'Courage': ['courage'],
#  'Course': ['course'],
#  'Court': ['court'],
#  'Courthouse': ['Judiciary'],
#  'Coventry': ['Fleetwood'],
#  'Cowboy': ['Cowboys', 'cowboy'],
#  'Crash': ['crash'],
#  'Crazy': ['Weird'],
#  'Cream': ['cream'],
#  'Creative': ['creative'],
#  'Cretaceous': ['Jurassic'],
#  'Crew': ['crew'],
#  'Cricket': ['Rugby', 'cricketer'],
#  'Crimson': ['Scarlet'],
#  'Crisis': ['Conflict'],
#  'Cristina': ['Paula'],
#  'Critical': ['critical', 'critically'],
#  'Croatia': ['Sicily'],
#  'Croatian': ['Korean', 'Flemish', 'Pomeranian'],
#  'Crow': ['crow'],
#  'Crown': ['crown'],
#  'Cruise': ['cruise'],
#  'Crusade': ['Crusaders'],
#  'Crusaders': ['Crusade'],
#  'Crystal': ['crystal'],
#  'Cuban': ['Dominican',
#            'Havana',
#            'Algerian',
#            'Jamaican',
#            'Libyan',
#            'Sicilian',
#            'Tunisian',
#            'Cambodian'],
#  'Culture': ['culture', 'Cultural'],
#  'Cup': ['cup', 'cups', 'Cups'],
#  'Curran': ['Rourke'],
#  'Current': ['currents'],
#  'Custom': ['custom'],
#  'Customs': ['customs', 'Immigration'],
#  'Cuthbert': ['Susannah', 'Fergus'],
#  'Cynthia': ['Kathryn'],
#  'Czech': ['Belarus', 'Slovak'],
#  'DB': ['RB'],
#  'DJ': ['MC', 'DJs'],
#  'DOS': ['Unix'],
#  'DSO': ['VC'],
#  'DVD': ['video', 'CD', 'CDs', 'VHS', 'DVDs'],
#  'Da': ['da'],
#  'Dad': ['Mom', 'Daddy'],
#  'Daddy': ['Mama', 'Papa'],
#  'Daemon': ['Jared'],
#  'Dallas': ['Austin'],
#  'Damascus': ['Mecca'],
#  'Damn': ['Stupid'],
#  'Damon': ['Stefan'],
#  'Dance': ['dance', 'Dancing'],
#  'Daniel': ['Gabriel'],
#  'Danielle': ['Nicole', 'Stephanie', 'Elaine', 'Kristen'],
#  'Daniels': ['Jacobs'],
#  'Danish': ['French',
#             'Russian',
#             'Dutch',
#             'Swedish',
#             'Turkish',
#             'Norwegian',
#             'Portuguese',
#             'Swiss',
#             'Hungarian',
#             'Denmark',
#             'Serbian',
#             'Finnish',
#             'Belgian',
#             'Copenhagen',
#             'Prussian',
#             'Estonian',
#             'Icelandic',
#             'Latvian',
#             'Scandinavian'],
#  'Daphne': ['Veronica'],
#  'Darlington': ['Greenwood'],
#  'Darryl': ['Dwight', 'Daryl'],
#  'Das': ['das'],
#  'Dave': ['Steve'],
#  'Davey': ['Paddy'],
#  'Davidson': ['McLean'],
#  'Davies': ['Griffiths'],
#  'De': ['de'],
#  'Dead': ['dead'],
#  'Dean': ['dean'],
#  'Debbie': ['Tanya'],
#  'Deborah': ['Jennifer', 'Diana', 'Judith', 'Debbie', 'Yvonne'],
#  'Decision': ['decision'],
#  'Declan': ['Aidan', 'Ronan'],
#  'Deep': ['deep'],
#  'Deer': ['deer'],
#  'Defence': ['defense', 'Defense', 'defence', 'defences'],
#  'Defense': ['Defence', 'defenses', 'Defensive'],
#  'Del': ['del'],
#  'Delilah': ['Boone', 'Sadie', 'Annabelle'],
#  'Della': ['Kylie', 'Burnett'],
#  'Democrat': ['Republican'],
#  'Democratic': ['Democracy'],
#  'Democrats': ['Liberals', 'economists'],
#  'Den': ['den'],
#  'Denmark': ['Greenland', 'Schleswig'],
#  'Denny': ['Kellan'],
#  'Dental': ['pulmonary'],
#  'Denton': ['Harrington'],
#  'Department': ['department', 'Bureau'],
#  'Depot': ['depot'],
#  'Depression': ['depression', 'recession'],
#  'Deputy': ['Deputies'],
#  'Der': ['der'],
#  'Derby': ['derby'],
#  'Derbyshire': ['Leeds',
#                 'Sheffield',
#                 'Leicester',
#                 'Nottingham',
#                 'Sunderland',
#                 'Geelong',
#                 'Doncaster',
#                 'Wolverhampton',
#                 'Crewe',
#                 'Swindon'],
#  'Des': ['des', 'Les'],
#  'Desert': ['desert', 'arid'],
#  'Detective': ['Inspector', 'detective', 'detectives'],
#  'Devil': ['Devils', 'Satan'],
#  'Di': ['di'],
#  'Dictionary': ['Encyclopedia', 'Directory'],
#  'Did': ['Had'],
#  'Die': ['die'],
#  'Diesel': ['diesel'],
#  'Diet': ['diet'],
#  'Digital': ['Interactive'],
#  'Din': ['din'],
#  'Dinamo': ['Dynamo'],
#  'Diocese': ['Theological', 'Synod'],
#  'Direct': ['indirect'],
#  'Directed': ['Voiced'],
#  'Director': ['Commissioner', 'Editor', 'Directorate', 'Administrator'],
#  'Dirty': ['dirty'],
#  'Disaster': ['disaster'],
#  'Disco': ['disco'],
#  'Distance': ['distance'],
#  'District': ['district', 'districts', 'Districts'],
#  'Divine': ['divine'],
#  'Division': ['division', 'divisions', 'Divisions'],
#  'Dock': ['dock'],
#  'Doctor': ['doctor', 'Doctors'],
#  'Dodgers': ['Raiders', 'Broncos', 'Rams', 'Bruins', 'RBIs'],
#  'Doherty': ['Nicholson'],
#  'Doing': ['Done'],
#  'Domain': ['domain', 'domains'],
#  'Dome': ['dome'],
#  'Domenico': ['Roberto', 'Misty', 'Carmine'],
#  'Domestic': ['domestic'],
#  'Doncaster': ['Calais', 'Hawthorn'],
#  'Dong': ['Gong'],
#  'Donnell': ['Brien', 'Neill', 'Connell'],
#  'Doom': ['doom'],
#  'Doris': ['Sylvia', 'Phyllis'],
#  'Dorothea': ['Louisa'],
#  'Dover': ['Chatham'],
#  'Downtown': ['downtown', 'neighborhoods', 'Chinatown'],
#  'Dracula': ['Frankenstein'],
#  'Draft': ['draft', 'drafted', 'drafting'],
#  'Dragon': ['Dragons'],
#  'Drama': ['drama', 'Comedy', 'Dramatic'],
#  'Drum': ['drum', 'Drums'],
#  'Du': ['du'],
#  'Dual': ['dual', 'Multiple'],
#  'Dub': ['dub'],
#  'Dublin': ['Edinburgh', 'Glasgow', 'Cardiff'],
#  'Duchess': ['Duke',
#              'Princess',
#              'Duchy',
#              'Countess',
#              'duke',
#              'Marquis',
#              'Marquess',
#              'Dukes',
#              'Baroness'],
#  'Duck': ['Ducks'],
#  'Dude': ['Babe'],
#  'Dust': ['dust'],
#  'Dusty': ['Renee'],
#  'Dutch': ['Amsterdam'],
#  'Duty': ['duty'],
#  'Dwight': ['Darryl'],
#  'Dyer': ['Glover'],
#  'Dynamo': ['Dinamo'],
#  'Dynasty': ['dynasty'],
#  'Díaz': ['Marcos'],
#  'Düsseldorf': ['Verona', 'Hagen'],
#  'EMI': ['Sony', 'RCA', 'Decca', 'BMG'],
#  'EPA': ['WHO'],
#  'Eagle': ['eagle'],
#  'Earth': ['earth'],
#  'Easy': ['easy', 'easier'],
#  'Edith': ['Eleanor', 'Esther', 'Lillian'],
#  'Edition': ['edition', 'editions', 'Version', 'Editions'],
#  'Edmonton': ['Vancouver', 'Halifax', 'Albuquerque', 'Anaheim'],
#  'Edmund': ['Theodore', 'Edmond'],
#  'Edna': ['Mabel', 'Susie'],
#  'Eduard': ['Josef', 'Emil'],
#  'Eduardo': ['Eduard'],
#  'Education': ['Agriculture', 'Educational', 'Teachers', 'schooling'],
#  'Edward': ['Arthur', 'Alfred', 'Edmund'],
#  'Egg': ['egg'],
#  'Egypt': ['Syria', 'Lebanon', 'Palestine', 'Arabia', 'Alexandria', 'Cairo'],
#  'Egyptian': ['Egypt'],
#  'Egyptians': ['Sinai'],
#  'Eisenhower': ['Truman'],
#  'El': ['Al', 'el'],
#  'Elder': ['Younger', 'Elders'],
#  'Election': ['election', 'Electoral', 'reelected'],
#  'Electoral': ['Administrative'],
#  'Electrical': ['IEEE'],
#  'Elementary': ['elementary'],
#  'Elena': ['Damon', 'Bonnie'],
#  'Elephant': ['elephant', 'Monkey', 'elephants'],
#  'Elisabeth': ['Joanne'],
#  'Elite': ['elite'],
#  'Elizabeth': ['Catherine', 'Katherine'],
#  'Elliot': ['Elliott', 'Juliana'],
#  'Elliott': ['Elliot'],
#  'Elmer': ['Bugs'],
#  'Em': ['em'],
#  'Emanuel': ['Emmanuel'],
#  'Emergency': ['emergency'],
#  'Emily': ['Emma', 'Katie', 'Amelia'],
#  'Emmanuel': ['Alain', 'Emanuel'],
#  'Emmy': ['Oscar'],
#  'Emperor': ['Kaiser'],
#  'Empire': ['Imperial'],
#  'Empress': ['Tsar'],
#  'En': ['en'],
#  'End': ['end'],
#  'Enemy': ['Evil'],
#  'Engine': ['engine'],
#  'Engineer': ['engineering', 'architect', 'Producer', 'Architect', 'Designer'],
#  'Engineering': ['Construction', 'Technologies'],
#  'Engineers': ['Journalists'],
#  'England': ['London', 'India', 'Wales'],
#  'Epic': ['epic'],
#  'Episode': ['episode'],
#  'Equal': ['equal'],
#  'Equity': ['equity', 'Equality'],
#  'Era': ['era'],
#  'Eric': ['Erik'],
#  'Erik': ['Eric'],
#  'Ernest': ['Albert'],
#  'Ernie': ['Louie'],
#  'Ernst': ['Heinz'],
# ...
#  'unstable': ['stable'],
#  'until': ['till'],
#  'untouched': ['unused', 'unfinished'],
#  'unusual': ['unique', 'rare', 'abnormal'],
#  'up': ['out', 'down', 'Up'],
#  'upcoming': ['forthcoming', 'imminent', 'impending'],
#  'update': ['updated', 'upgrade', 'updates', 'upgrades'],
#  'updated': ['update'],
#  'upon': ['Upon'],
#  'uprising': ['outbreak'],
#  'upstairs': ['downstairs', 'attic'],
#  'upstream': ['ashore'],
#  'urban': ['industrial'],
#  'urge': ['impulse', 'temptation', 'inclination'],
#  'urgent': ['dire'],
#  'us': ['Us'],
#  'use': ['used', 'using', 'uses', 'usage', 'Use', 'utilize'],
#  'used': ['Used'],
#  'useful': ['handy'],
#  'useless': ['helpless',
#              'obsolete',
#              'harmless',
#              'redundant',
#              'lifeless',
#              'worthless'],
#  'user': ['users', 'consumer', 'Users'],
#  'uses': ['use', 'Using'],
#  'usually': ['traditionally', 'Usually', 'Generally', 'Normally'],
#  'utilities': ['utility'],
#  'utility': ['utilities'],
#  'utilize': ['leverage'],
#  'utilized': ['recycled'],
#  'utterly': ['utter'],
#  'vacant': ['empty', 'vacated', 'vacancy'],
#  'vacation': ['holiday', 'honeymoon'],
#  'valid': ['invalid'],
#  'validity': ['valid',
#               'effectiveness',
#               'reliability',
#               'efficacy',
#               'sanity',
#               'credibility',
#               'authenticity'],
#  'valley': ['Valley', 'ridge', 'valleys', 'canyon', 'estuary'],
#  'value': ['importance', 'valued', 'Value'],
#  'values': ['ideals'],
#  'valve': ['cylinder', 'valves'],
#  'vampire': ['demon',
#              'vampires',
#              'supernatural',
#              'Vampire',
#              'immortal',
#              'Dracula',
#              'Vampires',
#              'vamp'],
#  'vampires': ['werewolves', 'elves'],
#  'van': ['Van'],
#  'vanished': ['departed'],
#  'var': ['subsp'],
#  'variable': ['variables'],
#  'variables': ['variable'],
#  'variant': ['derivative'],
#  'variants': ['mutations'],
#  'variation': ['variations', 'variants', 'Variations', 'variance'],
#  'variations': ['modifications', 'alterations'],
#  'varied': ['eclectic'],
#  'varies': ['increases',
#             'vary',
#             'ranges',
#             'varied',
#             'varying',
#             'differ',
#             'differs',
#             'differing',
#             'differed'],
#  'varieties': ['variety'],
#  'variety': ['varieties'],
#  'various': ['different'],
#  'varsity': ['Varsity'],
#  'vary': ['variation', 'modify', 'specify', 'rotate'],
#  'vassal': ['subordinate', 'puppet'],
#  'vector': ['matrix', 'vectors', 'tensor'],
#  'vehicle': ['car', 'Vehicle'],
#  'vein': ['veins', 'artery'],
#  'veins': ['vein', 'insides'],
#  'velocity': ['momentum'],
#  'velvet': ['leather', 'silk', 'silky', 'Velvet', 'satin'],
#  'vengeance': ['revenge', 'fury', 'retaliation'],
#  'ventral': ['neural'],
#  'venture': ['ventures', 'ventured', 'Venture'],
#  'venue': ['stadium', 'arena', 'auditorium'],
#  'verb': ['noun', 'verbs', 'nouns'],
#  'verge': ['eve'],
#  'verse': ['poetry', 'verses'],
#  'version': ['versions'],
#  'versus': ['vs'],
#  'vertex': ['node', 'vertices'],
#  'vertical': ['horizontal', 'vertically', 'horizontally'],
#  'very': ['quite', 'extremely', 'Very'],
#  'vessel': ['steamer'],
#  'veteran': ['Veterans'],
#  'via': ['Via'],
#  'vibration': ['resonance'],
#  'vicar': ['Vicar'],
#  'vice': ['Vice', 'deputy'],
#  'vicinity': ['proximity'],
#  'victim': ['victims', 'prey', 'survivor'],
#  'victory': ['success', 'defeat', 'wins', 'victories', 'Victory', 'triumph'],
#  'video': ['DVD', 'Video', 'videos'],
#  'view': ['View'],
#  'viewer': ['reader'],
#  'viewpoint': ['view', 'views', 'perspective', 'stance', 'outlook'],
#  'villa': ['Villa'],
#  'village': ['settlement',
#              'villages',
#              'Village',
#              'township',
#              'hamlet',
#              'villagers'],
#  'villain': ['hero', 'traitor'],
#  'villains': ['Avengers'],
#  'vine': ['grape', 'grapes', 'vines', 'vineyards'],
#  'viola': ['Viola'],
#  'violated': ['violation', 'upheld'],
#  'violation': ['breach',
#                'violations',
#                'compliance',
#                'violated',
#                'violating',
#                'unconstitutional',
#                'Enforcement',
#                'infringement',
#                'abuses',
#                'violate',
#                'defiance'],
#  'violence': ['violent',
#               'terrorism',
#               'aggression',
#               'Violence',
#               'hostility',
#               'cruelty',
#               'atrocities',
#               'brutality'],
#  'violin': ['guitar',
#             'piano',
#             'keyboards',
#             'guitars',
#             'saxophone',
#             'Piano',
#             'keyboard',
#             'flute',
#             'cello',
#             'synthesizer',
#             'viola',
#             'fiddle',
#             'harmonica',
#             'harp',
#             'accordion',
#             'Flute'],
#  'viral': ['virus', 'bacterial', 'infectious', 'viruses'],
#  'virgin': ['Virgin'],
#  'virtual': ['Virtual'],
#  'virtue': ['virtues'],
#  'virtues': ['virtue'],
#  'virus': ['viral'],
#  'visa': ['passport', 'Visa'],
#  'vision': ['Vision'],
#  'visit': ['visited', 'visiting', 'visits'],
#  'visited': ['inspected'],
#  'visiting': ['visit', 'Visiting'],
#  'visitor': ['visitors', 'Visitors', 'caller'],
#  'visitors': ['spectators', 'pilgrims'],
#  'visual': ['graphic', 'Visual', 'visually'],
#  'vital': ['useful', 'decisive'],
#  'vocal': ['instrumental'],
#  'vocalist': ['Vocals',
#               'composers',
#               'playwright',
#               'Vocal',
#               'cartoonist',
#               'Singers'],
#  'voice': ['tone', 'voices'],
#  'voices': ['voice', 'voiced', 'Voice', 'whispers', 'Voices'],
#  'vol': ['Vol', 'vols'],
#  'volcano': ['lava'],
#  'volleyball': ['baseball',
#                 'Basketball',
#                 'Volleyball',
#                 'handball',
#                 'gymnastics',
#                 'badminton',
#                 'Handball'],
#  'volume': ['volumes', 'Volume'],
#  'volumes': ['volume'],
#  'volunteer': ['volunteers',
#                'voluntary',
#                'Volunteer',
#                'volunteered',
#                'Volunteers'],
#  'volunteered': ['enlisted'],
#  'volunteers': ['volunteer'],
#  'von': ['Von', 'zu'],
#  'vote': ['votes',
#           'voted',
#           'voting',
#           'voters',
#           'referendum',
#           'ballot',
#           'ballots'],
#  'votes': ['vote'],
#  'voting': ['voter'],
#  'vow': ['vows'],
#  'vowel': ['vowels', 'syllable', 'consonant', 'consonants', 'syllables'],
#  'vowels': ['vowel', 'phrases', 'melodies', 'rhythms'],
#  'vs': ['versus'],
#  'vulnerable': ['vulnerability'],
#  'wage': ['salaries'],
#  'wages': ['unemployment', 'productivity'],
#  'wagon': ['carriage', 'trucks', 'cart'],
#  'wait': ['waiting', 'Wait'],
#  'waited': ['awaited'],
#  'waiter': ['waitress', 'salesman'],
#  'waiting': ['wait', 'waited', 'Waiting', 'awaiting', 'waits'],
#  'waitress': ['maid',
#               'waiter',
#               'bartender',
#               'diner',
#               'prostitute',
#               'housekeeper',
#               'hostess'],
#  'wake': ['aftermath'],
#  'wakes': ['wake',
#            'woke',
#            'awake',
#            'Wake',
#            'waking',
#            'awoke',
#            'awakened',
#            'woken'],
#  'waking': ['wakes'],
#  'walk': ['walked', 'drive', 'ride', 'walks', 'Walk'],
#  'walking': ['Walking'],
#  'wall': ['walls', 'Wall'],
#  'walls': ['walled', 'Walls'],
#  'wander': ['drift', 'stray', 'stumble'],
#  'wanna': ['gonna', 'gotta', 'Wanna', 'Gonna', 'Gotta'],
#  'want': ['need', 'wanted', 'wants', 'wanting', 'Want'],
#  'wanted': ['want', 'Wanted'],
#  'war': ['War', 'conflict'],
#  'ward': ['Ward', 'wards'],
#  'wards': ['ward'],
#  'warfare': ['hostilities', 'Warfare'],
#  'warily': ['closely'],
#  'warm': ['cold',
#           'hot',
#           'cool',
#           'warmth',
#           'warming',
#           'warmer',
#           'warmed',
#           'colder',
#           'Warm'],
#  'warmer': ['cooler'],
#  'warned': ['warning', 'caution'],
#  'warning': ['warned', 'warn', 'warnings', 'Warning', 'warns'],
#  'warrior': ['warriors', 'Warrior', 'warlord'],
#  'wars': ['warfare'],
#  'warship': ['shipyard', 'Shipyard'],
#  'wary': ['sleepy'],
#  'wash': ['washed', 'washing'],
#  'washed': ['dried'],
#  'washing': ['wash', 'drying', 'sewing'],
#  'wasn': ['didn',
#           'couldn',
#           'wouldn',
#           'hadn',
#           'doesn',
#           'isn',
#           'weren',
#           'haven',
#           'aren',
#           'shouldn',
#           'hasn',
#           'ain',
#           'Didn',
#           'Isn',
#           'Wasn'],
#  'waste': ['wasting', 'Waste'],
#  'wasting': ['rotting'],
#  'watch': ['watched', 'watching', 'Watch', 'watches'],
#  'watched': ['viewed'],
#  'watches': ['watch', 'observing', 'Watching'],
#  'watching': ['viewing', 'eyeing'],
#  'water': ['Water', 'waters'],
#  'waters': ['Waters'],
#  'wave': ['waves', 'waved', 'Wave'],
#  'waves': ['wave'],
#  'way': ['Way', 'manner'],
#  'weak': ['weakness'],
#  'weakened': ['battered'],
#  'weaker': ['unstable'],
#  'wealthy': ['rich', 'wealth', 'billionaire'],
#  'weapons': ['sword',
#              'missiles',
#              'swords',
#              'knives',
#              'armament',
#              'Weapons',
#              'munitions'],
#  'wear': ['wore'],
#  'weather': ['Weather'],
#  'wedding': ['Wedding'],
#  'weed': ['weeds'],
#  'weekly': ['annual', 'regularly', 'Daily', 'Weekly', 'Monthly', 'hourly'],
#  'weeks': ['Weeks'],
#  'weigh': ['weight', 'weighed'],
#  'weighed': ['weighing', 'weights', 'weigh', 'weighted', 'weighs', 'Weight'],
#  'weighing': ['measuring'],
#  'welcome': ['welcomed', 'Welcome', 'welcoming'],
#  'welcoming': ['welcome', 'greeting'],
#  'welfare': ['Welfare'],
#  'well': ['poorly'],
#  'were': ['was', 'are'],
#  'weren': ['Aren', 'Couldn'],
#  'werewolves': ['spiders'],
#  'wet': ['dry', 'damp', 'moist', 'Wet'],
#  'wetland': ['habitat'],
#  'whale': ['shark', 'sharks', 'crab'],
#  'whatever': ['what', 'whoever'],
#  'wheat': ['cereal'],
#  'wheel': ['wheeled', 'Wheel'],
#  'wheels': ['axle'],
#  'when': ['where'],
#  'whenever': ['anytime', 'Whenever'],
#  'where': ['wherein'],
#  'wherever': ['everywhere', 'whenever'],
#  'whether': ['if', 'Whether'],
#  'while': ['when', 'whilst'],
#  'whilst': ['while', 'although', 'While', 'whereas', 'Whilst'],
#  'whip': ['whipped', 'whipping'],
#  'whipped': ['whip'],
#  'whisper': ['murmur'],
#  'whispered': ['mouthed', 'hushed'],
#  'whites': ['blacks', 'Blacks'],
#  'whitish': ['pale', 'hairy', 'furrowed', 'lesions'],
#  'who': ['whom', 'Who'],
#  'whoever': ['whatever', 'Whatever', 'wherever', 'Whoever'],
#  'whole': ['entire', 'Whole'],
#  'whom': ['who', 'whose'],
#  'whore': ['liar'],
#  'why': ['how', 'Why'],
#  'wicked': ['Wicked'],
#  'wicket': ['batsman'],
#  'wickets': ['wicket'],
#  'widen': ['narrow', 'narrowed', 'strengthen', 'Wide', 'deepened', 'narrowing'],
#  'widened': ['straightened', 'flared', 'flattened'],
#  'wider': ['wide',
#            'broad',
#            'widened',
#            'tighter',
#            'broader',
#            'brighter',
#            'widening',
#            'thicker',
#            'widen'],
#  'width': ['diameter', 'bandwidth'],
#  'wild': ['Wild', 'feral'],
#  'wilderness': ['Wilderness'],
#  'wildlife': ['Wildlife', 'fauna'],
#  'will': ['Will'],
#  'win': ['Win'],
#  'wind': ['winds', 'Wind', 'breeze'],
#  'window': ['windows', 'doorway', 'windshield', 'Window'],
#  'windshield': ['bumper'],
#  'wine': ['Wine', 'wines', 'whiskey'],
#  'wing': ['wings', 'Wing'],
#  'wings': ['wing', 'Wings', 'winged'],
#  'wingspan': ['fuselage', 'Wingspan'],
#  'winner': ['loser'],
#  'winners': ['recipients'],
#  'wins': ['successes', 'Winning'],
#  'winter': ['summer', 'Winter', 'winters'],
#  'wipe': ['wiped', 'wiping', 'erase', 'swiped'],
#  'wiped': ['wipe', 'erased'],
#  'wire': ['wires', 'Wire'],
#  'wisdom': ['Wisdom'],
#  'wise': ['Wise'],
#  'wish': ['desire', 'wished', 'wishes', 'wishing', 'Wish'],
#  'wished': ['hoped', 'desired', 'longed'],
#  'wishes': ['wish', 'requests', 'desires', 'intends'],
#  'wishing': ['longing'],
#  'witch': ['Witch', 'wizard'],
#  'with': ['of', 'as'],
#  'withdraw': ['retreat'],
#  'withdrawal': ['withdrew', 'removal'],
#  'withdrawn': ['discontinued'],
#  'withdrew': ['removed',
#               'withdrawn',
#               'withdraw',
#               'withdrawal',
#               'retreated',
#               'withdrawing'],
#  'within': ['inside', 'Within'],
#  'without': ['Without'],
#  'witness': ['witnessed', 'witnesses', 'testify', 'Witness'],
#  'witnesses': ['observers'],
#  'wizard': ['Wizard', 'magician', 'mage', 'troll'],
#  'woke': ['dreamed', 'ached', 'alerted'],
#  'wolf': ['Wolf', 'wolves', 'owl'],
#  'woman': ['man', 'person', 'lady', 'Woman'],
#  'women': ['people', 'men', 'children', 'Women', 'girls', 'ladies'],
#  'won': ['Won'],
#  'wonder': ['wondered', 'wondering', 'Wonder', 'wonders', 'amazement'],
#  'wonderful': ['nice',
#                'terrible',
#                'excellent',
#                'brilliant',
#                'horrible',
#                'awful',
#                'gorgeous',
#                'pleasant',
#                'exciting',
#                'exceptional',
#                'delicious',
#                'charming',
#                'spectacular',
#                'profound',
#                'fantastic',
#                'awesome',
#                'glorious',
#                'terrifying',
#                'fascinating',
#                'beautifully',
#                'Wonderful',
#                'disgusting',
#                'dreadful',
#                'superb'],
#  'wood': ['Wood'],
#  'woodland': ['grove'],
#  'woods': ['Woods'],
#  'word': ['words', 'phrase', 'Word'],
#  'wore': ['wearing', 'wear', 'worn', 'wears'],
#  'work': ['working', 'works', 'Work'],
#  'worker': ['workers', 'employee', 'technician'],
#  'workers': ['employees', 'worker', 'Workers', 'miners', 'workforce', 'Worker'],
#  'working': ['work', 'Working'],
#  'works': ['Works'],
#  'workshop': ['shop', 'workshops', 'Workshop'],
#  'world': ['World', 'universe', 'worlds'],
#  'worlds': ['Worlds'],
#  'worldwide': ['global',
#                'abroad',
#                'internationally',
#                'overseas',
#                'nationally',
#                'statewide'],
#  'worry': ['fear', 'worried', 'concern', 'worrying'],
#  'worship': ['hymns', 'worshipped', 'Worship'],
#  'worst': ['worse'],
#  'worth': ['Worth'],
#  'would': ['Would'],
#  'wound': ['wounds'],
#  'wounded': ['casualties'],
#  'wounds': ['wound', 'infections'],
#  'woven': ['knit'],
#  'wrap': ['wrapped', 'wrapping', 'wraps'],
#  'wrapped': ['tangled', 'packaged', 'bundled'],
#  'wrapping': ['wrap', 'winding', 'packaging'],
#  'wraps': ['jackets'],
#  'wrestler': ['wrestling'],
#  'wrestling': ['Wrestling',
#                'boxing',
#                'wrestler',
#                'wrestlers',
#                'Boxing',
#                'wrestled',
#                'MMA'],
#  'wrist': ['neck'],
#  'wrists': ['nape', 'cuffs'],
#  'write': ['written',
#            'wrote',
#            'writer',
#            'writers',
#            'writes',
#            'Writing',
#            'publish',
#            'Written',
#            'compose'],
#  'writes': ['argues'],
#  'writing': ['songwriting'],
#  'wrote': ['write', 'authored', 'penned'],
#  'yacht': ['barge'],
#  'yard': ['Yard'],
#  'yards': ['yard'],
#  'ye': ['ya', 'Ye', 'thee'],
#  'yeah': ['Yeah', 'yes', 'Yep'],
#  'year': ['season', 'month', 'Year'],
#  'yearly': ['seasonal'],
#  'years': ['days', 'months', 'hours', 'weeks', 'Years'],
#  'yelled': ['stomped'],
#  'yelling': ['waving', 'frantic', 'complaining'],
#  'yellow': ['Yellow', 'reddish', 'whitish'],
#  'yellowish': ['rectangular', 'fluorescent'],
#  'yes': ['Yes', 'yeah'],
#  'yesterday': ['today', 'ago'],
#  'yet': ['Yet'],
#  'yield': ['yields', 'yielded', 'yielding'],
#  'yielding': ['producing', 'yield'],
#  'yo': ['Yo'],
#  'yoga': ['Hinduism', 'Yoga'],
#  'young': ['Young'],
#  'younger': ['young', 'youngest', 'eldest'],
#  'youngest': ['smallest', 'tallest', 'newest', 'shortest'],
#  'your': ['yer'],
#  'yours': ['your'],
#  'youth': ['Youth', 'teens'],
#  'zero': ['Zero'],
#  'zinc': ['nickel'],
#  'zombie': ['vampire', 'corpse', 'werewolf', 'undead', 'Zombie', 'demonic'],
#  'zone': ['Zone', 'zones'],
#  'zoo': ['Zoo', 'aquarium'],
#  'zur': ['für'],
#  '£1': ['Rs', '£2'],
#  '£2': ['£1', 'euros'],
#  'École': ['Universidad', 'Ligue', 'Société', 'Académie', 'Université'],
#  'état': ['coup']}

# %%
i = 0

dist = torch.norm(filtered_vocab_embeds - pivot_vectors[i], dim=1, p=None)
knn = dist.topk(20, largest=False)
print(knn)

print()
print(tokenizer.convert_ids_to_tokens(index_idxs[int(pivot_tokens[i])]))
print(tokenizer.convert_ids_to_tokens([index_idxs[int(k)] for k in knn.indices]))
# Out:
# torch.return_types.topk(
# values=tensor([0.0000, 0.8689, 0.9224, 1.2187, 1.2297, 1.2297, 1.2633, 1.2662, 1.2722,
#         1.2759, 1.2766, 1.2784, 1.2798, 1.2812, 1.2825, 1.2827, 1.2926, 1.2926,
#         1.2928, 1.2958]),
# indices=tensor([ 4219,  6505,  8135, 13305,  3650,  2018,  7186, 21257, 14126,  9515,
#          1868, 14133, 14770, 20911,  7064,  4425, 14584, 10083, 13542,  3057]))
#
# ignored
# ['ignored', 'ignore', 'ignoring', 'neglected', 'rejected', 'refused', 'avoided', 'Ignoring', 'omitted', 'annoyed', 'grabbed', 'endured', 'scowled', 'mocked', 'glared', 'shouted', 'overlooked', 'utilized', 'irritated', 'regarded']

# %%
from transformers import pipeline

unmasker = pipeline('fill-mask', model='bert-base-cased')
unmasked = unmasker("Carravaggio is a [MASK].")

pprint(unmasked)

#pprint({res['token_str']: {k: v for k, v in decoded_pivots.items() if res['token_str'] in v} for res in unmasked})
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [{'score': 0.03785141184926033,
#   'sequence': 'Carravaggio is a politician.',
#   'token': 2931,
#   'token_str': 'politician'},
#  {'score': 0.03195589780807495,
#   'sequence': 'Carravaggio is a village.',
#   'token': 1491,
#   'token_str': 'village'},
#  {'score': 0.02933131717145443,
#   'sequence': 'Carravaggio is a commune.',
#   'token': 5188,
#   'token_str': 'commune'},
#  {'score': 0.025602901354432106,
#   'sequence': 'Carravaggio is a painter.',
#   'token': 5125,
#   'token_str': 'painter'},
#  {'score': 0.020912228152155876,
#   'sequence': 'Carravaggio is a comune.',
#   'token': 24382,
#   'token_str': 'comune'}]

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("It was commissioned by the local confraternity dedicated to Saint Anne for the altar of their oratory.")

print(doc.spans)
print([(token.text, token.pos_) for token in doc if token.pos_ in ['PROPN', 'NOUN']])

unmasked = unmasker("oratory is a [MASK].")

pprint(unmasked)
# Out:
# {}
# [('confraternity', 'NOUN'), ('Saint', 'PROPN'), ('Anne', 'PROPN'), ('altar', 'NOUN'), ('oratory', 'NOUN')]
# [{'score': 0.09746652841567993,
#   'sequence': 'oratory is a requirement.',
#   'token': 8875,
#   'token_str': 'requirement'},
#  {'score': 0.05214102193713188,
#   'sequence': 'oratory is a virtue.',
#   'token': 13456,
#   'token_str': 'virtue'},
#  {'score': 0.040402546525001526,
#   'sequence': 'oratory is a profession.',
#   'token': 9545,
#   'token_str': 'profession'},
#  {'score': 0.026807719841599464,
#   'sequence': 'oratory is a verb.',
#   'token': 12464,
#   'token_str': 'verb'},
#  {'score': 0.02123214863240719,
#   'sequence': 'oratory is a practice.',
#   'token': 2415,
#   'token_str': 'practice'}]

# %% [markdown]
# k-means clustering

# %%
from kmeans_pytorch import kmeans

cluster_ids, cluster_centres = kmeans(filtered_vocab_embeds, 11, distance='cosine', device=torch.device('cuda:0'))
# Out:
# running k-means on cuda:0..
# [running kmeans]: 34it [00:05,  5.76it/s, center_shift=0.000078, iteration=34, tol=0.000100]

# %%
print(0 in cluster_ids)

assignments = {int(i): (cluster_ids == int(i)).nonzero().squeeze(dim=1) for i in cluster_ids.unique()}
print(assignments)

assignment_lens = {k: len(v) for k, v in assignments.items()}
print(assignment_lens)
# Out:
# True
# {0: tensor([  167,   450,   460,  ..., 21377, 21381, 21410]), 1: tensor([  309,   346,   348,   396,   484,   495,   630,   743,   855,   873,
#           883,   907,   928,   939,  1027,  1061,  1078,  1205,  1242,  1303,
#          1308,  1373,  1386,  1449,  1525,  1550,  1553,  1647,  1732,  1762,
#          1794,  1849,  1921,  1964,  2001,  2134,  2161,  2165,  2201,  2260,
#          2351,  2359,  2451,  2502,  2523,  2535,  2649,  2650,  2674,  2733,
#          2808,  2877,  2965,  2995,  3132,  3225,  3245,  3260,  3291,  3302,
#          3307,  3343,  3389,  3453,  3465,  3491,  3500,  3532,  3586,  3659,
#          3676,  3699,  3705,  3735,  3768,  3885,  3887,  3889,  3912,  3923,
#          3953,  3965,  4097,  4121,  4151,  4184,  4216,  4218,  4301,  4326,
#          4409,  4433,  4457,  4570,  4682,  4716,  4730,  4751,  4764,  4778,
#          4790,  4817,  4831,  4846,  4890,  4941,  4951,  4954,  4981,  4994,
#          5089,  5097,  5115,  5125,  5147,  5154,  5194,  5211,  5213,  5235,
#          5252,  5287,  5296,  5301,  5306,  5326,  5365,  5415,  5427,  5452,
#          5632,  5748,  5836,  5847,  5862,  5869,  5883,  5912,  5945,  5970,
#          5992,  6016,  6058,  6112,  6225,  6229,  6305,  6322,  6397,  6476,
#          6526,  6533,  6556,  6557,  6558,  6576,  6603,  6621,  6625,  6638,
#          6669,  6692,  6705,  6708,  6715,  6758,  6762,  6769,  6782,  6797,
#          6804,  6823,  6831,  6898,  6911,  6916,  6940,  6955,  6991,  6998,
#          7037,  7043,  7073,  7085,  7138,  7218,  7233,  7244,  7247,  7289,
#          7300,  7348,  7397,  7414,  7420,  7437,  7441,  7475,  7545,  7550,
#          7580,  7614,  7677,  7683,  7727,  7736,  7740,  7747,  7763,  7783,
#          7787,  7793,  7804,  7879,  7966,  7987,  8035,  8076,  8086,  8147,
#          8237,  8240,  8253,  8276,  8277,  8291,  8322,  8345,  8392,  8596,
#          8600,  8609,  8616,  8656,  8702,  8703,  8705,  8746,  8773,  8805,
#          8811,  8826,  8848,  8869,  8883,  8891,  8914,  8916,  8939,  8955,
#          8984,  9038,  9063,  9076,  9093,  9113,  9129,  9136,  9141,  9191,
#          9201,  9291,  9308,  9310,  9334,  9340,  9380,  9404,  9460,  9593,
#          9664,  9669,  9688,  9697,  9708,  9715,  9732,  9764,  9771,  9794,
#          9820,  9841,  9871,  9902,  9914,  9927,  9949, 10022, 10036, 10095,
#         10127, 10210, 10213, 10269, 10283, 10294, 10318, 10345, 10393, 10402,
#         10453, 10456, 10481, 10502, 10545, 10568, 10626, 10660, 10668, 10675,
#         10685, 10695, 10707, 10716, 10768, 10769, 10783, 10810, 10826, 10836,
#         10843, 10852, 10950, 10972, 10982, 10998, 11024, 11036, 11044, 11056,
#         11058, 11119, 11130, 11137, 11150, 11186, 11194, 11213, 11224, 11291,
#         11318, 11320, 11336, 11352, 11377, 11393, 11462, 11471, 11501, 11529,
#         11533, 11562, 11570, 11575, 11595, 11634, 11638, 11696, 11703, 11717,
#         11776, 11808, 11811, 11833, 11845, 11903, 11911, 11939, 11963, 11985,
#         12007, 12031, 12074, 12077, 12078, 12081, 12083, 12108, 12117, 12119,
#         12165, 12181, 12196, 12197, 12202, 12233, 12246, 12308, 12312, 12317,
#         12389, 12419, 12472, 12486, 12487, 12488, 12500, 12551, 12648, 12719,
#         12750, 12757, 12777, 12785, 12789, 12813, 12836, 12857, 12864, 12890,
#         12924, 12938, 12940, 12946, 12988, 13022, 13062, 13063, 13079, 13110,
#         13164, 13165, 13187, 13209, 13231, 13259, 13278, 13325, 13386, 13401,
#         13445, 13446, 13455, 13579, 13606, 13649, 13785, 13787, 13823, 13852,
#         13871, 13882, 13950, 13986, 14005, 14013, 14025, 14027, 14037, 14112,
#         14139, 14243, 14280, 14284, 14287, 14311, 14351, 14403, 14406, 14478,
#         14496, 14498, 14505, 14537, 14570, 14618, 14646, 14660, 14745, 14773,
#         14805, 14812, 14826, 14844, 14847, 14863, 14871, 14915, 14979, 14980,
#         14986, 14998, 15050, 15068, 15096, 15136, 15168, 15195, 15239, 15241,
#         15284, 15290, 15316, 15324, 15342, 15356, 15361, 15367, 15382, 15401,
#         15438, 15476, 15483, 15499, 15522, 15533, 15586, 15588, 15600, 15644,
#         15660, 15667, 15715, 15744, 15747, 15769, 15870, 15914, 16057, 16077,
#         16090, 16136, 16153, 16228, 16235, 16251, 16274, 16332, 16352, 16391,
#         16398, 16464, 16542, 16606, 16645, 16650, 16653, 16709, 16711, 16743,
#         16787, 16794, 16798, 16805, 16849, 16851, 16853, 16867, 16895, 16903,
#         16906, 16917, 16950, 16965, 17024, 17028, 17036, 17070, 17085, 17096,
#         17106, 17113, 17136, 17189, 17198, 17204, 17208, 17221, 17228, 17240,
#         17276, 17313, 17317, 17355, 17359, 17362, 17373, 17375, 17386, 17389,
#         17393, 17505, 17506, 17539, 17541, 17579, 17627, 17706, 17730, 17745,
#         17768, 17800, 17838, 17893, 17916, 17938, 17977, 17981, 18029, 18035,
#         18036, 18057, 18073, 18093, 18097, 18102, 18115, 18121, 18177, 18180,
#         18184, 18249, 18257, 18331, 18332, 18385, 18472, 18487, 18584, 18587,
#         18670, 18708, 18712, 18738, 18741, 18747, 18751, 18808, 18818, 18901,
#         18927, 18951, 18965, 18969, 19009, 19040, 19073, 19077, 19080, 19147,
#         19186, 19265, 19284, 19316, 19318, 19345, 19438, 19443, 19460, 19466,
#         19480, 19563, 19567, 19616, 19620, 19638, 19678, 19843, 19849, 19851,
#         19955, 19969, 19985, 20030, 20052, 20053, 20070, 20084, 20114, 20115,
#         20142, 20150, 20167, 20178, 20197, 20225, 20262, 20264, 20311, 20436,
#         20445, 20474, 20478, 20493, 20517, 20581, 20649, 20679, 20683, 20693,
#         20763, 20801, 20872, 20891, 20928, 20935, 20945, 21011, 21016, 21069,
#         21097, 21163, 21193, 21197, 21227, 21304, 21374, 21402]), 2: tensor([  156,   168,   196,   210,   217,   224,   225,   227,   232,   233,
#           235,   238,   241,   242,   243,   245,   252,   254,   255,   257,
#           259,   260,   274,   275,   276,   279,   296,   297,   300,   314,
#           341,   342,   343,   353,   356,   367,   375,   378,   400,   403,
#           409,   421,   423,   427,   435,   463,   466,   472,   473,   476,
#           502,   535,   568,   579,   580,   582,   600,   606,   643,   646,
#           676,   678,   682,   699,   717,   739,   761,   767,   779,   781,
#           788,   793,   803,   805,   828,   840,   858,   908,   947,   958,
#           977,   988,   996,  1025,  1031,  1048,  1062,  1095,  1097,  1117,
#          1122,  1145,  1158,  1162,  1180,  1183,  1201,  1211,  1229,  1230,
#          1233,  1258,  1268,  1280,  1287,  1288,  1299,  1314,  1315,  1330,
#          1362,  1402,  1412,  1413,  1418,  1453,  1485,  1505,  1546,  1552,
#          1555,  1601,  1603,  1618,  1628,  1644,  1670,  1676,  1679,  1691,
#          1697,  1704,  1712,  1719,  1721,  1728,  1734,  1748,  1752,  1756,
#          1758,  1761,  1764,  1774,  1776,  1790,  1796,  1808,  1809,  1819,
#          1822,  1827,  1830,  1832,  1839,  1853,  1869,  1871,  1906,  1918,
#          1936,  1946,  1958,  1959,  1996,  2047,  2073,  2074,  2080,  2089,
#          2095,  2112,  2145,  2146,  2213,  2236,  2246,  2262,  2263,  2272,
#          2277,  2328,  2338,  2348,  2366,  2368,  2371,  2382,  2398,  2452,
#          2460,  2487,  2506,  2511,  2539,  2548,  2562,  2571,  2580,  2587,
#          2603,  2607,  2616,  2638,  2642,  2644,  2663,  2667,  2671,  2687,
#          2689,  2691,  2725,  2737,  2747,  2776,  2782,  2785,  2805,  2842,
#          2911,  2921,  2923,  2954,  2958,  2964,  2968,  3104,  3134,  3144,
#          3148,  3200,  3203,  3218,  3303,  3308,  3315,  3321,  3333,  3341,
#          3349,  3352,  3379,  3387,  3403,  3441,  3481,  3485,  3499,  3507,
#          3510,  3536,  3545,  3549,  3559,  3562,  3564,  3570,  3594,  3605,
#          3616,  3633,  3672,  3677,  3709,  3727,  3779,  3784,  3817,  3826,
#          3837,  3850,  3853,  3858,  3895,  3900,  3913,  3927,  3938,  3944,
#          3950,  3963,  3975,  3977,  3993,  4000,  4008,  4020,  4028,  4043,
#          4047,  4056,  4058,  4060,  4082,  4088,  4118,  4128,  4130,  4131,
#          4143,  4163,  4164,  4173,  4196,  4214,  4231,  4243,  4251,  4256,
#          4259,  4260,  4302,  4309,  4311,  4345,  4354,  4368,  4399,  4426,
#          4427,  4464,  4466,  4474,  4495,  4507,  4526,  4590,  4618,  4644,
#          4653,  4690,  4696,  4743,  4747,  4757,  4873,  4912,  4974,  5025,
#          5028,  5046,  5075,  5082,  5162,  5180,  5196,  5208,  5222,  5261,
#          5299,  5300,  5322,  5324,  5344,  5346,  5374,  5380,  5401,  5425,
#          5453,  5575,  5610,  5637,  5699,  5722,  5870,  5882,  5884,  5933,
#          5997,  6014,  6099,  6148,  6196,  6216,  6220,  6287,  6376,  6394,
#          6400,  6435,  6445,  6493,  6501,  6597,  6606,  6619,  6726,  6779,
#          6809,  6857,  6914,  7056,  7137,  7141,  7156,  7164,  7177,  7185,
#          7189,  7239,  7259,  7313,  7345,  7368,  7384,  7459,  7466,  7497,
#          7499,  7570,  7574,  7585,  7656,  7662,  7711,  7719,  7722,  7761,
#          7774,  7790,  7795,  7847,  7977,  7996,  8033,  8118,  8170,  8174,
#          8177,  8185,  8254,  8295,  8309,  8320,  8424,  8514,  8565,  8567,
#          8599,  8603,  8630,  8648,  8650,  8655,  8666,  8713,  8722,  8777,
#          8819,  8970,  9068,  9088,  9090,  9092,  9127,  9175,  9184,  9272,
#          9335,  9363,  9373,  9440,  9448,  9470,  9495,  9633,  9645,  9702,
#          9752,  9828,  9833,  9851,  9877,  9912,  9932,  9965,  9977, 10025,
#         10026, 10040, 10060, 10065, 10072, 10123, 10124, 10159, 10217, 10232,
#         10303, 10332, 10334, 10347, 10368, 10420, 10431, 10507, 10515, 10526,
#         10586, 10592, 10613, 10620, 10623, 10627, 10692, 10701, 10764, 10775,
#         10797, 10848, 10879, 10884, 10886, 10897, 10900, 10909, 10947, 10970,
#         10978, 11012, 11153, 11162, 11174, 11204, 11210, 11230, 11236, 11245,
#         11249, 11325, 11337, 11349, 11396, 11433, 11457, 11486, 11523, 11596,
#         11632, 11643, 11675, 11705, 11719, 11720, 11739, 11780, 11787, 11862,
#         11883, 12020, 12070, 12157, 12166, 12228, 12242, 12273, 12277, 12332,
#         12351, 12377, 12388, 12429, 12457, 12460, 12493, 12501, 12522, 12526,
#         12646, 12733, 12797, 12829, 12855, 12878, 12884, 12948, 13015, 13091,
#         13157, 13192, 13244, 13251, 13357, 13402, 13426, 13473, 13478, 13492,
#         13497, 13505, 13523, 13580, 13631, 13727, 13732, 13734, 13735, 13742,
#         13756, 13809, 13810, 13817, 13834, 13845, 13868, 13910, 13916, 13974,
#         13999, 14036, 14067, 14084, 14138, 14141, 14151, 14156, 14181, 14241,
#         14268, 14272, 14274, 14346, 14416, 14488, 14518, 14541, 14554, 14558,
#         14568, 14571, 14574, 14595, 14597, 14613, 14622, 14656, 14668, 14672,
#         14689, 14692, 14703, 14714, 14721, 14730, 14776, 14779, 14788, 14824,
#         14839, 14866, 14885, 14887, 14899, 14952, 14955, 14960, 14969, 14996,
#         15004, 15098, 15108, 15141, 15204, 15207, 15216, 15287, 15297, 15309,
#         15317, 15345, 15359, 15389, 15395, 15451, 15467, 15558, 15639, 15647,
#         15718, 15746, 15760, 15780, 15793, 15811, 15889, 15938, 16000, 16035,
#         16098, 16150, 16209, 16303, 16323, 16325, 16349, 16393, 16423, 16468,
#         16505, 16510, 16525, 16570, 16604, 16644, 16655, 16663, 16679, 16716,
#         16725, 16731, 16745, 16751, 16761, 16789, 16809, 16811, 16886, 16905,
#         16916, 16931, 16942, 16966, 16979, 16999, 17020, 17030, 17045, 17049,
#         17050, 17059, 17083, 17095, 17169, 17174, 17233, 17292, 17304, 17315,
#         17320, 17323, 17329, 17334, 17351, 17371, 17372, 17414, 17416, 17452,
#         17465, 17508, 17544, 17565, 17634, 17640, 17641, 17662, 17677, 17680,
#         17713, 17719, 17738, 17792, 17795, 17819, 17860, 17870, 17896, 17906,
#         17960, 17971, 17975, 17976, 17999, 18000, 18032, 18096, 18168, 18204,
#         18294, 18306, 18335, 18338, 18344, 18367, 18389, 18411, 18419, 18420,
#         18439, 18470, 18532, 18578, 18586, 18659, 18668, 18671, 18695, 18757,
#         18828, 18877, 18885, 18905, 18915, 18916, 18946, 18964, 19053, 19056,
#         19074, 19100, 19110, 19129, 19167, 19199, 19202, 19206, 19254, 19336,
#         19375, 19392, 19398, 19411, 19423, 19432, 19450, 19476, 19487, 19555,
#         19591, 19625, 19632, 19654, 19662, 19674, 19723, 19741, 19762, 19763,
#         19791, 19828, 19835, 19898, 19908, 19962, 19976, 19987, 19999, 20063,
#         20159, 20161, 20220, 20232, 20236, 20283, 20302, 20305, 20316, 20319,
#         20364, 20389, 20396, 20410, 20411, 20431, 20449, 20462, 20463, 20471,
#         20479, 20480, 20507, 20520, 20545, 20594, 20597, 20633, 20640, 20678,
#         20692, 20713, 20734, 20758, 20776, 20814, 20840, 20841, 20842, 20869,
#         20889, 20956, 20968, 20993, 21001, 21012, 21013, 21024, 21025, 21031,
#         21094, 21104, 21127, 21133, 21136, 21144, 21173, 21174, 21185, 21186,
#         21215, 21222, 21229, 21238, 21241, 21256, 21280, 21336, 21340, 21393,
#         21409]), 3: tensor([  102,   105,   121,  ..., 21396, 21399, 21412]), 4: tensor([   47,   119,   126,  ..., 21401, 21407, 21408]), 5: tensor([  120,   190,   306,  ..., 21390, 21405, 21406]), 6: tensor([  155,   202,   267,  ..., 21403, 21411, 21414]), 7: tensor([    6,    20,    26,  ..., 21376, 21398, 21400]), 8: tensor([  125,   239,   287,  ..., 21380, 21394, 21404]), 9: tensor([  138,   357,   410,  ..., 21366, 21367, 21413]), 10: tensor([    0,     1,     2,  ...,  7529,  7922, 11321])}
# {0: 2266, 1: 708, 2: 921, 3: 2849, 4: 1761, 5: 2528, 6: 4427, 7: 1461, 8: 1257, 9: 2038, 10: 1199}
